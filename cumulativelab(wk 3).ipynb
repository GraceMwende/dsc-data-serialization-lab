# %%
import json
import csv

# %%
world_cup_file = open('data/world_cup_2018.json')
population_file = open("data/country_populations.csv")

# %% [markdown]
# ### 2018 World Cup Data
# In the cell below, use the json module to load the data from world_cup_file into a dictionary called world_cup_data

# %%
world_cup_data = json.load(world_cup_file)
world_cup_file.close()

# %%
world_cup_data
# Out:
# {'name': 'World Cup 2018',
#  'rounds': [{'name': 'Matchday 1',
#    'matches': [{'num': 1,
#      'date': '2018-06-14',
#      'time': '18:00',
#      'team1': {'name': 'Russia', 'code': 'RUS'},
#      'team2': {'name': 'Saudi Arabia', 'code': 'KSA'},
#      'score1': 5,
#      'score2': 0,
#      'score1i': 2,
#      'score2i': 0,
#      'goals1': [{'name': 'Gazinsky', 'minute': 12, 'score1': 1, 'score2': 0},
#       {'name': 'Cheryshev', 'minute': 43, 'score1': 2, 'score2': 0},
#       {'name': 'Dzyuba', 'minute': 71, 'score1': 3, 'score2': 0},
#       {'name': 'Cheryshev',
#        'minute': 90,
#        'offset': 1,
#        'score1': 4,
#        'score2': 0},
#       {'name': 'Golovin',
#        'minute': 90,
#        'offset': 4,
#        'score1': 5,
#        'score2': 0}],
#      'goals2': [],
#      'group': 'Group A',
#      'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#      'city': 'Moscow',
#      'timezone': 'UTC+3'}]},
#   {'name': 'Matchday 2',
#    'matches': [{'num': 2,
#      'date': '2018-06-15',
#      'time': '17:00',
#      'team1': {'name': 'Egypt', 'code': 'EGY'},
#      'team2': {'name': 'Uruguay', 'code': 'URU'},
#      'score1': 0,
#      'score2': 1,
#      'score1i': 0,
#      'score2i': 0,
#      'goals1': [],
#      'goals2': [{'name': 'Giménez', 'minute': 89, 'score1': 0, 'score2': 1}],
#      'group': 'Group A',
#      'stadium': {'key': 'ekaterinburg', 'name': 'Ekaterinburg Arena'},
#      'city': 'Ekaterinburg',
#      'timezone': 'UTC+5'},
#     {'num': 3,
#      'date': '2018-06-15',
#      'time': '21:00',
#      'team1': {'name': 'Portugal', 'code': 'POR'},
#      'team2': {'name': 'Spain', 'code': 'ESP'},
#      'score1': 3,
#      'score2': 3,
#      'score1i': 2,
#      'score2i': 1,
#      'goals1': [{'name': 'Ronaldo',
#        'minute': 4,
#        'score1': 1,
#        'score2': 0,
#        'penalty': True},
#       {'name': 'Ronaldo', 'minute': 44, 'score1': 2, 'score2': 1},
#       {'name': 'Ronaldo', 'minute': 88, 'score1': 3, 'score2': 3}],
#      'goals2': [{'name': 'Costa', 'minute': 24, 'score1': 1, 'score2': 1},
#       {'name': 'Costa', 'minute': 55, 'score1': 2, 'score2': 2},
#       {'name': 'Nacho', 'minute': 58, 'score1': 2, 'score2': 3}],
#      'group': 'Group B',
#      'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#      'city': 'Sochi',
#      'timezone': 'UTC+3'},
#     {'num': 4,
#      'date': '2018-06-15',
#      'time': '18:00',
#      'team1': {'name': 'Morocco', 'code': 'MAR'},
#      'team2': {'name': 'Iran', 'code': 'IRN'},
#      'score1': 0,
#      'score2': 1,
#      'score1i': 0,
#      'score2i': 0,
#      'goals1': [],
#      'goals2': [{'name': 'Bouhaddouz',
#        'minute': 90,
#        'offset': 5,
#        'score1': 0,
#        'score2': 1,
#        'owngoal': True}],
#      'group': 'Group B',
#      'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#      'city': 'Saint Petersburg',
#      'timezone': 'UTC+3'}]},
#   {'name': 'Matchday 3',
#    'matches': [{'num': 5,
#      'date': '2018-06-16',
#      'time': '13:00',
#      'team1': {'name': 'France', 'code': 'FRA'},
#      'team2': {'name': 'Australia', 'code': 'AUS'},
#      'score1': 2,
#      'score2': 1,
#      'score1i': 0,
#      'score2i': 0,
#      'goals1': [{'name': 'Griezmann',
#        'minute': 58,
#        'score1': 1,
#        'score2': 0,
#        'penalty': True},
#       {'name': 'Behich',
#        'minute': 81,
#        'score1': 2,
#        'score2': 1,
#        'owngoal': True}],
#      'goals2': [{'name': 'Jedinak',
#        'minute': 62,
#        'score1': 1,
#        'score2': 1,
#        'penalty': True}],
#      'group': 'Group C',
#      'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#      'city': 'Kazan',
#      'timezone': 'UTC+3'},
#     {'num': 6,
#      'date': '2018-06-16',
#      'time': '19:00',
#      'team1': {'name': 'Peru', 'code': 'PER'},
#      'team2': {'name': 'Denmark', 'code': 'DEN'},
#      'score1': 0,
#      'score2': 1,
#      'score1i': 0,
#      'score2i': 0,
#      'goals1': [],
#      'goals2': [{'name': 'Poulsen', 'minute': 59, 'score1': 0, 'score2': 1}],
#      'group': 'Group C',
#      'stadium': {'key': 'mordovia', 'name': 'Mordovia Arena'},
#      'city': 'Saransk',
#      'timezone': 'UTC+3'},
#     {'num': 7,
#      'date': '2018-06-16',
#      'time': '16:00',
#      'team1': {'name': 'Argentina', 'code': 'ARG'},
#      'team2': {'name': 'Iceland', 'code': 'ISL'},
#      'score1': 1,
#      'score2': 1,
#      'score1i': 1,
#      'score2i': 1,
#      'goals1': [{'name': 'Agüero', 'minute': 19, 'score1': 1, 'score2': 0}],
#      'goals2': [{'name': 'Finnbogason',
#        'minute': 23,
#        'score1': 1,
#        'score2': 1}],
#      'group': 'Group D',
#      'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'},
#      'city': 'Moscow',
#      'timezone': 'UTC+3'},
#     {'num': 8,
#      'date': '2018-06-16',
#      'time': '21:00',
#      'team1': {'name': 'Croatia', 'code': 'CRO'},
#      'team2': {'name': 'Nigeria', 'code': 'NGA'},
#      'score1': 2,
#      'score2': 0,
#      'score1i': 1,
#      'score2i': 0,
#      'goals1': [{'name': 'Etebo',
#        'minute': 32,
#        'score1': 1,
#        'score2': 0,
#        'owngoal': True},
#       {'name': 'Modrić',
#        'minute': 71,
#        'score1': 2,
#        'score2': 0,
#        'penalty': True}],
#      'goals2': [],
#      'group': 'Group D',
#      'stadium': {'key': 'kaliningrad', 'name': 'Kaliningrad Stadium'},
#      'city': 'Kaliningrad',
#      'timezone': 'UTC+2'}]},
#   {'name': 'Matchday 4',
#    'matches': [{'num': 9,
#      'date': '2018-06-17',
#      'time': '21:00',
#      'team1': {'name': 'Brazil', 'code': 'BRA'},
#      'team2': {'name': 'Switzerland', 'code': 'SUI'},
#      'score1': 1,
#      'score2': 1,
#      'score1i': 1,
#      'score2i': 0,
#      'goals1': [{'name': 'Coutinho', 'minute': 20, 'score1': 1, 'score2': 0}],
#      'goals2': [{'name': 'Zuber', 'minute': 50, 'score1': 1, 'score2': 1}],
#      'group': 'Group E',
#      'stadium': {'key': 'rostov', 'name': 'Rostov Arena'},
#      'city': 'Rostov-on-Don',
#      'timezone': 'UTC+3'},
#     {'num': 10,
#      'date': '2018-06-17',
#      'time': '16:00',
#      'team1': {'name': 'Costa Rica', 'code': 'CRC'},
#      'team2': {'name': 'Serbia', 'code': 'SRB'},
#      'score1': 0,
#      'score2': 1,
#      'score1i': 0,
#      'score2i': 0,
#      'goals1': [],
#      'goals2': [{'name': 'Kolarov', 'minute': 56, 'score1': 0, 'score2': 1}],
#      'group': 'Group E',
#      'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#      'city': 'Samara',
#      'timezone': 'UTC+4'},
#     {'num': 11,
#      'date': '2018-06-17',
#      'time': '18:00',
#      'team1': {'name': 'Germany', 'code': 'GER'},
#      'team2': {'name': 'Mexico', 'code': 'MEX'},
#      'score1': 0,
#      'score2': 1,
#      'score1i': 0,
#      'score2i': 1,
#      'goals1': [],
#      'goals2': [{'name': 'Lozano', 'minute': 35, 'score1': 0, 'score2': 1}],
#      'group': 'Group F',
#      'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#      'city': 'Moscow',
#      'timezone': 'UTC+3'}]},
#   {'name': 'Matchday 5',
#    'matches': [{'num': 12,
#      'date': '2018-06-18',
#      'time': '15:00',
#      'team1': {'name': 'Sweden', 'code': 'SWE'},
#      'team2': {'name': 'South Korea', 'code': 'KOR'},
#      'score1': 1,
#      'score2': 0,
#      'score1i': 0,
#      'score2i': 0,
#      'goals1': [{'name': 'Granqvist',
#        'minute': 65,
#        'score1': 1,
#        'score2': 0,
#        'penalty': True}],
#      'goals2': [],
#      'group': 'Group F',
#      'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'},
#      'city': 'Nizhny Novgorod',
#      'timezone': 'UTC+3'},
#     {'num': 13,
#      'date': '2018-06-18',
#      'time': '18:00',
#      'team1': {'name': 'Belgium', 'code': 'BEL'},
#      'team2': {'name': 'Panama', 'code': 'PAN'},
#      'score1': 3,
#      'score2': 0,
#      'score1i': 0,
#      'score2i': 0,
#      'goals1': [{'name': 'Mertens', 'minute': 47, 'score1': 1, 'score2': 0},
#       {'name': 'Lukaku', 'minute': 69, 'score1': 2, 'score2': 0},
#       {'name': 'Lukaku', 'minute': 75, 'score1': 3, 'score2': 0}],
#      'goals2': [],
#      'group': 'Group G',
#      'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#      'city': 'Sochi',
#      'timezone': 'UTC+3'},
#     {'num': 14,
#      'date': '2018-06-18',
#      'time': '21:00',
#      'team1': {'name': 'Tunisia', 'code': 'TUN'},
#      'team2': {'name': 'England', 'code': 'ENG'},
#      'score1': 1,
#      'score2': 2,
#      'score1i': 1,
#      'score2i': 1,
#      'goals1': [{'name': 'Sassi',
#        'minute': 35,
#        'score1': 1,
#        'score2': 1,
#        'penalty': True}],
#      'goals2': [{'name': 'Kane', 'minute': 11, 'score1': 0, 'score2': 1},
#       {'name': 'Kane', 'minute': 90, 'offset': 1, 'score1': 1, 'score2': 2}],
#      'group': 'Group G',
#      'stadium': {'key': 'volgograd', 'name': 'Volgograd Arena'},
#      'city': 'Volgograd',
#      'timezone': 'UTC+3'}]},
#   {'name': 'Matchday 6',
#    'matches': [{'num': 15,
#      'date': '2018-06-19',
#      'time': '18:00',
#      'team1': {'name': 'Poland', 'code': 'POL'},
#      'team2': {'name': 'Senegal', 'code': 'SEN'},
#      'score1': 1,
#      'score2': 2,
#      'score1i': 0,
#      'score2i': 1,
#      'goals1': [{'name': 'Krychowiak',
#        'minute': 86,
#        'score1': 1,
#        'score2': 2}],
#      'goals2': [{'name': 'Cionek',
#        'minute': 37,
#        'score1': 0,
#        'score2': 1,
#        'owngoal': True},
#       {'name': 'Niang', 'minute': 60, 'score1': 0, 'score2': 2}],
#      'group': 'Group H',
#      'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'},
#      'city': 'Moscow',
#      'timezone': 'UTC+3'},
#     {'num': 16,
#      'date': '2018-06-19',
#      'time': '15:00',
#      'team1': {'name': 'Colombia', 'code': 'COL'},
#      'team2': {'name': 'Japan', 'code': 'JPN'},
#      'score1': 1,
#      'score2': 2,
#      'score1i': 1,
#      'score2i': 1,
#      'goals1': [{'name': 'J. Quintero',
#        'minute': 39,
#        'score1': 1,
#        'score2': 1}],
#      'goals2': [{'name': 'Kagawa',
#        'minute': 6,
#        'score1': 0,
#        'score2': 1,
#        'penalty': True},
#       {'name': 'Osako', 'minute': 73, 'score1': 1, 'score2': 2}],
#      'group': 'Group H',
#      'stadium': {'key': 'mordovia', 'name': 'Mordovia Arena'},
#      'city': 'Saransk',
#      'timezone': 'UTC+3'},
#     {'num': 17,
#      'date': '2018-06-19',
#      'time': '21:00',
#      'team1': {'name': 'Russia', 'code': 'RUS'},
#      'team2': {'name': 'Egypt', 'code': 'EGY'},
#      'score1': 3,
#      'score2': 1,
#      'score1i': 0,
#      'score2i': 0,
#      'goals1': [{'name': 'A. Fathi',
#        'minute': 47,
#        'score1': 1,
#        'score2': 0,
#        'owngoal': True},
#       {'name': 'Cheryshev', 'minute': 59, 'score1': 2, 'score2': 0},
#       {'name': 'Dzyuba', 'minute': 62, 'score1': 3, 'score2': 0}],
#      'goals2': [{'name': 'M. Salah',
#        'minute': 73,
#        'score1': 3,
#        'score2': 1,
#        'penalty': True}],
#      'group': 'Group A',
#      'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#      'city': 'Saint Petersburg',
#      'timezone': 'UTC+3'}]},
#   {'name': 'Matchday 7',
#    'matches': [{'num': 18,
#      'date': '2018-06-20',
#      'time': '18:00',
#      'team1': {'name': 'Uruguay', 'code': 'URU'},
#      'team2': {'name': 'Saudi Arabia', 'code': 'KSA'},
#      'score1': 1,
#      'score2': 0,
#      'score1i': 1,
#      'score2i': 0,
#      'goals1': [{'name': 'L. Suárez', 'minute': 23, 'score1': 1, 'score2': 0}],
#      'goals2': [],
#      'group': 'Group A',
#      'stadium': {'key': 'rostov', 'name': 'Rostov Arena'},
#      'city': 'Rostov-on-Don',
#      'timezone': 'UTC+3'},
#     {'num': 19,
#      'date': '2018-06-20',
#      'time': '15:00',
#      'team1': {'name': 'Portugal', 'code': 'POR'},
#      'team2': {'name': 'Morocco', 'code': 'MAR'},
#      'score1': 1,
#      'score2': 0,
#      'score1i': 1,
#      'score2i': 0,
#      'goals1': [{'name': 'Ronaldo', 'minute': 4, 'score1': 1, 'score2': 0}],
#      'goals2': [],
#      'group': 'Group B',
#      'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#      'city': 'Moscow',
#      'timezone': 'UTC+3'},
#     {'num': 20,
#      'date': '2018-06-20',
#      'time': '21:00',
#      'team1': {'name': 'Iran', 'code': 'IRN'},
#      'team2': {'name': 'Spain', 'code': 'ESP'},
#      'score1': 0,
#      'score2': 1,
#      'score1i': 0,
#      'score2i': 0,
#      'goals1': [],
#      'goals2': [{'name': 'Diego Costa',
#        'minute': 54,
#        'score1': 0,
#        'score2': 1}],
#      'group': 'Group B',
#      'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#      'city': 'Kazan',
#      'timezone': 'UTC+3'}]},
#   {'name': 'Matchday 8',
#    'matches': [{'num': 21,
#      'date': '2018-06-21',
#      'time': '20:00',
#      'team1': {'name': 'France', 'code': 'FRA'},
#      'team2': {'name': 'Peru', 'code': 'PER'},
#      'score1': 1,
#      'score2': 0,
#      'score1i': 1,
#      'score2i': 0,
#      'goals1': [{'name': 'Mbappé', 'minute': 34, 'score1': 1, 'score2': 0}],
#      'goals2': [],
#      'group': 'Group C',
#      'stadium': {'key': 'ekaterinburg', 'name': 'Ekaterinburg Arena'},
#      'city': 'Ekaterinburg',
#      'timezone': 'UTC+5'},
#     {'num': 22,
#      'date': '2018-06-21',
#      'time': '16:00',
#      'team1': {'name': 'Denmark', 'code': 'DEN'},
#      'team2': {'name': 'Australia', 'code': 'AUS'},
#      'score1': 1,
#      'score2': 1,
#      'score1i': 1,
#      'score2i': 1,
#      'goals1': [{'name': 'Eriksen', 'minute': 7, 'score1': 1, 'score2': 0}],
#      'goals2': [{'name': 'Jedinak',
#        'minute': 38,
#        'score1': 1,
#        'score2': 1,
#        'penalty': True}],
#      'group': 'Group C',
#      'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#      'city': 'Samara',
#      'timezone': 'UTC+4'},
#     {'num': 23,
#      'date': '2018-06-21',
#      'time': '21:00',
#      'team1': {'name': 'Argentina', 'code': 'ARG'},
#      'team2': {'name': 'Croatia', 'code': 'CRO'},
#      'score1': 0,
#      'score2': 3,
#      'score1i': 0,
#      'score2i': 0,
#      'goals1': [],
#      'goals2': [{'name': 'Rebić', 'minute': 53, 'score1': 0, 'score2': 1},
#       {'name': 'Modrić', 'minute': 80, 'score1': 0, 'score2': 2},
#       {'name': 'Rakitić',
#        'minute': 90,
#        'offset': 1,
#        'score1': 0,
#        'score2': 3}],
#      'group': 'Group D',
#      'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'},
#      'city': 'Nizhny Novgorod',
#      'timezone': 'UTC+3'}]},
#   {'name': 'Matchday 9',
#    'matches': [{'num': 24,
#      'date': '2018-06-22',
#      'time': '18:00',
#      'team1': {'name': 'Nigeria', 'code': 'NGA'},
#      'team2': {'name': 'Iceland', 'code': 'ISL'},
#      'score1': 2,
#      'score2': 0,
#      'score1i': 0,
#      'score2i': 0,
#      'goals1': [{'name': 'Musa', 'minute': 49, 'score1': 1, 'score2': 0},
#       {'name': 'Musa', 'minute': 75, 'score1': 2, 'score2': 0}],
#      'goals2': [],
#      'group': 'Group D',
#      'stadium': {'key': 'volgograd', 'name': 'Volgograd Arena'},
#      'city': 'Volgograd',
#      'timezone': 'UTC+3'},
#     {'num': 25,
#      'date': '2018-06-22',
#      'time': '15:00',
#      'team1': {'name': 'Brazil', 'code': 'BRA'},
#      'team2': {'name': 'Costa Rica', 'code': 'CRC'},
#      'score1': 2,
#      'score2': 0,
#      'score1i': 0,
#      'score2i': 0,
#      'group': 'Group E',
#      'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#      'city': 'Saint Petersburg',
#      'timezone': 'UTC+3'},
#     {'num': 26,
#      'date': '2018-06-22',
#      'time': '20:00',
#      'team1': {'name': 'Serbia', 'code': 'SRB'},
#      'team2': {'name': 'Switzerland', 'code': 'SUI'},
#      'score1': 1,
#      'score2': 2,
#      'score1i': 1,
#      'score2i': 0,
#      'goals1': [{'name': 'Mitrović', 'minute': 5, 'score1': 1, 'score2': 0}],
#      'goals2': [{'name': 'Xhaka', 'minute': 52, 'score1': 1, 'score2': 1},
#       {'name': 'Shaqiri', 'minute': 90, 'score1': 1, 'score2': 2}],
#      'group': 'Group E',
#      'stadium': {'key': 'kaliningrad', 'name': 'Kaliningrad Stadium'},
#      'city': 'Kaliningrad',
#      'timezone': 'UTC+2'}]},
#   {'name': 'Matchday 10',
#    'matches': [{'num': 27,
#      'date': '2018-06-23',
#      'time': '21:00',
#      'team1': {'name': 'Germany', 'code': 'GER'},
#      'team2': {'name': 'Sweden', 'code': 'SWE'},
#      'score1': 2,
#      'score2': 1,
#      'score1i': 0,
#      'score2i': 1,
#      'goals1': [{'name': 'Reus', 'minute': 48, 'score1': 1, 'score2': 1},
#       {'name': 'Kroos', 'minute': 90, 'offset': 5, 'score1': 2, 'score2': 1}],
#      'goals2': [{'name': 'Toivonen', 'minute': 32, 'score1': 0, 'score2': 1}],
#      'group': 'Group F',
#      'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#      'city': 'Sochi',
#      'timezone': 'UTC+3'},
#     {'num': 28,
#      'date': '2018-06-23',
#      'time': '18:00',
#      'team1': {'name': 'South Korea', 'code': 'KOR'},
#      'team2': {'name': 'Mexico', 'code': 'MEX'},
#      'score1': 1,
#      'score2': 2,
#      'score1i': 0,
#      'score2i': 1,
#      'goals1': [{'name': 'Son Heung-min',
#        'minute': 90,
#        'offset': 3,
#        'score1': 1,
#        'score2': 2}],
#      'goals2': [{'name': 'Carlos V.',
#        'minute': 26,
#        'score1': 0,
#        'score2': 1,
#        'penalty': True},
#       {'name': 'J. Hernández', 'minute': 66, 'score1': 0, 'score2': 2}],
#      'group': 'Group F',
#      'stadium': {'key': 'rostov', 'name': 'Rostov Arena'},
#      'city': 'Rostov-on-Don',
#      'timezone': 'UTC+3'},
#     {'num': 29,
#      'date': '2018-06-23',
#      'time': '15:00',
#      'team1': {'name': 'Belgium', 'code': 'BEL'},
#      'team2': {'name': 'Tunisia', 'code': 'TUN'},
#      'score1': 5,
#      'score2': 2,
#      'score1i': 3,
#      'score2i': 1,
#      'goals1': [{'name': 'E. Hazard',
#        'minute': 6,
#        'score1': 1,
#        'score2': 0,
#        'penalty': True},
#       {'name': 'R. Lukaku', 'minute': 16, 'score1': 2, 'score2': 0},
#       {'name': 'R. Lukaku',
#        'minute': 45,
#        'offset': 3,
#        'score1': 3,
#        'score2': 1},
#       {'name': 'E. Hazard', 'minute': 51, 'score1': 4, 'score2': 1},
#       {'name': 'Batshuayi', 'minute': 90, 'score1': 5, 'score2': 1}],
#      'goals2': [{'name': 'Bronn', 'minute': 18, 'score1': 2, 'score2': 1},
#       {'name': 'Khazri', 'minute': 90, 'offset': 3, 'score1': 5, 'score2': 2}],
#      'group': 'Group G',
#      'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'},
#      'city': 'Moscow',
#      'timezone': 'UTC+3'}]},
#   {'name': 'Matchday 11',
#    'matches': [{'num': 30,
#      'date': '2018-06-24',
#      'time': '15:00',
#      'team1': {'name': 'England', 'code': 'ENG'},
#      'team2': {'name': 'Panama', 'code': 'PAN'},
#      'score1': 6,
#      'score2': 1,
#      'score1i': 5,
#      'score2i': 0,
#      'goals1': [{'name': 'Stones', 'minute': 8, 'score1': 1, 'score2': 0},
#       {'name': 'Kane',
#        'minute': 22,
#        'score1': 2,
#        'score2': 0,
#        'penalty': True},
#       {'name': 'Lingard', 'minute': 36, 'score1': 3, 'score2': 0},
#       {'name': 'Stones', 'minute': 40, 'score1': 4, 'score2': 0},
#       {'name': 'Kane',
#        'minute': 45,
#        'offset': 1,
#        'score1': 5,
#        'score2': 0,
#        'penalty': True},
#       {'name': 'Kane', 'minute': 62, 'score1': 6, 'score2': 0}],
#      'goals2': [{'name': 'Baloy', 'minute': 78, 'score1': 6, 'score2': 1}],
#      'group': 'Group G',
#      'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'},
#      'city': 'Nizhny Novgorod',
#      'timezone': 'UTC+3'},
#     {'num': 31,
#      'date': '2018-06-24',
#      'time': '21:00',
#      'team1': {'name': 'Poland', 'code': 'POL'},
#      'team2': {'name': 'Colombia', 'code': 'COL'},
#      'score1': 0,
#      'score2': 3,
#      'score1i': 0,
#      'score2i': 1,
#      'goals1': [],
#      'goals2': [{'name': 'Y. Mina', 'minute': 40, 'score1': 0, 'score2': 1},
#       {'name': 'Falcao', 'minute': 70, 'score1': 0, 'score2': 2},
#       {'name': 'Cuadrado', 'minute': 75, 'score1': 0, 'score2': 3}],
#      'group': 'Group H',
#      'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#      'city': 'Kazan',
#      'timezone': 'UTC+3'},
#     {'num': 32,
#      'date': '2018-06-24',
#      'time': '20:00',
#      'team1': {'name': 'Japan', 'code': 'JPN'},
#      'team2': {'name': 'Senegal', 'code': 'SEN'},
#      'score1': 2,
#      'score2': 2,
#      'score1i': 1,
#      'score2i': 1,
#      'goals1': [{'name': 'Inui', 'minute': 34, 'score1': 1, 'score2': 1},
#       {'name': 'Honda', 'minute': 78, 'score1': 2, 'score2': 2}],
#      'goals2': [{'name': 'Mané', 'minute': 11, 'score1': 0, 'score2': 1},
#       {'name': 'M. Wagué', 'minute': 71, 'score1': 1, 'score2': 2}],
#      'group': 'Group H',
#      'stadium': {'key': 'ekaterinburg', 'name': 'Ekaterinburg Arena'},
#      'city': 'Ekaterinburg',
#      'timezone': 'UTC+5'}]},
#   {'name': 'Matchday 12',
#    'matches': [{'num': 33,
#      'date': '2018-06-25',
#      'time': '18:00',
#      'team1': {'name': 'Uruguay', 'code': 'URU'},
#      'team2': {'name': 'Russia', 'code': 'RUS'},
#      'score1': 3,
#      'score2': 0,
#      'score1i': 2,
#      'score2i': 0,
#      'goals1': [{'name': 'L. Suárez', 'minute': 10, 'score1': 1, 'score2': 0},
#       {'name': 'Cheryshev',
#        'minute': 23,
#        'score1': 2,
#        'score2': 0,
#        'owngoal': True},
#       {'name': 'E. Cavani', 'minute': 90, 'score1': 3, 'score2': 0}],
#      'goals2': [],
#      'group': 'Group A',
#      'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#      'city': 'Samara',
#      'timezone': 'UTC+4'},
#     {'num': 34,
#      'date': '2018-06-25',
#      'time': '17:00',
#      'team1': {'name': 'Saudi Arabia', 'code': 'KSA'},
#      'team2': {'name': 'Egypt', 'code': 'EGY'},
#      'score1': 2,
#      'score2': 1,
#      'score1i': 1,
#      'score2i': 1,
#      'goals1': [{'name': 'Salman Al-Faraj',
#        'minute': 45,
#        'offset': 6,
#        'score1': 1,
#        'score2': 1,
#        'penalty': True},
#       {'name': 'Salem Al-Dawsari',
#        'minute': 90,
#        'offset': 5,
#        'score1': 2,
#        'score2': 1}],
#      'goals2': [{'name': 'M. Salah', 'minute': 22, 'score1': 0, 'score2': 1}],
#      'group': 'Group A',
#      'stadium': {'key': 'volgograd', 'name': 'Volgograd Arena'},
#      'city': 'Volgograd',
#      'timezone': 'UTC+3'},
#     {'num': 35,
#      'date': '2018-06-25',
#      'time': '21:00',
#      'team1': {'name': 'Iran', 'code': 'IRN'},
#      'team2': {'name': 'Portugal', 'code': 'POR'},
#      'score1': 1,
#      'score2': 1,
#      'score1i': 0,
#      'score2i': 1,
#      'goals1': [{'name': 'Karim Ansarifard',
#        'minute': 90,
#        'offset': 3,
#        'score1': 1,
#        'score2': 1,
#        'penalty': True}],
#      'goals2': [{'name': 'Quaresma', 'minute': 45, 'score1': 0, 'score2': 1}],
#      'group': 'Group B',
#      'stadium': {'key': 'mordovia', 'name': 'Mordovia Arena'},
#      'city': 'Saransk',
#      'timezone': 'UTC+3'},
#     {'num': 36,
#      'date': '2018-06-25',
#      'time': '20:00',
#      'team1': {'name': 'Spain', 'code': 'ESP'},
#      'team2': {'name': 'Morocco', 'code': 'MAR'},
#      'score1': 2,
#      'score2': 2,
#      'score1i': 1,
#      'score2i': 1,
#      'goals1': [{'name': 'Isco', 'minute': 19, 'score1': 1, 'score2': 1},
#       {'name': 'Iago Aspas',
#        'minute': 90,
#        'offset': 1,
#        'score1': 2,
#        'score2': 2}],
#      'goals2': [{'name': 'Boutaib', 'minute': 14, 'score1': 0, 'score2': 1},
#       {'name': 'En-Nesyri', 'minute': 81, 'score1': 1, 'score2': 2}],
#      'group': 'Group B',
#      'stadium': {'key': 'kaliningrad', 'name': 'Kaliningrad Stadium'},
#      'city': 'Kaliningrad',
#      'timezone': 'UTC+2'}]},
#   {'name': 'Matchday 13',
#    'matches': [{'num': 37,
#      'date': '2018-06-26',
#      'time': '17:00',
#      'team1': {'name': 'Denmark', 'code': 'DEN'},
#      'team2': {'name': 'France', 'code': 'FRA'},
#      'score1': 0,
#      'score2': 0,
#      'score1i': 0,
#      'score2i': 0,
#      'group': 'Group C',
#      'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#      'city': 'Moscow',
#      'timezone': 'UTC+3'},
#     {'num': 38,
#      'date': '2018-06-26',
#      'time': '17:00',
#      'team1': {'name': 'Australia', 'code': 'AUS'},
#      'team2': {'name': 'Peru', 'code': 'PER'},
#      'score1': 0,
#      'score2': 2,
#      'score1i': 0,
#      'score2i': 1,
#      'goals1': [],
#      'goals2': [{'name': 'Carrillo', 'minute': 18, 'score1': 0, 'score2': 1},
#       {'name': 'Guerrero', 'minute': 50, 'score1': 0, 'score2': 2}],
#      'group': 'Group C',
#      'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#      'city': 'Sochi',
#      'timezone': 'UTC+3'},
#     {'num': 39,
#      'date': '2018-06-26',
#      'time': '21:00',
#      'team1': {'name': 'Nigeria', 'code': 'NGA'},
#      'team2': {'name': 'Argentina', 'code': 'ARG'},
#      'score1': 1,
#      'score2': 2,
#      'score1i': 0,
#      'score2i': 1,
#      'goals1': [{'name': 'Moses',
#        'minute': 51,
#        'score1': 1,
#        'score2': 1,
#        'penalty': True}],
#      'goals2': [{'name': 'Messi', 'minute': 14, 'score1': 0, 'score2': 1},
#       {'name': 'Marcos Rojo', 'minute': 86, 'score1': 1, 'score2': 2}],
#      'group': 'Group D',
#      'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#      'city': 'Saint Petersburg',
#      'timezone': 'UTC+3'},
#     {'num': 40,
#      'date': '2018-06-26',
#      'time': '21:00',
#      'team1': {'name': 'Iceland', 'code': 'ISL'},
#      'team2': {'name': 'Croatia', 'code': 'CRO'},
#      'score1': 1,
#      'score2': 2,
#      'score1i': 0,
#      'score2i': 0,
#      'goals1': [{'name': 'G. Sigurðsson',
#        'minute': 76,
#        'score1': 1,
#        'score2': 1,
#        'penalty': True}],
#      'goals2': [{'name': 'Badelj', 'minute': 53, 'score1': 0, 'score2': 1},
#       {'name': 'Perišić', 'minute': 90, 'score1': 1, 'score2': 2}],
#      'group': 'Group D',
#      'stadium': {'key': 'rostov', 'name': 'Rostov Arena'},
#      'city': 'Rostov-on-Don',
#      'timezone': 'UTC+3'}]},
#   {'name': 'Matchday 14',
#    'matches': [{'num': 41,
#      'date': '2018-06-27',
#      'time': '21:00',
#      'team1': {'name': 'Serbia', 'code': 'SRB'},
#      'team2': {'name': 'Brazil', 'code': 'BRA'},
#      'score1': 0,
#      'score2': 2,
#      'score1i': 0,
#      'score2i': 1,
#      'goals1': [],
#      'goals2': [{'name': 'Paulinho', 'minute': 36, 'score1': 0, 'score2': 1},
#       {'name': 'Thiago Silva', 'minute': 68, 'score1': 0, 'score2': 2}],
#      'group': 'Group E',
#      'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'},
#      'city': 'Moscow',
#      'timezone': 'UTC+3'},
#     {'num': 42,
#      'date': '2018-06-27',
#      'time': '21:00',
#      'team1': {'name': 'Switzerland', 'code': 'SUI'},
#      'team2': {'name': 'Costa Rica', 'code': 'CRC'},
#      'score1': 2,
#      'score2': 2,
#      'score1i': 1,
#      'score2i': 0,
#      'goals1': [{'name': 'Džemaili', 'minute': 31, 'score1': 1, 'score2': 0},
#       {'name': 'Drmić', 'minute': 88, 'score1': 2, 'score2': 1}],
#      'goals2': [{'name': 'Waston', 'minute': 56, 'score1': 1, 'score2': 1},
#       {'name': 'Sommer',
#        'minute': 90,
#        'offset': 3,
#        'score1': 2,
#        'score2': 2,
#        'owngoal': True}],
#      'group': 'Group E',
#      'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'},
#      'city': 'Nizhny Novgorod',
#      'timezone': 'UTC+3'},
#     {'num': 43,
#      'date': '2018-06-27',
#      'time': '17:00',
#      'team1': {'name': 'South Korea', 'code': 'KOR'},
#      'team2': {'name': 'Germany', 'code': 'GER'},
#      'score1': 2,
#      'score2': 0,
#      'score1i': 0,
#      'score2i': 0,
#      'goals1': [{'name': 'Kim Young-gwon',
#        'minute': 90,
#        'offset': 2,
#        'score1': 1,
#        'score2': 0},
#       {'name': 'Son Heung-min',
#        'minute': 90,
#        'offset': 6,
#        'score1': 2,
#        'score2': 0}],
#      'goals2': [],
#      'group': 'Group F',
#      'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#      'city': 'Kazan',
#      'timezone': 'UTC+3'},
#     {'num': 44,
#      'date': '2018-06-27',
#      'time': '19:00',
#      'team1': {'name': 'Mexico', 'code': 'MEX'},
#      'team2': {'name': 'Sweden', 'code': 'SWE'},
#      'score1': 0,
#      'score2': 3,
#      'score1i': 0,
#      'score2i': 0,
#      'goals1': [],
#      'goals2': [{'name': 'Augustinsson',
#        'minute': 50,
#        'score1': 0,
#        'score2': 1},
#       {'name': 'Granqvist',
#        'minute': 62,
#        'score1': 0,
#        'score2': 2,
#        'penalty': True},
#       {'name': 'Álvarez',
#        'minute': 74,
#        'score1': 0,
#        'score2': 3,
#        'owngoal': True}],
#      'group': 'Group F',
#      'stadium': {'key': 'ekaterinburg', 'name': 'Ekaterinburg Arena'},
#      'city': 'Ekaterinburg',
#      'timezone': 'UTC+5'}]},
#   {'name': 'Matchday 15',
#    'matches': [{'num': 45,
#      'date': '2018-06-28',
#      'time': '20:00',
#      'team1': {'name': 'England', 'code': 'ENG'},
#      'team2': {'name': 'Belgium', 'code': 'BEL'},
#      'score1': 0,
#      'score2': 1,
#      'score1i': 0,
#      'score2i': 0,
#      'goals1': [],
#      'goals2': [{'name': 'Adnan Januzaj',
#        'minute': 51,
#        'score1': 0,
#        'score2': 1}],
#      'group': 'Group G',
#      'stadium': {'key': 'kaliningrad', 'name': 'Kaliningrad Stadium'},
#      'city': 'Kaliningrad',
#      'timezone': 'UTC+2'},
#     {'num': 46,
#      'date': '2018-06-28',
#      'time': '21:00',
#      'team1': {'name': 'Panama', 'code': 'PAN'},
#      'team2': {'name': 'Tunisia', 'code': 'TUN'},
#      'score1': 1,
#      'score2': 2,
#      'score1i': 1,
#      'score2i': 0,
#      'goals1': [{'name': 'Yassine Meriah',
#        'minute': 33,
#        'score1': 1,
#        'score2': 0,
#        'owngoal': True}],
#      'goals2': [{'name': 'Fakhereedine Ben Youssef',
#        'minute': 51,
#        'score1': 1,
#        'score2': 1},
#       {'name': 'Wahbi Khazri', 'minute': 66, 'score1': 1, 'score2': 2}],
#      'group': 'Group G',
#      'stadium': {'key': 'mordovia', 'name': 'Mordovia Arena'},
#      'city': 'Saransk',
#      'timezone': 'UTC+3'},
#     {'num': 47,
#      'date': '2018-06-28',
#      'time': '17:00',
#      'team1': {'name': 'Japan', 'code': 'JPN'},
#      'team2': {'name': 'Poland', 'code': 'POL'},
#      'score1': 0,
#      'score2': 1,
#      'score1i': 0,
#      'score2i': 1,
#      'goals1': [],
#      'goals2': [{'name': 'Bednarek', 'minute': 59, 'score1': 0, 'score2': 1}],
#      'group': 'Group H',
#      'stadium': {'key': 'volgograd', 'name': 'Volgograd Arena'},
#      'city': 'Volgograd',
#      'timezone': 'UTC+3'},
#     {'num': 48,
#      'date': '2018-06-28',
#      'time': '18:00',
#      'team1': {'name': 'Senegal', 'code': 'SEN'},
#      'team2': {'name': 'Colombia', 'code': 'COL'},
#      'score1': 0,
#      'score2': 1,
#      'score1i': 0,
#      'score2i': 1,
#      'goals1': [],
#      'goals2': [{'name': 'Y. Mina', 'minute': 74, 'score1': 0, 'score2': 1}],
#      'group': 'Group H',
#      'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#      'city': 'Samara',
#      'timezone': 'UTC+4'}]},
#   {'name': 'Round of 16',
#    'matches': [{'num': 49,
#      'date': '2018-06-30',
#      'time': '21:00',
#      'team1': {'name': 'Uruguay', 'code': 'URU'},
#      'team2': {'name': 'Portugal', 'code': 'POR'},
#      'score1': 2,
#      'score2': 1,
#      'score1i': 1,
#      'score2i': 0,
#      'score1et': None,
#      'score2et': None,
#      'score1p': None,
#      'score2p': None,
#      'knockout': True,
#      'goals1': [{'name': 'Edinson Cavani',
#        'minute': 7,
#        'score1': 1,
#        'score2': 0},
#       {'name': 'Edinson Cavani', 'minute': 62, 'score1': 2, 'score2': 1}],
#      'goals2': [{'name': 'Pepe', 'minute': 55, 'score1': 1, 'score2': 1}],
#      'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#      'city': 'Sochi',
#      'timezone': 'UTC+3'},
#     {'num': 50,
#      'date': '2018-06-30',
#      'time': '17:00',
#      'team1': {'name': 'France', 'code': 'FRA'},
#      'team2': {'name': 'Argentina', 'code': 'ARG'},
#      'score1': 4,
#      'score2': 3,
#      'score1i': 1,
#      'score2i': 1,
#      'score1et': None,
#      'score2et': None,
#      'score1p': None,
#      'score2p': None,
#      'knockout': True,
#      'goals1': [{'name': 'Antoine Griezmann',
#        'minute': 13,
#        'score1': 1,
#        'score2': 0,
#        'penalty': True},
#       {'name': 'Benjamin Pavard', 'minute': 57, 'score1': 2, 'score2': 2},
#       {'name': 'Kylian Mbappé', 'minute': 64, 'score1': 3, 'score2': 2},
#       {'name': 'Kylian Mbappé', 'minute': 68, 'score1': 4, 'score2': 2}],
#      'goals2': [{'name': 'Ángel Di María',
#        'minute': 41,
#        'score1': 1,
#        'score2': 1},
#       {'name': 'Gabriel Mercado', 'minute': 48, 'score1': 1, 'score2': 2},
#       {'name': 'Sergio Agüero',
#        'minute': 90,
#        'offset': 3,
#        'score1': 4,
#        'score2': 3}],
#      'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#      'city': 'Kazan',
#      'timezone': 'UTC+3'},
#     {'num': 51,
#      'date': '2018-07-01',
#      'time': '17:00',
#      'team1': {'name': 'Spain', 'code': 'ESP'},
#      'team2': {'name': 'Russia', 'code': 'RUS'},
#      'score1': 1,
#      'score2': 1,
#      'score1i': 1,
#      'score2i': 1,
#      'score1et': 1,
#      'score2et': 1,
#      'score1p': 3,
#      'score2p': 4,
#      'knockout': True,
#      'goals1': [{'name': 'Sergei Ignashevich',
#        'minute': 12,
#        'score1': 1,
#        'score2': 0,
#        'owngoal': True}],
#      'goals2': [{'name': 'Artem Dzyuba',
#        'minute': 41,
#        'score1': 1,
#        'score2': 1,
#        'penalty': True}],
#      'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#      'city': 'Moscow',
#      'timezone': 'UTC+3'},
#     {'num': 52,
#      'date': '2018-07-01',
#      'time': '21:00',
#      'team1': {'name': 'Croatia', 'code': 'CRO'},
#      'team2': {'name': 'Denmark', 'code': 'DEN'},
#      'score1': 1,
#      'score2': 1,
#      'score1i': 1,
#      'score2i': 1,
#      'score1et': 1,
#      'score2et': 1,
#      'score1p': 3,
#      'score2p': 2,
#      'knockout': True,
#      'goals1': [{'name': 'Mario Mandžukić',
#        'minute': 4,
#        'score1': 1,
#        'score2': 1}],
#      'goals2': [{'name': 'Mathias Jørgensen',
#        'minute': 1,
#        'score1': 0,
#        'score2': 1}],
#      'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'},
#      'city': 'Nizhny Novgorod',
#      'timezone': 'UTC+3'},
#     {'num': 53,
#      'date': '2018-07-02',
#      'time': '18:00',
#      'team1': {'name': 'Brazil', 'code': 'BRA'},
#      'team2': {'name': 'Mexico', 'code': 'MEX'},
#      'score1': 2,
#      'score2': 0,
#      'score1i': 0,
#      'score2i': 0,
#      'score1et': None,
#      'score2et': None,
#      'score1p': None,
#      'score2p': None,
#      'knockout': True,
#      'goals1': [{'name': 'Neymar', 'minute': 51, 'score1': 1, 'score2': 0},
#       {'name': 'Roberto Firmino', 'minute': 88, 'score1': 2, 'score2': 0}],
#      'goals2': [],
#      'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#      'city': 'Samara',
#      'timezone': 'UTC+4'},
#     {'num': 54,
#      'date': '2018-07-02',
#      'time': '21:00',
#      'team1': {'name': 'Belgium', 'code': 'BEL'},
#      'team2': {'name': 'Japan', 'code': 'JPN'},
#      'score1': 3,
#      'score2': 2,
#      'score1i': 0,
#      'score2i': 0,
#      'score1et': None,
#      'score2et': None,
#      'score1p': None,
#      'score2p': None,
#      'knockout': True,
#      'goals1': [{'name': 'Jan Vertonghen',
#        'minute': 69,
#        'score1': 1,
#        'score2': 2},
#       {'name': 'Marouane Fellaini', 'minute': 74, 'score1': 2, 'score2': 2},
#       {'name': 'Nacer Chadli',
#        'minute': 90,
#        'offset': 4,
#        'score1': 3,
#        'score2': 2}],
#      'goals2': [{'name': 'Genki Haraguchi',
#        'minute': 48,
#        'score1': 0,
#        'score2': 1},
#       {'name': 'Takashi Inui', 'minute': 52, 'score1': 0, 'score2': 2}],
#      'stadium': {'key': 'rostov', 'name': 'Rostov Arena'},
#      'city': 'Rostov-on-Don',
#      'timezone': 'UTC+3'},
#     {'num': 55,
#      'date': '2018-07-03',
#      'time': '17:00',
#      'team1': {'name': 'Sweden', 'code': 'SWE'},
#      'team2': {'name': 'Switzerland', 'code': 'SUI'},
#      'score1': 1,
#      'score2': 0,
#      'score1i': 0,
#      'score2i': 0,
#      'score1et': None,
#      'score2et': None,
#      'score1p': None,
#      'score2p': None,
#      'knockout': True,
#      'goals1': [{'name': 'Emil Forsberg',
#        'minute': 66,
#        'score1': 1,
#        'score2': 0}],
#      'goals2': [],
#      'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#      'city': 'Saint Petersburg',
#      'timezone': 'UTC+3'},
#     {'num': 56,
#      'date': '2018-07-03',
#      'time': '21:00',
#      'team1': {'name': 'Colombia', 'code': 'COL'},
#      'team2': {'name': 'England', 'code': 'ENG'},
#      'score1': 1,
#      'score2': 1,
#      'score1i': 0,
#      'score2i': 0,
#      'score1et': 1,
#      'score2et': 1,
#      'score1p': 3,
#      'score2p': 4,
#      'knockout': True,
#      'goals1': [{'name': 'Yerry Mina',
#        'minute': 90,
#        'offset': 3,
#        'score1': 1,
#        'score2': 1}],
#      'goals2': [{'name': 'Harry Kane',
#        'minute': 57,
#        'score1': 0,
#        'score2': 1,
#        'penalty': True}],
#      'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'},
#      'city': 'Moscow',
#      'timezone': 'UTC+3'}]},
#   {'name': 'Quarter-finals',
#    'matches': [{'num': 57,
#      'date': '2018-07-06',
#      'time': '17:00',
#      'team1': {'name': 'Uruguay', 'code': 'URU'},
#      'team2': {'name': 'France', 'code': 'FRA'},
#      'score1': 0,
#      'score2': 2,
#      'score1i': 0,
#      'score2i': 1,
#      'score1et': None,
#      'score2et': None,
#      'score1p': None,
#      'score2p': None,
#      'knockout': True,
#      'goals1': [],
#      'goals2': [{'name': 'Raphaël Varane',
#        'minute': 40,
#        'score1': 0,
#        'score2': 1},
#       {'name': 'Antoine Griezmann', 'minute': 61, 'score1': 0, 'score2': 2}],
#      'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'},
#      'city': 'Nizhny Novgorod',
#      'timezone': 'UTC+3'},
#     {'num': 58,
#      'date': '2018-07-06',
#      'time': '21:00',
#      'team1': {'name': 'Brazil', 'code': 'BRA'},
#      'team2': {'name': 'Belgium', 'code': 'BEL'},
#      'score1': 1,
#      'score2': 2,
#      'score1i': 0,
#      'score2i': 2,
#      'score1et': None,
#      'score2et': None,
#      'score1p': None,
#      'score2p': None,
#      'knockout': True,
#      'goals1': [{'name': 'Renato Augusto',
#        'minute': 76,
#        'score1': 1,
#        'score2': 2}],
#      'goals2': [{'name': 'Fernandinho',
#        'minute': 13,
#        'score1': 0,
#        'score2': 1,
#        'owngoal': True},
#       {'name': 'Kevin De Bruyne', 'minute': 31, 'score1': 0, 'score2': 2}],
#      'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#      'city': 'Kazan',
#      'timezone': 'UTC+3'},
#     {'num': 59,
#      'date': '2018-07-07',
#      'time': '21:00',
#      'team1': {'name': 'Russia', 'code': 'RUS'},
#      'team2': {'name': 'Croatia', 'code': 'CRO'},
#      'score1': 1,
#      'score2': 1,
#      'score1i': 1,
#      'score2i': 1,
#      'score1et': 2,
#      'score2et': 2,
#      'score1p': 3,
#      'score2p': 4,
#      'knockout': True,
#      'goals1': [{'name': 'Denis Cheryshev',
#        'minute': 31,
#        'score1': 1,
#        'score2': 0},
#       {'name': 'Mário Figueira Fernandes',
#        'minute': 115,
#        'score1': 2,
#        'score2': 2}],
#      'goals2': [{'name': 'Andrej Kramarić',
#        'minute': 39,
#        'score1': 1,
#        'score2': 1},
#       {'name': 'Domagoj Vida', 'minute': 100, 'score1': 1, 'score2': 2}],
#      'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#      'city': 'Sochi',
#      'timezone': 'UTC+3'},
#     {'num': 60,
#      'date': '2018-07-07',
#      'time': '18:00',
#      'team1': {'name': 'Sweden', 'code': 'SWE'},
#      'team2': {'name': 'England', 'code': 'ENG'},
#      'score1': 0,
#      'score2': 2,
#      'score1i': 0,
#      'score2i': 1,
#      'score1et': None,
#      'score2et': None,
#      'score1p': None,
#      'score2p': None,
#      'knockout': True,
#      'goals1': [],
#      'goals2': [{'name': 'Harry Maguire',
#        'minute': 30,
#        'score1': 0,
#        'score2': 1},
#       {'name': 'Dele Alli', 'minute': 58, 'score1': 0, 'score2': 2}],
#      'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#      'city': 'Samara',
#      'timezone': 'UTC+4'}]},
#   {'name': 'Semi-finals',
#    'matches': [{'num': 61,
#      'date': '2018-07-10',
#      'time': '21:00',
#      'team1': {'name': 'France', 'code': 'FRA'},
#      'team2': {'name': 'Belgium', 'code': 'BEL'},
#      'score1': 1,
#      'score2': 0,
#      'score1i': 0,
#      'score2i': 0,
#      'score1et': None,
#      'score2et': None,
#      'score1p': None,
#      'score2p': None,
#      'knockout': True,
#      'goals1': [{'name': 'Samuel Umtiti',
#        'minute': 51,
#        'score1': 1,
#        'score2': 0}],
#      'goals2': [],
#      'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#      'city': 'Saint Petersburg',
#      'timezone': 'UTC+3'},
#     {'num': 62,
#      'date': '2018-07-11',
#      'time': '21:00',
#      'team1': {'name': 'Croatia', 'code': 'CRO'},
#      'team2': {'name': 'England', 'code': 'ENG'},
#      'score1': 1,
#      'score2': 1,
#      'score1i': 0,
#      'score2i': 1,
#      'score1et': 2,
#      'score2et': 1,
#      'score1p': None,
#      'score2p': None,
#      'knockout': True,
#      'goals1': [{'name': 'Ivan Perišić',
#        'minute': 68,
#        'score1': 1,
#        'score2': 1},
#       {'name': 'Mario Mandžukić', 'minute': 109, 'score1': 2, 'score2': 1}],
#      'goals2': [{'name': 'Kieran Trippier',
#        'minute': 5,
#        'score1': 0,
#        'score2': 1}],
#      'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#      'city': 'Moscow',
#      'timezone': 'UTC+3'}]},
#   {'name': 'Match for third place',
#    'matches': [{'num': 63,
#      'date': '2018-07-14',
#      'time': '17:00',
#      'team1': {'name': 'Belgium', 'code': 'BEL'},
#      'team2': {'name': 'England', 'code': 'ENG'},
#      'score1': 2,
#      'score2': 0,
#      'score1i': 1,
#      'score2i': 0,
#      'score1et': None,
#      'score2et': None,
#      'score1p': None,
#      'score2p': None,
#      'knockout': True,
#      'goals1': [{'name': 'Thomas Meunier',
#        'minute': 4,
#        'score1': 1,
#        'score2': 0},
#       {'name': 'Eden Hazard', 'minute': 82, 'score1': 2, 'score2': 0}],
#      'goals2': [],
#      'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#      'city': 'Saint Petersburg',
#      'timezone': 'UTC+3'}]},
#   {'name': 'Final',
#    'matches': [{'num': 64,
#      'date': '2018-07-15',
#      'time': '18:00',
#      'team1': {'name': 'France', 'code': 'FRA'},
#      'team2': {'name': 'Croatia', 'code': 'CRO'},
#      'score1': 4,
#      'score2': 2,
#      'score1i': 2,
#      'score2i': 1,
#      'score1et': None,
#      'score2et': None,
#      'score1p': None,
#      'score2p': None,
#      'knockout': True,
#      'goals1': [{'name': 'Mario Mandžukić',
#        'minute': 18,
#        'score1': 1,
#        'score2': 0,
#        'owngoal': True},
#       {'name': 'Griezmann',
#        'minute': 38,
#        'score1': 2,
#        'score2': 1,
#        'penalty': True},
#       {'name': 'Pogba', 'minute': 59, 'score1': 3, 'score2': 1},
#       {'name': 'Mbappé', 'minute': 65, 'score1': 4, 'score2': 1}],
#      'goals2': [{'name': 'Perišić', 'minute': 28, 'score1': 1, 'score2': 1},
#       {'name': 'Mario Mandžukić', 'minute': 69, 'score1': 4, 'score2': 2}],
#      'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#      'city': 'Moscow',
#      'timezone': 'UTC+3'}]}]}

# %% [markdown]
# ### Make sure the assert passes, ensuring that world_cup_data has the correct type.

# %%
# Check that the overall data structure is a dictionary
assert type(world_cup_data) == dict

# Check that the dictionary has 2 keys, 'name' and 'rounds'
assert list(world_cup_data.keys()) == ["name", "rounds"]

# %% [markdown]
# ### Population Data
# Now use the csv module to load the data from population_file into a list of dictionaries called population_data
#
# (Recall that you can convert a csv.DictReader object into a list of dictionaries using the built-in list() function.)

# %%
population_data = list(csv.DictReader(population_file))
population_file.close()

# %%
population_data
# Out:
# [{'': '2714',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1960',
#   'Value': '8996973'},
#  {'': '2715',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1961',
#   'Value': '9169410'},
#  {'': '2716',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1962',
#   'Value': '9351441'},
#  {'': '2717',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1963',
#   'Value': '9543205'},
#  {'': '2718',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1964',
#   'Value': '9744781'},
#  {'': '2719',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1965',
#   'Value': '9956320'},
#  {'': '2720',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1966',
#   'Value': '10174836'},
#  {'': '2721',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1967',
#   'Value': '10399926'},
#  {'': '2722',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1968',
#   'Value': '10637063'},
#  {'': '2723',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1969',
#   'Value': '10893776'},
#  {'': '2724',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1970',
#   'Value': '11173642'},
#  {'': '2725',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1971',
#   'Value': '11475445'},
#  {'': '2726',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1972',
#   'Value': '11791215'},
#  {'': '2727',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1973',
#   'Value': '12108963'},
#  {'': '2728',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1974',
#   'Value': '12412950'},
#  {'': '2729',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1975',
#   'Value': '12689160'},
#  {'': '2730',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1976',
#   'Value': '12943093'},
#  {'': '2731',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1977',
#   'Value': '13171306'},
#  {'': '2732',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1978',
#   'Value': '13341198'},
#  {'': '2733',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1979',
#   'Value': '13411056'},
#  {'': '2734',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1980',
#   'Value': '13356511'},
#  {'': '2735',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1981',
#   'Value': '13171673'},
#  {'': '2736',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1982',
#   'Value': '12882528'},
#  {'': '2737',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1983',
#   'Value': '12537730'},
#  {'': '2738',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1984',
#   'Value': '12204292'},
#  {'': '2739',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1985',
#   'Value': '11938208'},
#  {'': '2740',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1986',
#   'Value': '11736179'},
#  {'': '2741',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1987',
#   'Value': '11604534'},
#  {'': '2742',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1988',
#   'Value': '11618005'},
#  {'': '2743',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1989',
#   'Value': '11868877'},
#  {'': '2744',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1990',
#   'Value': '12412308'},
#  {'': '2745',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1991',
#   'Value': '13299017'},
#  {'': '2746',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1992',
#   'Value': '14485546'},
#  {'': '2747',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1993',
#   'Value': '15816603'},
#  {'': '2748',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1994',
#   'Value': '17075727'},
#  {'': '2749',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1995',
#   'Value': '18110657'},
#  {'': '2750',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1996',
#   'Value': '18853437'},
#  {'': '2751',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1997',
#   'Value': '19357126'},
#  {'': '2752',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1998',
#   'Value': '19737765'},
#  {'': '2753',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '1999',
#   'Value': '20170844'},
#  {'': '2754',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2000',
#   'Value': '20779953'},
#  {'': '2755',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2001',
#   'Value': '21606988'},
#  {'': '2756',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2002',
#   'Value': '22600770'},
#  {'': '2757',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2003',
#   'Value': '23680871'},
#  {'': '2758',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2004',
#   'Value': '24726684'},
#  {'': '2759',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2005',
#   'Value': '25654277'},
#  {'': '2760',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2006',
#   'Value': '26433049'},
#  {'': '2761',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2007',
#   'Value': '27100536'},
#  {'': '2762',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2008',
#   'Value': '27722276'},
#  {'': '2763',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2009',
#   'Value': '28394813'},
#  {'': '2764',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2010',
#   'Value': '29185507'},
#  {'': '2765',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2011',
#   'Value': '30117413'},
#  {'': '2766',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2012',
#   'Value': '31161376'},
#  {'': '2767',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2013',
#   'Value': '32269589'},
#  {'': '2768',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2014',
#   'Value': '33370794'},
#  {'': '2769',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2015',
#   'Value': '34413603'},
#  {'': '2770',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2016',
#   'Value': '35383128'},
#  {'': '2771',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2017',
#   'Value': '36296400'},
#  {'': '2772',
#   'Country Name': 'Afghanistan',
#   'Country Code': 'AFG',
#   'Year': '2018',
#   'Value': '37172386'},
#  {'': '2773',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1960',
#   'Value': '1608800'},
#  {'': '2774',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1961',
#   'Value': '1659800'},
#  {'': '2775',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1962',
#   'Value': '1711319'},
#  {'': '2776',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1963',
#   'Value': '1762621'},
#  {'': '2777',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1964',
#   'Value': '1814135'},
#  {'': '2778',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1965',
#   'Value': '1864791'},
#  {'': '2779',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1966',
#   'Value': '1914573'},
#  {'': '2780',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1967',
#   'Value': '1965598'},
#  {'': '2781',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1968',
#   'Value': '2022272'},
#  {'': '2782',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1969',
#   'Value': '2081695'},
#  {'': '2783',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1970',
#   'Value': '2135479'},
#  {'': '2784',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1971',
#   'Value': '2187853'},
#  {'': '2785',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1972',
#   'Value': '2243126'},
#  {'': '2786',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1973',
#   'Value': '2296752'},
#  {'': '2787',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1974',
#   'Value': '2350124'},
#  {'': '2788',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1975',
#   'Value': '2404831'},
#  {'': '2789',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1976',
#   'Value': '2458526'},
#  {'': '2790',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1977',
#   'Value': '2513546'},
#  {'': '2791',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1978',
#   'Value': '2566266'},
#  {'': '2792',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1979',
#   'Value': '2617832'},
#  {'': '2793',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1980',
#   'Value': '2671997'},
#  {'': '2794',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1981',
#   'Value': '2726056'},
#  {'': '2795',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1982',
#   'Value': '2784278'},
#  {'': '2796',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1983',
#   'Value': '2843960'},
#  {'': '2797',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1984',
#   'Value': '2904429'},
#  {'': '2798',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1985',
#   'Value': '2964762'},
#  {'': '2799',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1986',
#   'Value': '3022635'},
#  {'': '2800',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1987',
#   'Value': '3083605'},
#  {'': '2801',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1988',
#   'Value': '3142336'},
#  {'': '2802',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1989',
#   'Value': '3227943'},
#  {'': '2803',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1990',
#   'Value': '3286542'},
#  {'': '2804',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1991',
#   'Value': '3266790'},
#  {'': '2805',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1992',
#   'Value': '3247039'},
#  {'': '2806',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1993',
#   'Value': '3227287'},
#  {'': '2807',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1994',
#   'Value': '3207536'},
#  {'': '2808',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1995',
#   'Value': '3187784'},
#  {'': '2809',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1996',
#   'Value': '3168033'},
#  {'': '2810',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1997',
#   'Value': '3148281'},
#  {'': '2811',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1998',
#   'Value': '3128530'},
#  {'': '2812',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '1999',
#   'Value': '3108778'},
#  {'': '2813',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2000',
#   'Value': '3089027'},
#  {'': '2814',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2001',
#   'Value': '3060173'},
#  {'': '2815',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2002',
#   'Value': '3051010'},
#  {'': '2816',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2003',
#   'Value': '3039616'},
#  {'': '2817',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2004',
#   'Value': '3026939'},
#  {'': '2818',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2005',
#   'Value': '3011487'},
#  {'': '2819',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2006',
#   'Value': '2992547'},
#  {'': '2820',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2007',
#   'Value': '2970017'},
#  {'': '2821',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2008',
#   'Value': '2947314'},
#  {'': '2822',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2009',
#   'Value': '2927519'},
#  {'': '2823',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2010',
#   'Value': '2913021'},
#  {'': '2824',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2011',
#   'Value': '2905195'},
#  {'': '2825',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2012',
#   'Value': '2900401'},
#  {'': '2826',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2013',
#   'Value': '2895092'},
#  {'': '2827',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2014',
#   'Value': '2889104'},
#  {'': '2828',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2015',
#   'Value': '2880703'},
#  {'': '2829',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2016',
#   'Value': '2876101'},
#  {'': '2830',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2017',
#   'Value': '2873457'},
#  {'': '2831',
#   'Country Name': 'Albania',
#   'Country Code': 'ALB',
#   'Year': '2018',
#   'Value': '2866376'},
#  {'': '2832',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1960',
#   'Value': '11057863'},
#  {'': '2833',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1961',
#   'Value': '11336339'},
#  {'': '2834',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1962',
#   'Value': '11619828'},
#  {'': '2835',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1963',
#   'Value': '11912803'},
#  {'': '2836',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1964',
#   'Value': '12221675'},
#  {'': '2837',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1965',
#   'Value': '12550885'},
#  {'': '2838',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1966',
#   'Value': '12902627'},
#  {'': '2839',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1967',
#   'Value': '13275026'},
#  {'': '2840',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1968',
#   'Value': '13663583'},
#  {'': '2841',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1969',
#   'Value': '14061722'},
#  {'': '2842',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1970',
#   'Value': '14464985'},
#  {'': '2843',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1971',
#   'Value': '14872250'},
#  {'': '2844',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1972',
#   'Value': '15285990'},
#  {'': '2845',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1973',
#   'Value': '15709825'},
#  {'': '2846',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1974',
#   'Value': '16149025'},
#  {'': '2847',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1975',
#   'Value': '16607707'},
#  {'': '2848',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1976',
#   'Value': '17085801'},
#  {'': '2849',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1977',
#   'Value': '17582904'},
#  {'': '2850',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1978',
#   'Value': '18102266'},
#  {'': '2851',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1979',
#   'Value': '18647815'},
#  {'': '2852',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1980',
#   'Value': '19221665'},
#  {'': '2853',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1981',
#   'Value': '19824301'},
#  {'': '2854',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1982',
#   'Value': '20452902'},
#  {'': '2855',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1983',
#   'Value': '21101875'},
#  {'': '2856',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1984',
#   'Value': '21763575'},
#  {'': '2857',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1985',
#   'Value': '22431502'},
#  {'': '2858',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1986',
#   'Value': '23102389'},
#  {'': '2859',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1987',
#   'Value': '23774284'},
#  {'': '2860',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1988',
#   'Value': '24443467'},
#  {'': '2861',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1989',
#   'Value': '25106190'},
#  {'': '2862',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1990',
#   'Value': '25758869'},
#  {'': '2863',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1991',
#   'Value': '26400479'},
#  {'': '2864',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1992',
#   'Value': '27028326'},
#  {'': '2865',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1993',
#   'Value': '27635515'},
#  {'': '2866',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1994',
#   'Value': '28213774'},
#  {'': '2867',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1995',
#   'Value': '28757785'},
#  {'': '2868',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1996',
#   'Value': '29266405'},
#  {'': '2869',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1997',
#   'Value': '29742979'},
#  {'': '2870',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1998',
#   'Value': '30192754'},
#  {'': '2871',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '1999',
#   'Value': '30623406'},
#  {'': '2872',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2000',
#   'Value': '31042235'},
#  {'': '2873',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2001',
#   'Value': '31451514'},
#  {'': '2874',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2002',
#   'Value': '31855109'},
#  {'': '2875',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2003',
#   'Value': '32264157'},
#  {'': '2876',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2004',
#   'Value': '32692163'},
#  {'': '2877',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2005',
#   'Value': '33149724'},
#  {'': '2878',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2006',
#   'Value': '33641002'},
#  {'': '2879',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2007',
#   'Value': '34166972'},
#  {'': '2880',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2008',
#   'Value': '34730608'},
#  {'': '2881',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2009',
#   'Value': '35333881'},
#  {'': '2882',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2010',
#   'Value': '35977455'},
#  {'': '2883',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2011',
#   'Value': '36661444'},
#  {'': '2884',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2012',
#   'Value': '37383887'},
#  {'': '2885',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2013',
#   'Value': '38140132'},
#  {'': '2886',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2014',
#   'Value': '38923687'},
#  {'': '2887',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2015',
#   'Value': '39728025'},
#  {'': '2888',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2016',
#   'Value': '40551404'},
#  {'': '2889',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2017',
#   'Value': '41389198'},
#  {'': '2890',
#   'Country Name': 'Algeria',
#   'Country Code': 'DZA',
#   'Year': '2018',
#   'Value': '42228429'},
#  {'': '2891',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1960',
#   'Value': '20123'},
#  {'': '2892',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1961',
#   'Value': '20602'},
#  {'': '2893',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1962',
#   'Value': '21253'},
#  {'': '2894',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1963',
#   'Value': '22034'},
#  {'': '2895',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1964',
#   'Value': '22854'},
#  {'': '2896',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1965',
#   'Value': '23672'},
#  {'': '2897',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1966',
#   'Value': '24462'},
#  {'': '2898',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1967',
#   'Value': '25248'},
#  {'': '2899',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1968',
#   'Value': '25989'},
#  {'': '2900',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1969',
#   'Value': '26703'},
#  {'': '2901',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1970',
#   'Value': '27363'},
#  {'': '2902',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1971',
#   'Value': '27984'},
#  {'': '2903',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1972',
#   'Value': '28567'},
#  {'': '2904',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1973',
#   'Value': '29100'},
#  {'': '2905',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1974',
#   'Value': '29596'},
#  {'': '2906',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1975',
#   'Value': '30052'},
#  {'': '2907',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1976',
#   'Value': '30456'},
#  {'': '2908',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1977',
#   'Value': '30838'},
#  {'': '2909',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1978',
#   'Value': '31269'},
#  {'': '2910',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1979',
#   'Value': '31845'},
#  {'': '2911',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1980',
#   'Value': '32646'},
#  {'': '2912',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1981',
#   'Value': '33701'},
#  {'': '2913',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1982',
#   'Value': '34968'},
#  {'': '2914',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1983',
#   'Value': '36412'},
#  {'': '2915',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1984',
#   'Value': '37946'},
#  {'': '2916',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1985',
#   'Value': '39519'},
#  {'': '2917',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1986',
#   'Value': '41119'},
#  {'': '2918',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1987',
#   'Value': '42740'},
#  {'': '2919',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1988',
#   'Value': '44343'},
#  {'': '2920',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1989',
#   'Value': '45894'},
#  {'': '2921',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1990',
#   'Value': '47347'},
#  {'': '2922',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1991',
#   'Value': '48685'},
#  {'': '2923',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1992',
#   'Value': '49896'},
#  {'': '2924',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1993',
#   'Value': '51020'},
#  {'': '2925',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1994',
#   'Value': '52095'},
#  {'': '2926',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1995',
#   'Value': '53161'},
#  {'': '2927',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1996',
#   'Value': '54211'},
#  {'': '2928',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1997',
#   'Value': '55221'},
#  {'': '2929',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1998',
#   'Value': '56171'},
#  {'': '2930',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '1999',
#   'Value': '57053'},
#  {'': '2931',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2000',
#   'Value': '57821'},
#  {'': '2932',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2001',
#   'Value': '58494'},
#  {'': '2933',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2002',
#   'Value': '59080'},
#  {'': '2934',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2003',
#   'Value': '59504'},
#  {'': '2935',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2004',
#   'Value': '59681'},
#  {'': '2936',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2005',
#   'Value': '59562'},
#  {'': '2937',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2006',
#   'Value': '59107'},
#  {'': '2938',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2007',
#   'Value': '58365'},
#  {'': '2939',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2008',
#   'Value': '57492'},
#  {'': '2940',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2009',
#   'Value': '56683'},
#  {'': '2941',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2010',
#   'Value': '56079'},
#  {'': '2942',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2011',
#   'Value': '55759'},
#  {'': '2943',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2012',
#   'Value': '55667'},
#  {'': '2944',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2013',
#   'Value': '55713'},
#  {'': '2945',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2014',
#   'Value': '55791'},
#  {'': '2946',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2015',
#   'Value': '55812'},
#  {'': '2947',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2016',
#   'Value': '55741'},
#  {'': '2948',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2017',
#   'Value': '55620'},
#  {'': '2949',
#   'Country Name': 'American Samoa',
#   'Country Code': 'ASM',
#   'Year': '2018',
#   'Value': '55465'},
#  {'': '2950',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1960',
#   'Value': '13411'},
#  {'': '2951',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1961',
#   'Value': '14375'},
#  {'': '2952',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1962',
#   'Value': '15370'},
#  {'': '2953',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1963',
#   'Value': '16412'},
#  {'': '2954',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1964',
#   'Value': '17469'},
#  {'': '2955',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1965',
#   'Value': '18549'},
#  {'': '2956',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1966',
#   'Value': '19647'},
#  {'': '2957',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1967',
#   'Value': '20758'},
#  {'': '2958',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1968',
#   'Value': '21890'},
#  {'': '2959',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1969',
#   'Value': '23058'},
#  {'': '2960',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1970',
#   'Value': '24276'},
#  {'': '2961',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1971',
#   'Value': '25559'},
#  {'': '2962',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1972',
#   'Value': '26892'},
#  {'': '2963',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1973',
#   'Value': '28232'},
#  {'': '2964',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1974',
#   'Value': '29520'},
#  {'': '2965',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1975',
#   'Value': '30705'},
#  {'': '2966',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1976',
#   'Value': '31777'},
#  {'': '2967',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1977',
#   'Value': '32771'},
#  {'': '2968',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1978',
#   'Value': '33737'},
#  {'': '2969',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1979',
#   'Value': '34818'},
#  {'': '2970',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1980',
#   'Value': '36067'},
#  {'': '2971',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1981',
#   'Value': '37500'},
#  {'': '2972',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1982',
#   'Value': '39114'},
#  {'': '2973',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1983',
#   'Value': '40867'},
#  {'': '2974',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1984',
#   'Value': '42706'},
#  {'': '2975',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1985',
#   'Value': '44600'},
#  {'': '2976',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1986',
#   'Value': '46517'},
#  {'': '2977',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1987',
#   'Value': '48455'},
#  {'': '2978',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1988',
#   'Value': '50434'},
#  {'': '2979',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1989',
#   'Value': '52448'},
#  {'': '2980',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1990',
#   'Value': '54509'},
#  {'': '2981',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1991',
#   'Value': '56671'},
#  {'': '2982',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1992',
#   'Value': '58888'},
#  {'': '2983',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1993',
#   'Value': '60971'},
#  {'': '2984',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1994',
#   'Value': '62677'},
#  {'': '2985',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1995',
#   'Value': '63850'},
#  {'': '2986',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1996',
#   'Value': '64360'},
#  {'': '2987',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1997',
#   'Value': '64327'},
#  {'': '2988',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1998',
#   'Value': '64142'},
#  {'': '2989',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '1999',
#   'Value': '64370'},
#  {'': '2990',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2000',
#   'Value': '65390'},
#  {'': '2991',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2001',
#   'Value': '67341'},
#  {'': '2992',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2002',
#   'Value': '70049'},
#  {'': '2993',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2003',
#   'Value': '73182'},
#  {'': '2994',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2004',
#   'Value': '76244'},
#  {'': '2995',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2005',
#   'Value': '78867'},
#  {'': '2996',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2006',
#   'Value': '80993'},
#  {'': '2997',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2007',
#   'Value': '82684'},
#  {'': '2998',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2008',
#   'Value': '83862'},
#  {'': '2999',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2009',
#   'Value': '84463'},
#  {'': '3000',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2010',
#   'Value': '84449'},
#  {'': '3001',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2011',
#   'Value': '83747'},
#  {'': '3002',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2012',
#   'Value': '82427'},
#  {'': '3003',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2013',
#   'Value': '80774'},
#  {'': '3004',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2014',
#   'Value': '79213'},
#  {'': '3005',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2015',
#   'Value': '78011'},
#  {'': '3006',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2016',
#   'Value': '77297'},
#  {'': '3007',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2017',
#   'Value': '77001'},
#  {'': '3008',
#   'Country Name': 'Andorra',
#   'Country Code': 'AND',
#   'Year': '2018',
#   'Value': '77006'},
#  {'': '3009',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1960',
#   'Value': '5454933'},
#  {'': '3010',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1961',
#   'Value': '5531472'},
#  {'': '3011',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1962',
#   'Value': '5608539'},
#  {'': '3012',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1963',
#   'Value': '5679458'},
#  {'': '3013',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1964',
#   'Value': '5735044'},
#  {'': '3014',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1965',
#   'Value': '5770570'},
#  {'': '3015',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1966',
#   'Value': '5781214'},
#  {'': '3016',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1967',
#   'Value': '5774243'},
#  {'': '3017',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1968',
#   'Value': '5771652'},
#  {'': '3018',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1969',
#   'Value': '5803254'},
#  {'': '3019',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1970',
#   'Value': '5890365'},
#  {'': '3020',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1971',
#   'Value': '6040777'},
#  {'': '3021',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1972',
#   'Value': '6248552'},
#  {'': '3022',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1973',
#   'Value': '6496962'},
#  {'': '3023',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1974',
#   'Value': '6761380'},
#  {'': '3024',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1975',
#   'Value': '7024000'},
#  {'': '3025',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1976',
#   'Value': '7279509'},
#  {'': '3026',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1977',
#   'Value': '7533735'},
#  {'': '3027',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1978',
#   'Value': '7790707'},
#  {'': '3028',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1979',
#   'Value': '8058067'},
#  {'': '3029',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1980',
#   'Value': '8341289'},
#  {'': '3030',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1981',
#   'Value': '8640446'},
#  {'': '3031',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1982',
#   'Value': '8952950'},
#  {'': '3032',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1983',
#   'Value': '9278096'},
#  {'': '3033',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1984',
#   'Value': '9614754'},
#  {'': '3034',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1985',
#   'Value': '9961997'},
#  {'': '3035',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1986',
#   'Value': '10320111'},
#  {'': '3036',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1987',
#   'Value': '10689250'},
#  {'': '3037',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1988',
#   'Value': '11068050'},
#  {'': '3038',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1989',
#   'Value': '11454777'},
#  {'': '3039',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1990',
#   'Value': '11848386'},
#  {'': '3040',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1991',
#   'Value': '12248901'},
#  {'': '3041',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1992',
#   'Value': '12657366'},
#  {'': '3042',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1993',
#   'Value': '13075049'},
#  {'': '3043',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1994',
#   'Value': '13503747'},
#  {'': '3044',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1995',
#   'Value': '13945206'},
#  {'': '3045',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1996',
#   'Value': '14400719'},
#  {'': '3046',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1997',
#   'Value': '14871570'},
#  {'': '3047',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1998',
#   'Value': '15359601'},
#  {'': '3048',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '1999',
#   'Value': '15866869'},
#  {'': '3049',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2000',
#   'Value': '16395473'},
#  {'': '3050',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2001',
#   'Value': '16945753'},
#  {'': '3051',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2002',
#   'Value': '17519417'},
#  {'': '3052',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2003',
#   'Value': '18121479'},
#  {'': '3053',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2004',
#   'Value': '18758145'},
#  {'': '3054',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2005',
#   'Value': '19433602'},
#  {'': '3055',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2006',
#   'Value': '20149901'},
#  {'': '3056',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2007',
#   'Value': '20905363'},
#  {'': '3057',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2008',
#   'Value': '21695634'},
#  {'': '3058',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2009',
#   'Value': '22514281'},
#  {'': '3059',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2010',
#   'Value': '23356246'},
#  {'': '3060',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2011',
#   'Value': '24220661'},
#  {'': '3061',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2012',
#   'Value': '25107931'},
#  {'': '3062',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2013',
#   'Value': '26015780'},
#  {'': '3063',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2014',
#   'Value': '26941779'},
#  {'': '3064',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2015',
#   'Value': '27884381'},
#  {'': '3065',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2016',
#   'Value': '28842484'},
#  {'': '3066',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2017',
#   'Value': '29816748'},
#  {'': '3067',
#   'Country Name': 'Angola',
#   'Country Code': 'AGO',
#   'Year': '2018',
#   'Value': '30809762'},
#  {'': '3068',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1960',
#   'Value': '54131'},
#  {'': '3069',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1961',
#   'Value': '55001'},
#  {'': '3070',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1962',
#   'Value': '55841'},
#  {'': '3071',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1963',
#   'Value': '56702'},
#  {'': '3072',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1964',
#   'Value': '57641'},
#  {'': '3073',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1965',
#   'Value': '58698'},
#  {'': '3074',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1966',
#   'Value': '59915'},
#  {'': '3075',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1967',
#   'Value': '61241'},
#  {'': '3076',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1968',
#   'Value': '62521'},
#  {'': '3077',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1969',
#   'Value': '63550'},
#  {'': '3078',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1970',
#   'Value': '64177'},
#  {'': '3079',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1971',
#   'Value': '64357'},
#  {'': '3080',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1972',
#   'Value': '64133'},
#  {'': '3081',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1973',
#   'Value': '63650'},
#  {'': '3082',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1974',
#   'Value': '63120'},
#  {'': '3083',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1975',
#   'Value': '62675'},
#  {'': '3084',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1976',
#   'Value': '62367'},
#  {'': '3085',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1977',
#   'Value': '62159'},
#  {'': '3086',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1978',
#   'Value': '62036'},
#  {'': '3087',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1979',
#   'Value': '61952'},
#  {'': '3088',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1980',
#   'Value': '61865'},
#  {'': '3089',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1981',
#   'Value': '61800'},
#  {'': '3090',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1982',
#   'Value': '61779'},
#  {'': '3091',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1983',
#   'Value': '61787'},
#  {'': '3092',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1984',
#   'Value': '61786'},
#  {'': '3093',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1985',
#   'Value': '61786'},
#  {'': '3094',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1986',
#   'Value': '61754'},
#  {'': '3095',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1987',
#   'Value': '61717'},
#  {'': '3096',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1988',
#   'Value': '61771'},
#  {'': '3097',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1989',
#   'Value': '62008'},
#  {'': '3098',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1990',
#   'Value': '62528'},
#  {'': '3099',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1991',
#   'Value': '63367'},
#  {'': '3100',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1992',
#   'Value': '64471'},
#  {'': '3101',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1993',
#   'Value': '65777'},
#  {'': '3102',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1994',
#   'Value': '67204'},
#  {'': '3103',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1995',
#   'Value': '68670'},
#  {'': '3104',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1996',
#   'Value': '70173'},
#  {'': '3105',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1997',
#   'Value': '71704'},
#  {'': '3106',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1998',
#   'Value': '73224'},
#  {'': '3107',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '1999',
#   'Value': '74674'},
#  {'': '3108',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2000',
#   'Value': '76016'},
#  {'': '3109',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2001',
#   'Value': '77212'},
#  {'': '3110',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2002',
#   'Value': '78295'},
#  {'': '3111',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2003',
#   'Value': '79300'},
#  {'': '3112',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2004',
#   'Value': '80336'},
#  {'': '3113',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2005',
#   'Value': '81465'},
#  {'': '3114',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2006',
#   'Value': '82704'},
#  {'': '3115',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2007',
#   'Value': '84026'},
#  {'': '3116',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2008',
#   'Value': '85397'},
#  {'': '3117',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2009',
#   'Value': '86746'},
#  {'': '3118',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2010',
#   'Value': '88028'},
#  {'': '3119',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2011',
#   'Value': '89253'},
#  {'': '3120',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2012',
#   'Value': '90409'},
#  {'': '3121',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2013',
#   'Value': '91516'},
#  {'': '3122',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2014',
#   'Value': '92562'},
#  {'': '3123',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2015',
#   'Value': '93566'},
#  {'': '3124',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2016',
#   'Value': '94527'},
#  {'': '3125',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2017',
#   'Value': '95426'},
#  {'': '3126',
#   'Country Name': 'Antigua and Barbuda',
#   'Country Code': 'ATG',
#   'Year': '2018',
#   'Value': '96286'},
#  {'': '3127',
#   'Country Name': 'Argentina',
#   'Country Code': 'ARG',
#   'Year': '1960',
#   'Value': '20481779'},
#  {'': '3128',
#   'Country Name': 'Argentina',
#   'Country Code': 'ARG',
#   'Year': '1961',
#   'Value': '20817266'},
#  {'': '3129',
#   'Country Name': 'Argentina',
#   'Country Code': 'ARG',
#   'Year': '1962',
#   'Value': '21153052'},
#  {'': '3130',
#   'Country Name': 'Argentina',
#   'Country Code': 'ARG',
#   'Year': '1963',
#   'Value': '21488912'},
#  {'': '3131',
#   'Country Name': 'Argentina',
#   'Country Code': 'ARG',
#   'Year': '1964',
#   'Value': '21824425'},
#  {'': '3132',
#   'Country Name': 'Argentina',
#   'Country Code': 'ARG',
#   'Year': '1965',
#   'Value': '22159650'},
#  {'': '3133',
#   'Country Name': 'Argentina',
#   'Country Code': 'ARG',
#   'Year': '1966',
#   'Value': '22494035'},
#  {'': '3134',
#   'Country Name': 'Argentina',
#   'Country Code': 'ARG',
#   'Year': '1967',
#   'Value': '22828869'},
#  {'': '3135',
#   'Country Name': 'Argentina',
#   'Country Code': 'ARG',
#   'Year': '1968',
#   'Value': '23168267'},
#  {'': '3136',
#   'Country Name': 'Argentina',
#   'Country Code': 'ARG',
#   'Year': '1969',
#   'Value': '23517611'},
#  {'': '3137',
#   'Country Name': 'Argentina',
#   'Country Code': 'ARG',
#   'Year': '1970',
#   'Value': '23880561'},
#  {'': '3138',
#   'Country Name': 'Argentina',
#   'Country Code': 'ARG',
#   'Year': '1971',
#   'Value': '24259561'},
#  {'': '3139',
#   'Country Name': 'Argentina',
#   'Country Code': 'ARG',
#   'Year': '1972',
#   'Value': '24653175'},
#  {'': '3140',
#   'Country Name': 'Argentina',
#   'Country Code': 'ARG',
#   'Year': '1973',
#   'Value': '25056478'},
#  {'': '3141',
#   'Country Name': 'Argentina',
#   'Country Code': 'ARG',
#   'Year': '1974',
#   'Value': '25462302'},
#  {'': '3142',
#   'Country Name': 'Argentina',
#   'Country Code': 'ARG',
#   'Year': '1975',
#   'Value': '25865776'},
#  {'': '3143',
#   'Country Name': 'Argentina',
#   'Country Code': 'ARG',
#   'Year': '1976',
# ...
#   'Year': '1989',
#   'Value': '481087'},
#  {'': '3570',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '1990',
#   'Value': '495931'},
#  {'': '3571',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '1991',
#   'Value': '509760'},
#  {'': '3572',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '1992',
#   'Value': '523086'},
#  {'': '3573',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '1993',
#   'Value': '536210'},
#  {'': '3574',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '1994',
#   'Value': '549583'},
#  {'': '3575',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '1995',
#   'Value': '563697'},
#  {'': '3576',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '1996',
#   'Value': '578666'},
#  {'': '3577',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '1997',
#   'Value': '594931'},
#  {'': '3578',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '1998',
#   'Value': '613700'},
#  {'': '3579',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '1999',
#   'Value': '636541'},
#  {'': '3580',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2000',
#   'Value': '664611'},
#  {'': '3581',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2001',
#   'Value': '697545'},
#  {'': '3582',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2002',
#   'Value': '735146'},
#  {'': '3583',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2003',
#   'Value': '778708'},
#  {'': '3584',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2004',
#   'Value': '829844'},
#  {'': '3585',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2005',
#   'Value': '889164'},
#  {'': '3586',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2006',
#   'Value': '958418'},
#  {'': '3587',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2007',
#   'Value': '1035919'},
#  {'': '3588',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2008',
#   'Value': '1114641'},
#  {'': '3589',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2009',
#   'Value': '1185076'},
#  {'': '3590',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2010',
#   'Value': '1240860'},
#  {'': '3591',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2011',
#   'Value': '1278151'},
#  {'': '3592',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2012',
#   'Value': '1299943'},
#  {'': '3593',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2013',
#   'Value': '1315029'},
#  {'': '3594',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2014',
#   'Value': '1336075'},
#  {'': '3595',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2015',
#   'Value': '1371851'},
#  {'': '3596',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2016',
#   'Value': '1425791'},
#  {'': '3597',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2017',
#   'Value': '1494074'},
#  {'': '3598',
#   'Country Name': 'Bahrain',
#   'Country Code': 'BHR',
#   'Year': '2018',
#   'Value': '1569439'},
#  {'': '3599',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1960',
#   'Value': '48013504'},
#  {'': '3600',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1961',
#   'Value': '49362843'},
#  {'': '3601',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1962',
#   'Value': '50752157'},
#  {'': '3602',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1963',
#   'Value': '52202007'},
#  {'': '3603',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1964',
#   'Value': '53741716'},
#  {'': '3604',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1965',
#   'Value': '55385112'},
#  {'': '3605',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1966',
#   'Value': '57157654'},
#  {'': '3606',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1967',
#   'Value': '59034249'},
#  {'': '3607',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1968',
#   'Value': '60918454'},
#  {'': '3608',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1969',
#   'Value': '62679765'},
#  {'': '3609',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1970',
#   'Value': '64232482'},
#  {'': '3610',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1971',
#   'Value': '65531633'},
#  {'': '3611',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1972',
#   'Value': '66625705'},
#  {'': '3612',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1973',
#   'Value': '67637530'},
#  {'': '3613',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1974',
#   'Value': '68742233'},
#  {'': '3614',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1975',
#   'Value': '70066301'},
#  {'': '3615',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1976',
#   'Value': '71652381'},
#  {'': '3616',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1977',
#   'Value': '73463584'},
#  {'': '3617',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1978',
#   'Value': '75450032'},
#  {'': '3618',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1979',
#   'Value': '77529045'},
#  {'': '3619',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1980',
#   'Value': '79639491'},
#  {'': '3620',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1981',
#   'Value': '81767515'},
#  {'': '3621',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1982',
#   'Value': '83932127'},
#  {'': '3622',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1983',
#   'Value': '86142495'},
#  {'': '3623',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1984',
#   'Value': '88416521'},
#  {'': '3624',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1985',
#   'Value': '90764183'},
#  {'': '3625',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1986',
#   'Value': '93187603'},
#  {'': '3626',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1987',
#   'Value': '95671163'},
#  {'': '3627',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1988',
#   'Value': '98186350'},
#  {'': '3628',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1989',
#   'Value': '100695497'},
#  {'': '3629',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1990',
#   'Value': '103171956'},
#  {'': '3630',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1991',
#   'Value': '105599127'},
#  {'': '3631',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1992',
#   'Value': '107983704'},
#  {'': '3632',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1993',
#   'Value': '110350639'},
#  {'': '3633',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1994',
#   'Value': '112737683'},
#  {'': '3634',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1995',
#   'Value': '115169930'},
#  {'': '3635',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1996',
#   'Value': '117649932'},
#  {'': '3636',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1997',
#   'Value': '120160564'},
#  {'': '3637',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1998',
#   'Value': '122682815'},
#  {'': '3638',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '1999',
#   'Value': '125189651'},
#  {'': '3639',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2000',
#   'Value': '127657854'},
#  {'': '3640',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2001',
#   'Value': '130088702'},
#  {'': '3641',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2002',
#   'Value': '132478086'},
#  {'': '3642',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2003',
#   'Value': '134791603'},
#  {'': '3643',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2004',
#   'Value': '136986432'},
#  {'': '3644',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2005',
#   'Value': '139035505'},
#  {'': '3645',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2006',
#   'Value': '140921167'},
#  {'': '3646',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2007',
#   'Value': '142660376'},
#  {'': '3647',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2008',
#   'Value': '144304167'},
#  {'': '3648',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2009',
#   'Value': '145924797'},
#  {'': '3649',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2010',
#   'Value': '147575430'},
#  {'': '3650',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2011',
#   'Value': '149273778'},
#  {'': '3651',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2012',
#   'Value': '151007807'},
#  {'': '3652',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2013',
#   'Value': '152764676'},
#  {'': '3653',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2014',
#   'Value': '154520167'},
#  {'': '3654',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2015',
#   'Value': '156256276'},
#  {'': '3655',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2016',
#   'Value': '157970840'},
#  {'': '3656',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2017',
#   'Value': '159670593'},
#  {'': '3657',
#   'Country Name': 'Bangladesh',
#   'Country Code': 'BGD',
#   'Year': '2018',
#   'Value': '161356039'},
#  {'': '3658',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1960',
#   'Value': '230980'},
#  {'': '3659',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1961',
#   'Value': '231718'},
#  {'': '3660',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1962',
#   'Value': '232633'},
#  {'': '3661',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1963',
#   'Value': '233630'},
#  {'': '3662',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1964',
#   'Value': '234586'},
#  {'': '3663',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1965',
#   'Value': '235413'},
#  {'': '3664',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1966',
#   'Value': '236088'},
#  {'': '3665',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1967',
#   'Value': '236659'},
#  {'': '3666',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1968',
#   'Value': '237241'},
#  {'': '3667',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1969',
#   'Value': '237955'},
#  {'': '3668',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1970',
#   'Value': '238896'},
#  {'': '3669',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1971',
#   'Value': '240094'},
#  {'': '3670',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1972',
#   'Value': '241515'},
#  {'': '3671',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1973',
#   'Value': '243069'},
#  {'': '3672',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1974',
#   'Value': '244644'},
#  {'': '3673',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1975',
#   'Value': '246154'},
#  {'': '3674',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1976',
#   'Value': '247583'},
#  {'': '3675',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1977',
#   'Value': '248937'},
#  {'': '3676',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1978',
#   'Value': '250203'},
#  {'': '3677',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1979',
#   'Value': '251351'},
#  {'': '3678',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1980',
#   'Value': '252394'},
#  {'': '3679',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1981',
#   'Value': '253298'},
#  {'': '3680',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1982',
#   'Value': '254082'},
#  {'': '3681',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1983',
#   'Value': '254788'},
#  {'': '3682',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1984',
#   'Value': '255497'},
#  {'': '3683',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1985',
#   'Value': '256263'},
#  {'': '3684',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1986',
#   'Value': '257107'},
#  {'': '3685',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1987',
#   'Value': '258019'},
#  {'': '3686',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1988',
#   'Value': '258977'},
#  {'': '3687',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1989',
#   'Value': '259957'},
#  {'': '3688',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1990',
#   'Value': '260936'},
#  {'': '3689',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1991',
#   'Value': '261905'},
#  {'': '3690',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1992',
#   'Value': '262886'},
#  {'': '3691',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1993',
#   'Value': '263874'},
#  {'': '3692',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1994',
#   'Value': '264893'},
#  {'': '3693',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1995',
#   'Value': '265955'},
#  {'': '3694',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1996',
#   'Value': '267049'},
#  {'': '3695',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1997',
#   'Value': '268187'},
#  {'': '3696',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1998',
#   'Value': '269336'},
#  {'': '3697',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '1999',
#   'Value': '270451'},
#  {'': '3698',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '2000',
#   'Value': '271515'},
#  {'': '3699',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '2001',
#   'Value': '272500'},
#  {'': '3700',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '2002',
#   'Value': '273425'},
#  {'': '3701',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '2003',
#   'Value': '274329'},
#  {'': '3702',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '2004',
#   'Value': '275284'},
#  {'': '3703',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '2005',
#   'Value': '276323'},
#  {'': '3704',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '2006',
#   'Value': '277477'},
#  {'': '3705',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '2007',
#   'Value': '278700'},
#  {'': '3706',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '2008',
#   'Value': '279946'},
#  {'': '3707',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '2009',
#   'Value': '281104'},
#  {'': '3708',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '2010',
#   'Value': '282131'},
#  {'': '3709',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '2011',
#   'Value': '282987'},
#  {'': '3710',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '2012',
#   'Value': '283700'},
#  {'': '3711',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '2013',
#   'Value': '284296'},
#  {'': '3712',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '2014',
#   'Value': '284825'},
#  {'': '3713',
#   'Country Name': 'Barbados',
#   'Country Code': 'BRB',
#   'Year': '2015',
#   'Value': '285324'},
#  ...]

# %% [markdown]
# ### Make sure the asserts pass, ensuring that population_data has the correct type.

# %%
# Run this cell without changes

# Check that the overall data structure is a list
assert type(population_data) == list

# Check that the 0th element is a dictionary
# (csv.DictReader interface differs slightly by Python version;
# either a dict or an OrderedDict is fine here)
from collections import OrderedDict

assert type(population_data[0]) == dict or type(population_data[0]) == OrderedDict

# %% [markdown]
# ### 1. List of Teams in 2018 World Cup
# Create an alphabetically-sorted list of teams who competed in the 2018 FIFA World Cup.
#
# This will take several steps, some of which have been completed for you.

# %%
type(world_cup_data)
# Out:
# dict

# %%
world_cup_data.keys()
# Out:
# dict_keys(['name', 'rounds'])

# %%
world_cup_data['name']
# Out:
# 'World Cup 2018'

# %% [markdown]
# ### Extracting Rounds
# The value associated with the 'rounds' key is a list containing all of the actual information about the rounds and the matches within those rounds.

# %%
rounds = world_cup_data["rounds"]

print("type(rounds):", type(rounds))
print("len(rounds):", len(rounds))
print("type(rounds[3])", type(rounds[3]))
print("rounds[3]:")
rounds[3]
# Out:
# type(rounds): <class 'list'>
# len(rounds): 20
# type(rounds[3]) <class 'dict'>
# rounds[3]:
# {'name': 'Matchday 4',
#  'matches': [{'num': 9,
#    'date': '2018-06-17',
#    'time': '21:00',
#    'team1': {'name': 'Brazil', 'code': 'BRA'},
#    'team2': {'name': 'Switzerland', 'code': 'SUI'},
#    'score1': 1,
#    'score2': 1,
#    'score1i': 1,
#    'score2i': 0,
#    'goals1': [{'name': 'Coutinho', 'minute': 20, 'score1': 1, 'score2': 0}],
#    'goals2': [{'name': 'Zuber', 'minute': 50, 'score1': 1, 'score2': 1}],
#    'group': 'Group E',
#    'stadium': {'key': 'rostov', 'name': 'Rostov Arena'},
#    'city': 'Rostov-on-Don',
#    'timezone': 'UTC+3'},
#   {'num': 10,
#    'date': '2018-06-17',
#    'time': '16:00',
#    'team1': {'name': 'Costa Rica', 'code': 'CRC'},
#    'team2': {'name': 'Serbia', 'code': 'SRB'},
#    'score1': 0,
#    'score2': 1,
#    'score1i': 0,
#    'score2i': 0,
#    'goals1': [],
#    'goals2': [{'name': 'Kolarov', 'minute': 56, 'score1': 0, 'score2': 1}],
#    'group': 'Group E',
#    'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#    'city': 'Samara',
#    'timezone': 'UTC+4'},
#   {'num': 11,
#    'date': '2018-06-17',
#    'time': '18:00',
#    'team1': {'name': 'Germany', 'code': 'GER'},
#    'team2': {'name': 'Mexico', 'code': 'MEX'},
#    'score1': 0,
#    'score2': 1,
#    'score1i': 0,
#    'score2i': 1,
#    'goals1': [],
#    'goals2': [{'name': 'Lozano', 'minute': 35, 'score1': 0, 'score2': 1}],
#    'group': 'Group F',
#    'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#    'city': 'Moscow',
#    'timezone': 'UTC+3'}]}

# %%
type(world_cup_data['rounds'])
# Out:
# list

# %%
len(world_cup_data['rounds'])
# Out:
# 20

# %%
world_cup_data['rounds'][2]
# Out:
# {'name': 'Matchday 3',
#  'matches': [{'num': 5,
#    'date': '2018-06-16',
#    'time': '13:00',
#    'team1': {'name': 'France', 'code': 'FRA'},
#    'team2': {'name': 'Australia', 'code': 'AUS'},
#    'score1': 2,
#    'score2': 1,
#    'score1i': 0,
#    'score2i': 0,
#    'goals1': [{'name': 'Griezmann',
#      'minute': 58,
#      'score1': 1,
#      'score2': 0,
#      'penalty': True},
#     {'name': 'Behich',
#      'minute': 81,
#      'score1': 2,
#      'score2': 1,
#      'owngoal': True}],
#    'goals2': [{'name': 'Jedinak',
#      'minute': 62,
#      'score1': 1,
#      'score2': 1,
#      'penalty': True}],
#    'group': 'Group C',
#    'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#    'city': 'Kazan',
#    'timezone': 'UTC+3'},
#   {'num': 6,
#    'date': '2018-06-16',
#    'time': '19:00',
#    'team1': {'name': 'Peru', 'code': 'PER'},
#    'team2': {'name': 'Denmark', 'code': 'DEN'},
#    'score1': 0,
#    'score2': 1,
#    'score1i': 0,
#    'score2i': 0,
#    'goals1': [],
#    'goals2': [{'name': 'Poulsen', 'minute': 59, 'score1': 0, 'score2': 1}],
#    'group': 'Group C',
#    'stadium': {'key': 'mordovia', 'name': 'Mordovia Arena'},
#    'city': 'Saransk',
#    'timezone': 'UTC+3'},
#   {'num': 7,
#    'date': '2018-06-16',
#    'time': '16:00',
#    'team1': {'name': 'Argentina', 'code': 'ARG'},
#    'team2': {'name': 'Iceland', 'code': 'ISL'},
#    'score1': 1,
#    'score2': 1,
#    'score1i': 1,
#    'score2i': 1,
#    'goals1': [{'name': 'Agüero', 'minute': 19, 'score1': 1, 'score2': 0}],
#    'goals2': [{'name': 'Finnbogason', 'minute': 23, 'score1': 1, 'score2': 1}],
#    'group': 'Group D',
#    'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'},
#    'city': 'Moscow',
#    'timezone': 'UTC+3'},
#   {'num': 8,
#    'date': '2018-06-16',
#    'time': '21:00',
#    'team1': {'name': 'Croatia', 'code': 'CRO'},
#    'team2': {'name': 'Nigeria', 'code': 'NGA'},
#    'score1': 2,
#    'score2': 0,
#    'score1i': 1,
#    'score2i': 0,
#    'goals1': [{'name': 'Etebo',
#      'minute': 32,
#      'score1': 1,
#      'score2': 0,
#      'owngoal': True},
#     {'name': 'Modrić',
#      'minute': 71,
#      'score1': 2,
#      'score2': 0,
#      'penalty': True}],
#    'goals2': [],
#    'group': 'Group D',
#    'stadium': {'key': 'kaliningrad', 'name': 'Kaliningrad Stadium'},
#    'city': 'Kaliningrad',
#    'timezone': 'UTC+2'}]}

# %%
world_cup_data['rounds'][0]['matches']
# Out:
# [{'num': 1,
#   'date': '2018-06-14',
#   'time': '18:00',
#   'team1': {'name': 'Russia', 'code': 'RUS'},
#   'team2': {'name': 'Saudi Arabia', 'code': 'KSA'},
#   'score1': 5,
#   'score2': 0,
#   'score1i': 2,
#   'score2i': 0,
#   'goals1': [{'name': 'Gazinsky', 'minute': 12, 'score1': 1, 'score2': 0},
#    {'name': 'Cheryshev', 'minute': 43, 'score1': 2, 'score2': 0},
#    {'name': 'Dzyuba', 'minute': 71, 'score1': 3, 'score2': 0},
#    {'name': 'Cheryshev', 'minute': 90, 'offset': 1, 'score1': 4, 'score2': 0},
#    {'name': 'Golovin', 'minute': 90, 'offset': 4, 'score1': 5, 'score2': 0}],
#   'goals2': [],
#   'group': 'Group A',
#   'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#   'city': 'Moscow',
#   'timezone': 'UTC+3'}]

# %%
world_cup_data['rounds'][1]['matches']
# Out:
# [{'num': 2,
#   'date': '2018-06-15',
#   'time': '17:00',
#   'team1': {'name': 'Egypt', 'code': 'EGY'},
#   'team2': {'name': 'Uruguay', 'code': 'URU'},
#   'score1': 0,
#   'score2': 1,
#   'score1i': 0,
#   'score2i': 0,
#   'goals1': [],
#   'goals2': [{'name': 'Giménez', 'minute': 89, 'score1': 0, 'score2': 1}],
#   'group': 'Group A',
#   'stadium': {'key': 'ekaterinburg', 'name': 'Ekaterinburg Arena'},
#   'city': 'Ekaterinburg',
#   'timezone': 'UTC+5'},
#  {'num': 3,
#   'date': '2018-06-15',
#   'time': '21:00',
#   'team1': {'name': 'Portugal', 'code': 'POR'},
#   'team2': {'name': 'Spain', 'code': 'ESP'},
#   'score1': 3,
#   'score2': 3,
#   'score1i': 2,
#   'score2i': 1,
#   'goals1': [{'name': 'Ronaldo',
#     'minute': 4,
#     'score1': 1,
#     'score2': 0,
#     'penalty': True},
#    {'name': 'Ronaldo', 'minute': 44, 'score1': 2, 'score2': 1},
#    {'name': 'Ronaldo', 'minute': 88, 'score1': 3, 'score2': 3}],
#   'goals2': [{'name': 'Costa', 'minute': 24, 'score1': 1, 'score2': 1},
#    {'name': 'Costa', 'minute': 55, 'score1': 2, 'score2': 2},
#    {'name': 'Nacho', 'minute': 58, 'score1': 2, 'score2': 3}],
#   'group': 'Group B',
#   'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#   'city': 'Sochi',
#   'timezone': 'UTC+3'},
#  {'num': 4,
#   'date': '2018-06-15',
#   'time': '18:00',
#   'team1': {'name': 'Morocco', 'code': 'MAR'},
#   'team2': {'name': 'Iran', 'code': 'IRN'},
#   'score1': 0,
#   'score2': 1,
#   'score1i': 0,
#   'score2i': 0,
#   'goals1': [],
#   'goals2': [{'name': 'Bouhaddouz',
#     'minute': 90,
#     'offset': 5,
#     'score1': 0,
#     'score2': 1,
#     'owngoal': True}],
#   'group': 'Group B',
#   'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#   'city': 'Saint Petersburg',
#   'timezone': 'UTC+3'}]

# %%
# for team in world_cup_data['rounds']:
#     #print(team['matches'])
#     for name in  team['matches']:
#         print(name['team1']['name'])

# %%
# x=[[name['team1']['name'] for name in  team['matches']]for team in world_cup_data['rounds'] ]
# x

# %% [markdown]
# ### Extracting Matches

# %%
world_cup_data["rounds"]
# Out:
# [{'name': 'Matchday 1',
#   'matches': [{'num': 1,
#     'date': '2018-06-14',
#     'time': '18:00',
#     'team1': {'name': 'Russia', 'code': 'RUS'},
#     'team2': {'name': 'Saudi Arabia', 'code': 'KSA'},
#     'score1': 5,
#     'score2': 0,
#     'score1i': 2,
#     'score2i': 0,
#     'goals1': [{'name': 'Gazinsky', 'minute': 12, 'score1': 1, 'score2': 0},
#      {'name': 'Cheryshev', 'minute': 43, 'score1': 2, 'score2': 0},
#      {'name': 'Dzyuba', 'minute': 71, 'score1': 3, 'score2': 0},
#      {'name': 'Cheryshev',
#       'minute': 90,
#       'offset': 1,
#       'score1': 4,
#       'score2': 0},
#      {'name': 'Golovin', 'minute': 90, 'offset': 4, 'score1': 5, 'score2': 0}],
#     'goals2': [],
#     'group': 'Group A',
#     'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#     'city': 'Moscow',
#     'timezone': 'UTC+3'}]},
#  {'name': 'Matchday 2',
#   'matches': [{'num': 2,
#     'date': '2018-06-15',
#     'time': '17:00',
#     'team1': {'name': 'Egypt', 'code': 'EGY'},
#     'team2': {'name': 'Uruguay', 'code': 'URU'},
#     'score1': 0,
#     'score2': 1,
#     'score1i': 0,
#     'score2i': 0,
#     'goals1': [],
#     'goals2': [{'name': 'Giménez', 'minute': 89, 'score1': 0, 'score2': 1}],
#     'group': 'Group A',
#     'stadium': {'key': 'ekaterinburg', 'name': 'Ekaterinburg Arena'},
#     'city': 'Ekaterinburg',
#     'timezone': 'UTC+5'},
#    {'num': 3,
#     'date': '2018-06-15',
#     'time': '21:00',
#     'team1': {'name': 'Portugal', 'code': 'POR'},
#     'team2': {'name': 'Spain', 'code': 'ESP'},
#     'score1': 3,
#     'score2': 3,
#     'score1i': 2,
#     'score2i': 1,
#     'goals1': [{'name': 'Ronaldo',
#       'minute': 4,
#       'score1': 1,
#       'score2': 0,
#       'penalty': True},
#      {'name': 'Ronaldo', 'minute': 44, 'score1': 2, 'score2': 1},
#      {'name': 'Ronaldo', 'minute': 88, 'score1': 3, 'score2': 3}],
#     'goals2': [{'name': 'Costa', 'minute': 24, 'score1': 1, 'score2': 1},
#      {'name': 'Costa', 'minute': 55, 'score1': 2, 'score2': 2},
#      {'name': 'Nacho', 'minute': 58, 'score1': 2, 'score2': 3}],
#     'group': 'Group B',
#     'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#     'city': 'Sochi',
#     'timezone': 'UTC+3'},
#    {'num': 4,
#     'date': '2018-06-15',
#     'time': '18:00',
#     'team1': {'name': 'Morocco', 'code': 'MAR'},
#     'team2': {'name': 'Iran', 'code': 'IRN'},
#     'score1': 0,
#     'score2': 1,
#     'score1i': 0,
#     'score2i': 0,
#     'goals1': [],
#     'goals2': [{'name': 'Bouhaddouz',
#       'minute': 90,
#       'offset': 5,
#       'score1': 0,
#       'score2': 1,
#       'owngoal': True}],
#     'group': 'Group B',
#     'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#     'city': 'Saint Petersburg',
#     'timezone': 'UTC+3'}]},
#  {'name': 'Matchday 3',
#   'matches': [{'num': 5,
#     'date': '2018-06-16',
#     'time': '13:00',
#     'team1': {'name': 'France', 'code': 'FRA'},
#     'team2': {'name': 'Australia', 'code': 'AUS'},
#     'score1': 2,
#     'score2': 1,
#     'score1i': 0,
#     'score2i': 0,
#     'goals1': [{'name': 'Griezmann',
#       'minute': 58,
#       'score1': 1,
#       'score2': 0,
#       'penalty': True},
#      {'name': 'Behich',
#       'minute': 81,
#       'score1': 2,
#       'score2': 1,
#       'owngoal': True}],
#     'goals2': [{'name': 'Jedinak',
#       'minute': 62,
#       'score1': 1,
#       'score2': 1,
#       'penalty': True}],
#     'group': 'Group C',
#     'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#     'city': 'Kazan',
#     'timezone': 'UTC+3'},
#    {'num': 6,
#     'date': '2018-06-16',
#     'time': '19:00',
#     'team1': {'name': 'Peru', 'code': 'PER'},
#     'team2': {'name': 'Denmark', 'code': 'DEN'},
#     'score1': 0,
#     'score2': 1,
#     'score1i': 0,
#     'score2i': 0,
#     'goals1': [],
#     'goals2': [{'name': 'Poulsen', 'minute': 59, 'score1': 0, 'score2': 1}],
#     'group': 'Group C',
#     'stadium': {'key': 'mordovia', 'name': 'Mordovia Arena'},
#     'city': 'Saransk',
#     'timezone': 'UTC+3'},
#    {'num': 7,
#     'date': '2018-06-16',
#     'time': '16:00',
#     'team1': {'name': 'Argentina', 'code': 'ARG'},
#     'team2': {'name': 'Iceland', 'code': 'ISL'},
#     'score1': 1,
#     'score2': 1,
#     'score1i': 1,
#     'score2i': 1,
#     'goals1': [{'name': 'Agüero', 'minute': 19, 'score1': 1, 'score2': 0}],
#     'goals2': [{'name': 'Finnbogason',
#       'minute': 23,
#       'score1': 1,
#       'score2': 1}],
#     'group': 'Group D',
#     'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'},
#     'city': 'Moscow',
#     'timezone': 'UTC+3'},
#    {'num': 8,
#     'date': '2018-06-16',
#     'time': '21:00',
#     'team1': {'name': 'Croatia', 'code': 'CRO'},
#     'team2': {'name': 'Nigeria', 'code': 'NGA'},
#     'score1': 2,
#     'score2': 0,
#     'score1i': 1,
#     'score2i': 0,
#     'goals1': [{'name': 'Etebo',
#       'minute': 32,
#       'score1': 1,
#       'score2': 0,
#       'owngoal': True},
#      {'name': 'Modrić',
#       'minute': 71,
#       'score1': 2,
#       'score2': 0,
#       'penalty': True}],
#     'goals2': [],
#     'group': 'Group D',
#     'stadium': {'key': 'kaliningrad', 'name': 'Kaliningrad Stadium'},
#     'city': 'Kaliningrad',
#     'timezone': 'UTC+2'}]},
#  {'name': 'Matchday 4',
#   'matches': [{'num': 9,
#     'date': '2018-06-17',
#     'time': '21:00',
#     'team1': {'name': 'Brazil', 'code': 'BRA'},
#     'team2': {'name': 'Switzerland', 'code': 'SUI'},
#     'score1': 1,
#     'score2': 1,
#     'score1i': 1,
#     'score2i': 0,
#     'goals1': [{'name': 'Coutinho', 'minute': 20, 'score1': 1, 'score2': 0}],
#     'goals2': [{'name': 'Zuber', 'minute': 50, 'score1': 1, 'score2': 1}],
#     'group': 'Group E',
#     'stadium': {'key': 'rostov', 'name': 'Rostov Arena'},
#     'city': 'Rostov-on-Don',
#     'timezone': 'UTC+3'},
#    {'num': 10,
#     'date': '2018-06-17',
#     'time': '16:00',
#     'team1': {'name': 'Costa Rica', 'code': 'CRC'},
#     'team2': {'name': 'Serbia', 'code': 'SRB'},
#     'score1': 0,
#     'score2': 1,
#     'score1i': 0,
#     'score2i': 0,
#     'goals1': [],
#     'goals2': [{'name': 'Kolarov', 'minute': 56, 'score1': 0, 'score2': 1}],
#     'group': 'Group E',
#     'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#     'city': 'Samara',
#     'timezone': 'UTC+4'},
#    {'num': 11,
#     'date': '2018-06-17',
#     'time': '18:00',
#     'team1': {'name': 'Germany', 'code': 'GER'},
#     'team2': {'name': 'Mexico', 'code': 'MEX'},
#     'score1': 0,
#     'score2': 1,
#     'score1i': 0,
#     'score2i': 1,
#     'goals1': [],
#     'goals2': [{'name': 'Lozano', 'minute': 35, 'score1': 0, 'score2': 1}],
#     'group': 'Group F',
#     'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#     'city': 'Moscow',
#     'timezone': 'UTC+3'}]},
#  {'name': 'Matchday 5',
#   'matches': [{'num': 12,
#     'date': '2018-06-18',
#     'time': '15:00',
#     'team1': {'name': 'Sweden', 'code': 'SWE'},
#     'team2': {'name': 'South Korea', 'code': 'KOR'},
#     'score1': 1,
#     'score2': 0,
#     'score1i': 0,
#     'score2i': 0,
#     'goals1': [{'name': 'Granqvist',
#       'minute': 65,
#       'score1': 1,
#       'score2': 0,
#       'penalty': True}],
#     'goals2': [],
#     'group': 'Group F',
#     'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'},
#     'city': 'Nizhny Novgorod',
#     'timezone': 'UTC+3'},
#    {'num': 13,
#     'date': '2018-06-18',
#     'time': '18:00',
#     'team1': {'name': 'Belgium', 'code': 'BEL'},
#     'team2': {'name': 'Panama', 'code': 'PAN'},
#     'score1': 3,
#     'score2': 0,
#     'score1i': 0,
#     'score2i': 0,
#     'goals1': [{'name': 'Mertens', 'minute': 47, 'score1': 1, 'score2': 0},
#      {'name': 'Lukaku', 'minute': 69, 'score1': 2, 'score2': 0},
#      {'name': 'Lukaku', 'minute': 75, 'score1': 3, 'score2': 0}],
#     'goals2': [],
#     'group': 'Group G',
#     'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#     'city': 'Sochi',
#     'timezone': 'UTC+3'},
#    {'num': 14,
#     'date': '2018-06-18',
#     'time': '21:00',
#     'team1': {'name': 'Tunisia', 'code': 'TUN'},
#     'team2': {'name': 'England', 'code': 'ENG'},
#     'score1': 1,
#     'score2': 2,
#     'score1i': 1,
#     'score2i': 1,
#     'goals1': [{'name': 'Sassi',
#       'minute': 35,
#       'score1': 1,
#       'score2': 1,
#       'penalty': True}],
#     'goals2': [{'name': 'Kane', 'minute': 11, 'score1': 0, 'score2': 1},
#      {'name': 'Kane', 'minute': 90, 'offset': 1, 'score1': 1, 'score2': 2}],
#     'group': 'Group G',
#     'stadium': {'key': 'volgograd', 'name': 'Volgograd Arena'},
#     'city': 'Volgograd',
#     'timezone': 'UTC+3'}]},
#  {'name': 'Matchday 6',
#   'matches': [{'num': 15,
#     'date': '2018-06-19',
#     'time': '18:00',
#     'team1': {'name': 'Poland', 'code': 'POL'},
#     'team2': {'name': 'Senegal', 'code': 'SEN'},
#     'score1': 1,
#     'score2': 2,
#     'score1i': 0,
#     'score2i': 1,
#     'goals1': [{'name': 'Krychowiak', 'minute': 86, 'score1': 1, 'score2': 2}],
#     'goals2': [{'name': 'Cionek',
#       'minute': 37,
#       'score1': 0,
#       'score2': 1,
#       'owngoal': True},
#      {'name': 'Niang', 'minute': 60, 'score1': 0, 'score2': 2}],
#     'group': 'Group H',
#     'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'},
#     'city': 'Moscow',
#     'timezone': 'UTC+3'},
#    {'num': 16,
#     'date': '2018-06-19',
#     'time': '15:00',
#     'team1': {'name': 'Colombia', 'code': 'COL'},
#     'team2': {'name': 'Japan', 'code': 'JPN'},
#     'score1': 1,
#     'score2': 2,
#     'score1i': 1,
#     'score2i': 1,
#     'goals1': [{'name': 'J. Quintero',
#       'minute': 39,
#       'score1': 1,
#       'score2': 1}],
#     'goals2': [{'name': 'Kagawa',
#       'minute': 6,
#       'score1': 0,
#       'score2': 1,
#       'penalty': True},
#      {'name': 'Osako', 'minute': 73, 'score1': 1, 'score2': 2}],
#     'group': 'Group H',
#     'stadium': {'key': 'mordovia', 'name': 'Mordovia Arena'},
#     'city': 'Saransk',
#     'timezone': 'UTC+3'},
#    {'num': 17,
#     'date': '2018-06-19',
#     'time': '21:00',
#     'team1': {'name': 'Russia', 'code': 'RUS'},
#     'team2': {'name': 'Egypt', 'code': 'EGY'},
#     'score1': 3,
#     'score2': 1,
#     'score1i': 0,
#     'score2i': 0,
#     'goals1': [{'name': 'A. Fathi',
#       'minute': 47,
#       'score1': 1,
#       'score2': 0,
#       'owngoal': True},
#      {'name': 'Cheryshev', 'minute': 59, 'score1': 2, 'score2': 0},
#      {'name': 'Dzyuba', 'minute': 62, 'score1': 3, 'score2': 0}],
#     'goals2': [{'name': 'M. Salah',
#       'minute': 73,
#       'score1': 3,
#       'score2': 1,
#       'penalty': True}],
#     'group': 'Group A',
#     'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#     'city': 'Saint Petersburg',
#     'timezone': 'UTC+3'}]},
#  {'name': 'Matchday 7',
#   'matches': [{'num': 18,
#     'date': '2018-06-20',
#     'time': '18:00',
#     'team1': {'name': 'Uruguay', 'code': 'URU'},
#     'team2': {'name': 'Saudi Arabia', 'code': 'KSA'},
#     'score1': 1,
#     'score2': 0,
#     'score1i': 1,
#     'score2i': 0,
#     'goals1': [{'name': 'L. Suárez', 'minute': 23, 'score1': 1, 'score2': 0}],
#     'goals2': [],
#     'group': 'Group A',
#     'stadium': {'key': 'rostov', 'name': 'Rostov Arena'},
#     'city': 'Rostov-on-Don',
#     'timezone': 'UTC+3'},
#    {'num': 19,
#     'date': '2018-06-20',
#     'time': '15:00',
#     'team1': {'name': 'Portugal', 'code': 'POR'},
#     'team2': {'name': 'Morocco', 'code': 'MAR'},
#     'score1': 1,
#     'score2': 0,
#     'score1i': 1,
#     'score2i': 0,
#     'goals1': [{'name': 'Ronaldo', 'minute': 4, 'score1': 1, 'score2': 0}],
#     'goals2': [],
#     'group': 'Group B',
#     'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#     'city': 'Moscow',
#     'timezone': 'UTC+3'},
#    {'num': 20,
#     'date': '2018-06-20',
#     'time': '21:00',
#     'team1': {'name': 'Iran', 'code': 'IRN'},
#     'team2': {'name': 'Spain', 'code': 'ESP'},
#     'score1': 0,
#     'score2': 1,
#     'score1i': 0,
#     'score2i': 0,
#     'goals1': [],
#     'goals2': [{'name': 'Diego Costa',
#       'minute': 54,
#       'score1': 0,
#       'score2': 1}],
#     'group': 'Group B',
#     'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#     'city': 'Kazan',
#     'timezone': 'UTC+3'}]},
#  {'name': 'Matchday 8',
#   'matches': [{'num': 21,
#     'date': '2018-06-21',
#     'time': '20:00',
#     'team1': {'name': 'France', 'code': 'FRA'},
#     'team2': {'name': 'Peru', 'code': 'PER'},
#     'score1': 1,
#     'score2': 0,
#     'score1i': 1,
#     'score2i': 0,
#     'goals1': [{'name': 'Mbappé', 'minute': 34, 'score1': 1, 'score2': 0}],
#     'goals2': [],
#     'group': 'Group C',
#     'stadium': {'key': 'ekaterinburg', 'name': 'Ekaterinburg Arena'},
#     'city': 'Ekaterinburg',
#     'timezone': 'UTC+5'},
#    {'num': 22,
#     'date': '2018-06-21',
#     'time': '16:00',
#     'team1': {'name': 'Denmark', 'code': 'DEN'},
#     'team2': {'name': 'Australia', 'code': 'AUS'},
#     'score1': 1,
#     'score2': 1,
#     'score1i': 1,
#     'score2i': 1,
#     'goals1': [{'name': 'Eriksen', 'minute': 7, 'score1': 1, 'score2': 0}],
#     'goals2': [{'name': 'Jedinak',
#       'minute': 38,
#       'score1': 1,
#       'score2': 1,
#       'penalty': True}],
#     'group': 'Group C',
#     'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#     'city': 'Samara',
#     'timezone': 'UTC+4'},
#    {'num': 23,
#     'date': '2018-06-21',
#     'time': '21:00',
#     'team1': {'name': 'Argentina', 'code': 'ARG'},
#     'team2': {'name': 'Croatia', 'code': 'CRO'},
#     'score1': 0,
#     'score2': 3,
#     'score1i': 0,
#     'score2i': 0,
#     'goals1': [],
#     'goals2': [{'name': 'Rebić', 'minute': 53, 'score1': 0, 'score2': 1},
#      {'name': 'Modrić', 'minute': 80, 'score1': 0, 'score2': 2},
#      {'name': 'Rakitić', 'minute': 90, 'offset': 1, 'score1': 0, 'score2': 3}],
#     'group': 'Group D',
#     'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'},
#     'city': 'Nizhny Novgorod',
#     'timezone': 'UTC+3'}]},
#  {'name': 'Matchday 9',
#   'matches': [{'num': 24,
#     'date': '2018-06-22',
#     'time': '18:00',
#     'team1': {'name': 'Nigeria', 'code': 'NGA'},
#     'team2': {'name': 'Iceland', 'code': 'ISL'},
#     'score1': 2,
#     'score2': 0,
#     'score1i': 0,
#     'score2i': 0,
#     'goals1': [{'name': 'Musa', 'minute': 49, 'score1': 1, 'score2': 0},
#      {'name': 'Musa', 'minute': 75, 'score1': 2, 'score2': 0}],
#     'goals2': [],
#     'group': 'Group D',
#     'stadium': {'key': 'volgograd', 'name': 'Volgograd Arena'},
#     'city': 'Volgograd',
#     'timezone': 'UTC+3'},
#    {'num': 25,
#     'date': '2018-06-22',
#     'time': '15:00',
#     'team1': {'name': 'Brazil', 'code': 'BRA'},
#     'team2': {'name': 'Costa Rica', 'code': 'CRC'},
#     'score1': 2,
#     'score2': 0,
#     'score1i': 0,
#     'score2i': 0,
#     'group': 'Group E',
#     'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#     'city': 'Saint Petersburg',
#     'timezone': 'UTC+3'},
#    {'num': 26,
#     'date': '2018-06-22',
#     'time': '20:00',
#     'team1': {'name': 'Serbia', 'code': 'SRB'},
#     'team2': {'name': 'Switzerland', 'code': 'SUI'},
#     'score1': 1,
#     'score2': 2,
#     'score1i': 1,
#     'score2i': 0,
#     'goals1': [{'name': 'Mitrović', 'minute': 5, 'score1': 1, 'score2': 0}],
#     'goals2': [{'name': 'Xhaka', 'minute': 52, 'score1': 1, 'score2': 1},
#      {'name': 'Shaqiri', 'minute': 90, 'score1': 1, 'score2': 2}],
#     'group': 'Group E',
#     'stadium': {'key': 'kaliningrad', 'name': 'Kaliningrad Stadium'},
#     'city': 'Kaliningrad',
#     'timezone': 'UTC+2'}]},
#  {'name': 'Matchday 10',
#   'matches': [{'num': 27,
#     'date': '2018-06-23',
#     'time': '21:00',
#     'team1': {'name': 'Germany', 'code': 'GER'},
#     'team2': {'name': 'Sweden', 'code': 'SWE'},
#     'score1': 2,
#     'score2': 1,
#     'score1i': 0,
#     'score2i': 1,
#     'goals1': [{'name': 'Reus', 'minute': 48, 'score1': 1, 'score2': 1},
#      {'name': 'Kroos', 'minute': 90, 'offset': 5, 'score1': 2, 'score2': 1}],
#     'goals2': [{'name': 'Toivonen', 'minute': 32, 'score1': 0, 'score2': 1}],
#     'group': 'Group F',
#     'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#     'city': 'Sochi',
#     'timezone': 'UTC+3'},
#    {'num': 28,
#     'date': '2018-06-23',
#     'time': '18:00',
#     'team1': {'name': 'South Korea', 'code': 'KOR'},
#     'team2': {'name': 'Mexico', 'code': 'MEX'},
#     'score1': 1,
#     'score2': 2,
#     'score1i': 0,
#     'score2i': 1,
#     'goals1': [{'name': 'Son Heung-min',
#       'minute': 90,
#       'offset': 3,
#       'score1': 1,
#       'score2': 2}],
#     'goals2': [{'name': 'Carlos V.',
#       'minute': 26,
#       'score1': 0,
#       'score2': 1,
#       'penalty': True},
#      {'name': 'J. Hernández', 'minute': 66, 'score1': 0, 'score2': 2}],
#     'group': 'Group F',
#     'stadium': {'key': 'rostov', 'name': 'Rostov Arena'},
#     'city': 'Rostov-on-Don',
#     'timezone': 'UTC+3'},
#    {'num': 29,
#     'date': '2018-06-23',
#     'time': '15:00',
#     'team1': {'name': 'Belgium', 'code': 'BEL'},
#     'team2': {'name': 'Tunisia', 'code': 'TUN'},
#     'score1': 5,
#     'score2': 2,
#     'score1i': 3,
#     'score2i': 1,
#     'goals1': [{'name': 'E. Hazard',
#       'minute': 6,
#       'score1': 1,
#       'score2': 0,
#       'penalty': True},
#      {'name': 'R. Lukaku', 'minute': 16, 'score1': 2, 'score2': 0},
#      {'name': 'R. Lukaku',
#       'minute': 45,
#       'offset': 3,
#       'score1': 3,
#       'score2': 1},
#      {'name': 'E. Hazard', 'minute': 51, 'score1': 4, 'score2': 1},
#      {'name': 'Batshuayi', 'minute': 90, 'score1': 5, 'score2': 1}],
#     'goals2': [{'name': 'Bronn', 'minute': 18, 'score1': 2, 'score2': 1},
#      {'name': 'Khazri', 'minute': 90, 'offset': 3, 'score1': 5, 'score2': 2}],
#     'group': 'Group G',
#     'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'},
#     'city': 'Moscow',
#     'timezone': 'UTC+3'}]},
#  {'name': 'Matchday 11',
#   'matches': [{'num': 30,
#     'date': '2018-06-24',
#     'time': '15:00',
#     'team1': {'name': 'England', 'code': 'ENG'},
#     'team2': {'name': 'Panama', 'code': 'PAN'},
#     'score1': 6,
#     'score2': 1,
#     'score1i': 5,
#     'score2i': 0,
#     'goals1': [{'name': 'Stones', 'minute': 8, 'score1': 1, 'score2': 0},
#      {'name': 'Kane', 'minute': 22, 'score1': 2, 'score2': 0, 'penalty': True},
#      {'name': 'Lingard', 'minute': 36, 'score1': 3, 'score2': 0},
#      {'name': 'Stones', 'minute': 40, 'score1': 4, 'score2': 0},
#      {'name': 'Kane',
#       'minute': 45,
#       'offset': 1,
#       'score1': 5,
#       'score2': 0,
#       'penalty': True},
#      {'name': 'Kane', 'minute': 62, 'score1': 6, 'score2': 0}],
#     'goals2': [{'name': 'Baloy', 'minute': 78, 'score1': 6, 'score2': 1}],
#     'group': 'Group G',
#     'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'},
#     'city': 'Nizhny Novgorod',
#     'timezone': 'UTC+3'},
#    {'num': 31,
#     'date': '2018-06-24',
#     'time': '21:00',
#     'team1': {'name': 'Poland', 'code': 'POL'},
#     'team2': {'name': 'Colombia', 'code': 'COL'},
#     'score1': 0,
#     'score2': 3,
#     'score1i': 0,
#     'score2i': 1,
#     'goals1': [],
#     'goals2': [{'name': 'Y. Mina', 'minute': 40, 'score1': 0, 'score2': 1},
#      {'name': 'Falcao', 'minute': 70, 'score1': 0, 'score2': 2},
#      {'name': 'Cuadrado', 'minute': 75, 'score1': 0, 'score2': 3}],
#     'group': 'Group H',
#     'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#     'city': 'Kazan',
#     'timezone': 'UTC+3'},
#    {'num': 32,
#     'date': '2018-06-24',
#     'time': '20:00',
#     'team1': {'name': 'Japan', 'code': 'JPN'},
#     'team2': {'name': 'Senegal', 'code': 'SEN'},
#     'score1': 2,
#     'score2': 2,
#     'score1i': 1,
#     'score2i': 1,
#     'goals1': [{'name': 'Inui', 'minute': 34, 'score1': 1, 'score2': 1},
#      {'name': 'Honda', 'minute': 78, 'score1': 2, 'score2': 2}],
#     'goals2': [{'name': 'Mané', 'minute': 11, 'score1': 0, 'score2': 1},
#      {'name': 'M. Wagué', 'minute': 71, 'score1': 1, 'score2': 2}],
#     'group': 'Group H',
#     'stadium': {'key': 'ekaterinburg', 'name': 'Ekaterinburg Arena'},
#     'city': 'Ekaterinburg',
#     'timezone': 'UTC+5'}]},
#  {'name': 'Matchday 12',
#   'matches': [{'num': 33,
#     'date': '2018-06-25',
#     'time': '18:00',
#     'team1': {'name': 'Uruguay', 'code': 'URU'},
#     'team2': {'name': 'Russia', 'code': 'RUS'},
#     'score1': 3,
#     'score2': 0,
#     'score1i': 2,
#     'score2i': 0,
#     'goals1': [{'name': 'L. Suárez', 'minute': 10, 'score1': 1, 'score2': 0},
#      {'name': 'Cheryshev',
#       'minute': 23,
#       'score1': 2,
#       'score2': 0,
#       'owngoal': True},
#      {'name': 'E. Cavani', 'minute': 90, 'score1': 3, 'score2': 0}],
#     'goals2': [],
#     'group': 'Group A',
#     'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#     'city': 'Samara',
#     'timezone': 'UTC+4'},
#    {'num': 34,
#     'date': '2018-06-25',
#     'time': '17:00',
#     'team1': {'name': 'Saudi Arabia', 'code': 'KSA'},
#     'team2': {'name': 'Egypt', 'code': 'EGY'},
#     'score1': 2,
#     'score2': 1,
#     'score1i': 1,
#     'score2i': 1,
#     'goals1': [{'name': 'Salman Al-Faraj',
#       'minute': 45,
#       'offset': 6,
#       'score1': 1,
#       'score2': 1,
#       'penalty': True},
#      {'name': 'Salem Al-Dawsari',
#       'minute': 90,
#       'offset': 5,
#       'score1': 2,
#       'score2': 1}],
#     'goals2': [{'name': 'M. Salah', 'minute': 22, 'score1': 0, 'score2': 1}],
#     'group': 'Group A',
#     'stadium': {'key': 'volgograd', 'name': 'Volgograd Arena'},
#     'city': 'Volgograd',
#     'timezone': 'UTC+3'},
#    {'num': 35,
#     'date': '2018-06-25',
#     'time': '21:00',
#     'team1': {'name': 'Iran', 'code': 'IRN'},
#     'team2': {'name': 'Portugal', 'code': 'POR'},
#     'score1': 1,
#     'score2': 1,
#     'score1i': 0,
#     'score2i': 1,
#     'goals1': [{'name': 'Karim Ansarifard',
#       'minute': 90,
#       'offset': 3,
#       'score1': 1,
#       'score2': 1,
#       'penalty': True}],
#     'goals2': [{'name': 'Quaresma', 'minute': 45, 'score1': 0, 'score2': 1}],
#     'group': 'Group B',
#     'stadium': {'key': 'mordovia', 'name': 'Mordovia Arena'},
#     'city': 'Saransk',
#     'timezone': 'UTC+3'},
#    {'num': 36,
#     'date': '2018-06-25',
#     'time': '20:00',
#     'team1': {'name': 'Spain', 'code': 'ESP'},
#     'team2': {'name': 'Morocco', 'code': 'MAR'},
#     'score1': 2,
#     'score2': 2,
#     'score1i': 1,
#     'score2i': 1,
#     'goals1': [{'name': 'Isco', 'minute': 19, 'score1': 1, 'score2': 1},
#      {'name': 'Iago Aspas',
#       'minute': 90,
#       'offset': 1,
#       'score1': 2,
#       'score2': 2}],
#     'goals2': [{'name': 'Boutaib', 'minute': 14, 'score1': 0, 'score2': 1},
#      {'name': 'En-Nesyri', 'minute': 81, 'score1': 1, 'score2': 2}],
#     'group': 'Group B',
#     'stadium': {'key': 'kaliningrad', 'name': 'Kaliningrad Stadium'},
#     'city': 'Kaliningrad',
#     'timezone': 'UTC+2'}]},
#  {'name': 'Matchday 13',
#   'matches': [{'num': 37,
#     'date': '2018-06-26',
#     'time': '17:00',
#     'team1': {'name': 'Denmark', 'code': 'DEN'},
#     'team2': {'name': 'France', 'code': 'FRA'},
#     'score1': 0,
#     'score2': 0,
#     'score1i': 0,
#     'score2i': 0,
#     'group': 'Group C',
#     'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#     'city': 'Moscow',
#     'timezone': 'UTC+3'},
#    {'num': 38,
#     'date': '2018-06-26',
#     'time': '17:00',
#     'team1': {'name': 'Australia', 'code': 'AUS'},
#     'team2': {'name': 'Peru', 'code': 'PER'},
#     'score1': 0,
#     'score2': 2,
#     'score1i': 0,
#     'score2i': 1,
#     'goals1': [],
#     'goals2': [{'name': 'Carrillo', 'minute': 18, 'score1': 0, 'score2': 1},
#      {'name': 'Guerrero', 'minute': 50, 'score1': 0, 'score2': 2}],
#     'group': 'Group C',
#     'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#     'city': 'Sochi',
#     'timezone': 'UTC+3'},
#    {'num': 39,
#     'date': '2018-06-26',
#     'time': '21:00',
#     'team1': {'name': 'Nigeria', 'code': 'NGA'},
#     'team2': {'name': 'Argentina', 'code': 'ARG'},
#     'score1': 1,
#     'score2': 2,
#     'score1i': 0,
#     'score2i': 1,
#     'goals1': [{'name': 'Moses',
#       'minute': 51,
#       'score1': 1,
#       'score2': 1,
#       'penalty': True}],
#     'goals2': [{'name': 'Messi', 'minute': 14, 'score1': 0, 'score2': 1},
#      {'name': 'Marcos Rojo', 'minute': 86, 'score1': 1, 'score2': 2}],
#     'group': 'Group D',
#     'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#     'city': 'Saint Petersburg',
#     'timezone': 'UTC+3'},
#    {'num': 40,
#     'date': '2018-06-26',
#     'time': '21:00',
#     'team1': {'name': 'Iceland', 'code': 'ISL'},
#     'team2': {'name': 'Croatia', 'code': 'CRO'},
#     'score1': 1,
#     'score2': 2,
#     'score1i': 0,
#     'score2i': 0,
#     'goals1': [{'name': 'G. Sigurðsson',
#       'minute': 76,
#       'score1': 1,
#       'score2': 1,
#       'penalty': True}],
#     'goals2': [{'name': 'Badelj', 'minute': 53, 'score1': 0, 'score2': 1},
#      {'name': 'Perišić', 'minute': 90, 'score1': 1, 'score2': 2}],
#     'group': 'Group D',
#     'stadium': {'key': 'rostov', 'name': 'Rostov Arena'},
#     'city': 'Rostov-on-Don',
#     'timezone': 'UTC+3'}]},
#  {'name': 'Matchday 14',
#   'matches': [{'num': 41,
#     'date': '2018-06-27',
#     'time': '21:00',
#     'team1': {'name': 'Serbia', 'code': 'SRB'},
#     'team2': {'name': 'Brazil', 'code': 'BRA'},
#     'score1': 0,
#     'score2': 2,
#     'score1i': 0,
#     'score2i': 1,
#     'goals1': [],
#     'goals2': [{'name': 'Paulinho', 'minute': 36, 'score1': 0, 'score2': 1},
#      {'name': 'Thiago Silva', 'minute': 68, 'score1': 0, 'score2': 2}],
#     'group': 'Group E',
#     'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'},
#     'city': 'Moscow',
#     'timezone': 'UTC+3'},
#    {'num': 42,
#     'date': '2018-06-27',
#     'time': '21:00',
#     'team1': {'name': 'Switzerland', 'code': 'SUI'},
#     'team2': {'name': 'Costa Rica', 'code': 'CRC'},
#     'score1': 2,
#     'score2': 2,
#     'score1i': 1,
#     'score2i': 0,
#     'goals1': [{'name': 'Džemaili', 'minute': 31, 'score1': 1, 'score2': 0},
#      {'name': 'Drmić', 'minute': 88, 'score1': 2, 'score2': 1}],
#     'goals2': [{'name': 'Waston', 'minute': 56, 'score1': 1, 'score2': 1},
#      {'name': 'Sommer',
#       'minute': 90,
#       'offset': 3,
#       'score1': 2,
#       'score2': 2,
#       'owngoal': True}],
#     'group': 'Group E',
#     'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'},
#     'city': 'Nizhny Novgorod',
#     'timezone': 'UTC+3'},
#    {'num': 43,
#     'date': '2018-06-27',
#     'time': '17:00',
#     'team1': {'name': 'South Korea', 'code': 'KOR'},
#     'team2': {'name': 'Germany', 'code': 'GER'},
#     'score1': 2,
#     'score2': 0,
#     'score1i': 0,
#     'score2i': 0,
#     'goals1': [{'name': 'Kim Young-gwon',
#       'minute': 90,
#       'offset': 2,
#       'score1': 1,
#       'score2': 0},
#      {'name': 'Son Heung-min',
#       'minute': 90,
#       'offset': 6,
#       'score1': 2,
#       'score2': 0}],
#     'goals2': [],
#     'group': 'Group F',
#     'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#     'city': 'Kazan',
#     'timezone': 'UTC+3'},
#    {'num': 44,
#     'date': '2018-06-27',
#     'time': '19:00',
#     'team1': {'name': 'Mexico', 'code': 'MEX'},
#     'team2': {'name': 'Sweden', 'code': 'SWE'},
#     'score1': 0,
#     'score2': 3,
#     'score1i': 0,
#     'score2i': 0,
#     'goals1': [],
#     'goals2': [{'name': 'Augustinsson',
#       'minute': 50,
#       'score1': 0,
#       'score2': 1},
#      {'name': 'Granqvist',
#       'minute': 62,
#       'score1': 0,
#       'score2': 2,
#       'penalty': True},
#      {'name': 'Álvarez',
#       'minute': 74,
#       'score1': 0,
#       'score2': 3,
#       'owngoal': True}],
#     'group': 'Group F',
#     'stadium': {'key': 'ekaterinburg', 'name': 'Ekaterinburg Arena'},
#     'city': 'Ekaterinburg',
#     'timezone': 'UTC+5'}]},
#  {'name': 'Matchday 15',
#   'matches': [{'num': 45,
#     'date': '2018-06-28',
#     'time': '20:00',
#     'team1': {'name': 'England', 'code': 'ENG'},
#     'team2': {'name': 'Belgium', 'code': 'BEL'},
#     'score1': 0,
#     'score2': 1,
#     'score1i': 0,
#     'score2i': 0,
#     'goals1': [],
#     'goals2': [{'name': 'Adnan Januzaj',
#       'minute': 51,
#       'score1': 0,
#       'score2': 1}],
#     'group': 'Group G',
#     'stadium': {'key': 'kaliningrad', 'name': 'Kaliningrad Stadium'},
#     'city': 'Kaliningrad',
#     'timezone': 'UTC+2'},
#    {'num': 46,
#     'date': '2018-06-28',
#     'time': '21:00',
#     'team1': {'name': 'Panama', 'code': 'PAN'},
#     'team2': {'name': 'Tunisia', 'code': 'TUN'},
#     'score1': 1,
#     'score2': 2,
#     'score1i': 1,
#     'score2i': 0,
#     'goals1': [{'name': 'Yassine Meriah',
#       'minute': 33,
#       'score1': 1,
#       'score2': 0,
#       'owngoal': True}],
#     'goals2': [{'name': 'Fakhereedine Ben Youssef',
#       'minute': 51,
#       'score1': 1,
#       'score2': 1},
#      {'name': 'Wahbi Khazri', 'minute': 66, 'score1': 1, 'score2': 2}],
#     'group': 'Group G',
#     'stadium': {'key': 'mordovia', 'name': 'Mordovia Arena'},
#     'city': 'Saransk',
#     'timezone': 'UTC+3'},
#    {'num': 47,
#     'date': '2018-06-28',
#     'time': '17:00',
#     'team1': {'name': 'Japan', 'code': 'JPN'},
#     'team2': {'name': 'Poland', 'code': 'POL'},
#     'score1': 0,
#     'score2': 1,
#     'score1i': 0,
#     'score2i': 1,
#     'goals1': [],
#     'goals2': [{'name': 'Bednarek', 'minute': 59, 'score1': 0, 'score2': 1}],
#     'group': 'Group H',
#     'stadium': {'key': 'volgograd', 'name': 'Volgograd Arena'},
#     'city': 'Volgograd',
#     'timezone': 'UTC+3'},
#    {'num': 48,
#     'date': '2018-06-28',
#     'time': '18:00',
#     'team1': {'name': 'Senegal', 'code': 'SEN'},
#     'team2': {'name': 'Colombia', 'code': 'COL'},
#     'score1': 0,
#     'score2': 1,
#     'score1i': 0,
#     'score2i': 1,
#     'goals1': [],
#     'goals2': [{'name': 'Y. Mina', 'minute': 74, 'score1': 0, 'score2': 1}],
#     'group': 'Group H',
#     'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#     'city': 'Samara',
#     'timezone': 'UTC+4'}]},
#  {'name': 'Round of 16',
#   'matches': [{'num': 49,
#     'date': '2018-06-30',
#     'time': '21:00',
#     'team1': {'name': 'Uruguay', 'code': 'URU'},
#     'team2': {'name': 'Portugal', 'code': 'POR'},
#     'score1': 2,
#     'score2': 1,
#     'score1i': 1,
#     'score2i': 0,
#     'score1et': None,
#     'score2et': None,
#     'score1p': None,
#     'score2p': None,
#     'knockout': True,
#     'goals1': [{'name': 'Edinson Cavani',
#       'minute': 7,
#       'score1': 1,
#       'score2': 0},
#      {'name': 'Edinson Cavani', 'minute': 62, 'score1': 2, 'score2': 1}],
#     'goals2': [{'name': 'Pepe', 'minute': 55, 'score1': 1, 'score2': 1}],
#     'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#     'city': 'Sochi',
#     'timezone': 'UTC+3'},
#    {'num': 50,
#     'date': '2018-06-30',
#     'time': '17:00',
#     'team1': {'name': 'France', 'code': 'FRA'},
#     'team2': {'name': 'Argentina', 'code': 'ARG'},
#     'score1': 4,
#     'score2': 3,
#     'score1i': 1,
#     'score2i': 1,
#     'score1et': None,
#     'score2et': None,
#     'score1p': None,
#     'score2p': None,
#     'knockout': True,
#     'goals1': [{'name': 'Antoine Griezmann',
#       'minute': 13,
#       'score1': 1,
#       'score2': 0,
#       'penalty': True},
#      {'name': 'Benjamin Pavard', 'minute': 57, 'score1': 2, 'score2': 2},
#      {'name': 'Kylian Mbappé', 'minute': 64, 'score1': 3, 'score2': 2},
#      {'name': 'Kylian Mbappé', 'minute': 68, 'score1': 4, 'score2': 2}],
#     'goals2': [{'name': 'Ángel Di María',
#       'minute': 41,
#       'score1': 1,
#       'score2': 1},
#      {'name': 'Gabriel Mercado', 'minute': 48, 'score1': 1, 'score2': 2},
#      {'name': 'Sergio Agüero',
#       'minute': 90,
#       'offset': 3,
#       'score1': 4,
#       'score2': 3}],
#     'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#     'city': 'Kazan',
#     'timezone': 'UTC+3'},
#    {'num': 51,
#     'date': '2018-07-01',
#     'time': '17:00',
#     'team1': {'name': 'Spain', 'code': 'ESP'},
#     'team2': {'name': 'Russia', 'code': 'RUS'},
#     'score1': 1,
#     'score2': 1,
#     'score1i': 1,
#     'score2i': 1,
#     'score1et': 1,
#     'score2et': 1,
#     'score1p': 3,
#     'score2p': 4,
#     'knockout': True,
#     'goals1': [{'name': 'Sergei Ignashevich',
#       'minute': 12,
#       'score1': 1,
#       'score2': 0,
#       'owngoal': True}],
#     'goals2': [{'name': 'Artem Dzyuba',
#       'minute': 41,
#       'score1': 1,
#       'score2': 1,
#       'penalty': True}],
#     'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#     'city': 'Moscow',
#     'timezone': 'UTC+3'},
#    {'num': 52,
#     'date': '2018-07-01',
#     'time': '21:00',
#     'team1': {'name': 'Croatia', 'code': 'CRO'},
#     'team2': {'name': 'Denmark', 'code': 'DEN'},
#     'score1': 1,
#     'score2': 1,
#     'score1i': 1,
#     'score2i': 1,
#     'score1et': 1,
#     'score2et': 1,
#     'score1p': 3,
#     'score2p': 2,
#     'knockout': True,
#     'goals1': [{'name': 'Mario Mandžukić',
#       'minute': 4,
#       'score1': 1,
#       'score2': 1}],
#     'goals2': [{'name': 'Mathias Jørgensen',
#       'minute': 1,
#       'score1': 0,
#       'score2': 1}],
#     'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'},
#     'city': 'Nizhny Novgorod',
#     'timezone': 'UTC+3'},
#    {'num': 53,
#     'date': '2018-07-02',
#     'time': '18:00',
#     'team1': {'name': 'Brazil', 'code': 'BRA'},
#     'team2': {'name': 'Mexico', 'code': 'MEX'},
#     'score1': 2,
#     'score2': 0,
#     'score1i': 0,
#     'score2i': 0,
#     'score1et': None,
#     'score2et': None,
#     'score1p': None,
#     'score2p': None,
#     'knockout': True,
#     'goals1': [{'name': 'Neymar', 'minute': 51, 'score1': 1, 'score2': 0},
#      {'name': 'Roberto Firmino', 'minute': 88, 'score1': 2, 'score2': 0}],
#     'goals2': [],
#     'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#     'city': 'Samara',
#     'timezone': 'UTC+4'},
#    {'num': 54,
#     'date': '2018-07-02',
#     'time': '21:00',
#     'team1': {'name': 'Belgium', 'code': 'BEL'},
#     'team2': {'name': 'Japan', 'code': 'JPN'},
#     'score1': 3,
#     'score2': 2,
#     'score1i': 0,
#     'score2i': 0,
#     'score1et': None,
#     'score2et': None,
#     'score1p': None,
#     'score2p': None,
#     'knockout': True,
#     'goals1': [{'name': 'Jan Vertonghen',
#       'minute': 69,
#       'score1': 1,
#       'score2': 2},
#      {'name': 'Marouane Fellaini', 'minute': 74, 'score1': 2, 'score2': 2},
#      {'name': 'Nacer Chadli',
#       'minute': 90,
#       'offset': 4,
#       'score1': 3,
#       'score2': 2}],
#     'goals2': [{'name': 'Genki Haraguchi',
#       'minute': 48,
#       'score1': 0,
#       'score2': 1},
#      {'name': 'Takashi Inui', 'minute': 52, 'score1': 0, 'score2': 2}],
#     'stadium': {'key': 'rostov', 'name': 'Rostov Arena'},
#     'city': 'Rostov-on-Don',
#     'timezone': 'UTC+3'},
#    {'num': 55,
#     'date': '2018-07-03',
#     'time': '17:00',
#     'team1': {'name': 'Sweden', 'code': 'SWE'},
#     'team2': {'name': 'Switzerland', 'code': 'SUI'},
#     'score1': 1,
#     'score2': 0,
#     'score1i': 0,
#     'score2i': 0,
#     'score1et': None,
#     'score2et': None,
#     'score1p': None,
#     'score2p': None,
#     'knockout': True,
#     'goals1': [{'name': 'Emil Forsberg',
#       'minute': 66,
#       'score1': 1,
#       'score2': 0}],
#     'goals2': [],
#     'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#     'city': 'Saint Petersburg',
#     'timezone': 'UTC+3'},
#    {'num': 56,
#     'date': '2018-07-03',
#     'time': '21:00',
#     'team1': {'name': 'Colombia', 'code': 'COL'},
#     'team2': {'name': 'England', 'code': 'ENG'},
#     'score1': 1,
#     'score2': 1,
#     'score1i': 0,
#     'score2i': 0,
#     'score1et': 1,
#     'score2et': 1,
#     'score1p': 3,
#     'score2p': 4,
#     'knockout': True,
#     'goals1': [{'name': 'Yerry Mina',
#       'minute': 90,
#       'offset': 3,
#       'score1': 1,
#       'score2': 1}],
#     'goals2': [{'name': 'Harry Kane',
#       'minute': 57,
#       'score1': 0,
#       'score2': 1,
#       'penalty': True}],
#     'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'},
#     'city': 'Moscow',
#     'timezone': 'UTC+3'}]},
#  {'name': 'Quarter-finals',
#   'matches': [{'num': 57,
#     'date': '2018-07-06',
#     'time': '17:00',
#     'team1': {'name': 'Uruguay', 'code': 'URU'},
#     'team2': {'name': 'France', 'code': 'FRA'},
#     'score1': 0,
#     'score2': 2,
#     'score1i': 0,
#     'score2i': 1,
#     'score1et': None,
#     'score2et': None,
#     'score1p': None,
#     'score2p': None,
#     'knockout': True,
#     'goals1': [],
#     'goals2': [{'name': 'Raphaël Varane',
#       'minute': 40,
#       'score1': 0,
#       'score2': 1},
#      {'name': 'Antoine Griezmann', 'minute': 61, 'score1': 0, 'score2': 2}],
#     'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'},
#     'city': 'Nizhny Novgorod',
#     'timezone': 'UTC+3'},
#    {'num': 58,
#     'date': '2018-07-06',
#     'time': '21:00',
#     'team1': {'name': 'Brazil', 'code': 'BRA'},
#     'team2': {'name': 'Belgium', 'code': 'BEL'},
#     'score1': 1,
#     'score2': 2,
#     'score1i': 0,
#     'score2i': 2,
#     'score1et': None,
#     'score2et': None,
#     'score1p': None,
#     'score2p': None,
#     'knockout': True,
#     'goals1': [{'name': 'Renato Augusto',
#       'minute': 76,
#       'score1': 1,
#       'score2': 2}],
#     'goals2': [{'name': 'Fernandinho',
#       'minute': 13,
#       'score1': 0,
#       'score2': 1,
#       'owngoal': True},
#      {'name': 'Kevin De Bruyne', 'minute': 31, 'score1': 0, 'score2': 2}],
#     'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#     'city': 'Kazan',
#     'timezone': 'UTC+3'},
#    {'num': 59,
#     'date': '2018-07-07',
#     'time': '21:00',
#     'team1': {'name': 'Russia', 'code': 'RUS'},
#     'team2': {'name': 'Croatia', 'code': 'CRO'},
#     'score1': 1,
#     'score2': 1,
#     'score1i': 1,
#     'score2i': 1,
#     'score1et': 2,
#     'score2et': 2,
#     'score1p': 3,
#     'score2p': 4,
#     'knockout': True,
#     'goals1': [{'name': 'Denis Cheryshev',
#       'minute': 31,
#       'score1': 1,
#       'score2': 0},
#      {'name': 'Mário Figueira Fernandes',
#       'minute': 115,
#       'score1': 2,
#       'score2': 2}],
#     'goals2': [{'name': 'Andrej Kramarić',
#       'minute': 39,
#       'score1': 1,
#       'score2': 1},
#      {'name': 'Domagoj Vida', 'minute': 100, 'score1': 1, 'score2': 2}],
#     'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#     'city': 'Sochi',
#     'timezone': 'UTC+3'},
#    {'num': 60,
#     'date': '2018-07-07',
#     'time': '18:00',
#     'team1': {'name': 'Sweden', 'code': 'SWE'},
#     'team2': {'name': 'England', 'code': 'ENG'},
#     'score1': 0,
#     'score2': 2,
#     'score1i': 0,
#     'score2i': 1,
#     'score1et': None,
#     'score2et': None,
#     'score1p': None,
#     'score2p': None,
#     'knockout': True,
#     'goals1': [],
#     'goals2': [{'name': 'Harry Maguire',
#       'minute': 30,
#       'score1': 0,
#       'score2': 1},
#      {'name': 'Dele Alli', 'minute': 58, 'score1': 0, 'score2': 2}],
#     'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#     'city': 'Samara',
#     'timezone': 'UTC+4'}]},
#  {'name': 'Semi-finals',
#   'matches': [{'num': 61,
#     'date': '2018-07-10',
#     'time': '21:00',
#     'team1': {'name': 'France', 'code': 'FRA'},
#     'team2': {'name': 'Belgium', 'code': 'BEL'},
#     'score1': 1,
#     'score2': 0,
#     'score1i': 0,
#     'score2i': 0,
#     'score1et': None,
#     'score2et': None,
#     'score1p': None,
#     'score2p': None,
#     'knockout': True,
#     'goals1': [{'name': 'Samuel Umtiti',
#       'minute': 51,
#       'score1': 1,
#       'score2': 0}],
#     'goals2': [],
#     'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#     'city': 'Saint Petersburg',
#     'timezone': 'UTC+3'},
#    {'num': 62,
#     'date': '2018-07-11',
#     'time': '21:00',
#     'team1': {'name': 'Croatia', 'code': 'CRO'},
#     'team2': {'name': 'England', 'code': 'ENG'},
#     'score1': 1,
#     'score2': 1,
#     'score1i': 0,
#     'score2i': 1,
#     'score1et': 2,
#     'score2et': 1,
#     'score1p': None,
#     'score2p': None,
#     'knockout': True,
#     'goals1': [{'name': 'Ivan Perišić',
#       'minute': 68,
#       'score1': 1,
#       'score2': 1},
#      {'name': 'Mario Mandžukić', 'minute': 109, 'score1': 2, 'score2': 1}],
#     'goals2': [{'name': 'Kieran Trippier',
#       'minute': 5,
#       'score1': 0,
#       'score2': 1}],
#     'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#     'city': 'Moscow',
#     'timezone': 'UTC+3'}]},
#  {'name': 'Match for third place',
#   'matches': [{'num': 63,
#     'date': '2018-07-14',
#     'time': '17:00',
#     'team1': {'name': 'Belgium', 'code': 'BEL'},
#     'team2': {'name': 'England', 'code': 'ENG'},
#     'score1': 2,
#     'score2': 0,
#     'score1i': 1,
#     'score2i': 0,
#     'score1et': None,
#     'score2et': None,
#     'score1p': None,
#     'score2p': None,
#     'knockout': True,
#     'goals1': [{'name': 'Thomas Meunier',
#       'minute': 4,
#       'score1': 1,
#       'score2': 0},
#      {'name': 'Eden Hazard', 'minute': 82, 'score1': 2, 'score2': 0}],
#     'goals2': [],
#     'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#     'city': 'Saint Petersburg',
#     'timezone': 'UTC+3'}]},
#  {'name': 'Final',
#   'matches': [{'num': 64,
#     'date': '2018-07-15',
#     'time': '18:00',
#     'team1': {'name': 'France', 'code': 'FRA'},
#     'team2': {'name': 'Croatia', 'code': 'CRO'},
#     'score1': 4,
#     'score2': 2,
#     'score1i': 2,
#     'score2i': 1,
#     'score1et': None,
#     'score2et': None,
#     'score1p': None,
#     'score2p': None,
#     'knockout': True,
#     'goals1': [{'name': 'Mario Mandžukić',
#       'minute': 18,
#       'score1': 1,
#       'score2': 0,
#       'owngoal': True},
#      {'name': 'Griezmann',
#       'minute': 38,
#       'score1': 2,
#       'score2': 1,
#       'penalty': True},
#      {'name': 'Pogba', 'minute': 59, 'score1': 3, 'score2': 1},
#      {'name': 'Mbappé', 'minute': 65, 'score1': 4, 'score2': 1}],
#     'goals2': [{'name': 'Perišić', 'minute': 28, 'score1': 1, 'score2': 1},
#      {'name': 'Mario Mandžukić', 'minute': 69, 'score1': 4, 'score2': 2}],
#     'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#     'city': 'Moscow',
#     'timezone': 'UTC+3'}]}]

# %%
for round_ in world_cup_data["rounds"]:
    print(round_['matches'])
# Out:
# [{'num': 1, 'date': '2018-06-14', 'time': '18:00', 'team1': {'name': 'Russia', 'code': 'RUS'}, 'team2': {'name': 'Saudi Arabia', 'code': 'KSA'}, 'score1': 5, 'score2': 0, 'score1i': 2, 'score2i': 0, 'goals1': [{'name': 'Gazinsky', 'minute': 12, 'score1': 1, 'score2': 0}, {'name': 'Cheryshev', 'minute': 43, 'score1': 2, 'score2': 0}, {'name': 'Dzyuba', 'minute': 71, 'score1': 3, 'score2': 0}, {'name': 'Cheryshev', 'minute': 90, 'offset': 1, 'score1': 4, 'score2': 0}, {'name': 'Golovin', 'minute': 90, 'offset': 4, 'score1': 5, 'score2': 0}], 'goals2': [], 'group': 'Group A', 'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'}, 'city': 'Moscow', 'timezone': 'UTC+3'}]
# [{'num': 2, 'date': '2018-06-15', 'time': '17:00', 'team1': {'name': 'Egypt', 'code': 'EGY'}, 'team2': {'name': 'Uruguay', 'code': 'URU'}, 'score1': 0, 'score2': 1, 'score1i': 0, 'score2i': 0, 'goals1': [], 'goals2': [{'name': 'Giménez', 'minute': 89, 'score1': 0, 'score2': 1}], 'group': 'Group A', 'stadium': {'key': 'ekaterinburg', 'name': 'Ekaterinburg Arena'}, 'city': 'Ekaterinburg', 'timezone': 'UTC+5'}, {'num': 3, 'date': '2018-06-15', 'time': '21:00', 'team1': {'name': 'Portugal', 'code': 'POR'}, 'team2': {'name': 'Spain', 'code': 'ESP'}, 'score1': 3, 'score2': 3, 'score1i': 2, 'score2i': 1, 'goals1': [{'name': 'Ronaldo', 'minute': 4, 'score1': 1, 'score2': 0, 'penalty': True}, {'name': 'Ronaldo', 'minute': 44, 'score1': 2, 'score2': 1}, {'name': 'Ronaldo', 'minute': 88, 'score1': 3, 'score2': 3}], 'goals2': [{'name': 'Costa', 'minute': 24, 'score1': 1, 'score2': 1}, {'name': 'Costa', 'minute': 55, 'score1': 2, 'score2': 2}, {'name': 'Nacho', 'minute': 58, 'score1': 2, 'score2': 3}], 'group': 'Group B', 'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'}, 'city': 'Sochi', 'timezone': 'UTC+3'}, {'num': 4, 'date': '2018-06-15', 'time': '18:00', 'team1': {'name': 'Morocco', 'code': 'MAR'}, 'team2': {'name': 'Iran', 'code': 'IRN'}, 'score1': 0, 'score2': 1, 'score1i': 0, 'score2i': 0, 'goals1': [], 'goals2': [{'name': 'Bouhaddouz', 'minute': 90, 'offset': 5, 'score1': 0, 'score2': 1, 'owngoal': True}], 'group': 'Group B', 'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'}, 'city': 'Saint Petersburg', 'timezone': 'UTC+3'}]
# [{'num': 5, 'date': '2018-06-16', 'time': '13:00', 'team1': {'name': 'France', 'code': 'FRA'}, 'team2': {'name': 'Australia', 'code': 'AUS'}, 'score1': 2, 'score2': 1, 'score1i': 0, 'score2i': 0, 'goals1': [{'name': 'Griezmann', 'minute': 58, 'score1': 1, 'score2': 0, 'penalty': True}, {'name': 'Behich', 'minute': 81, 'score1': 2, 'score2': 1, 'owngoal': True}], 'goals2': [{'name': 'Jedinak', 'minute': 62, 'score1': 1, 'score2': 1, 'penalty': True}], 'group': 'Group C', 'stadium': {'key': 'kazan', 'name': 'Kazan Arena'}, 'city': 'Kazan', 'timezone': 'UTC+3'}, {'num': 6, 'date': '2018-06-16', 'time': '19:00', 'team1': {'name': 'Peru', 'code': 'PER'}, 'team2': {'name': 'Denmark', 'code': 'DEN'}, 'score1': 0, 'score2': 1, 'score1i': 0, 'score2i': 0, 'goals1': [], 'goals2': [{'name': 'Poulsen', 'minute': 59, 'score1': 0, 'score2': 1}], 'group': 'Group C', 'stadium': {'key': 'mordovia', 'name': 'Mordovia Arena'}, 'city': 'Saransk', 'timezone': 'UTC+3'}, {'num': 7, 'date': '2018-06-16', 'time': '16:00', 'team1': {'name': 'Argentina', 'code': 'ARG'}, 'team2': {'name': 'Iceland', 'code': 'ISL'}, 'score1': 1, 'score2': 1, 'score1i': 1, 'score2i': 1, 'goals1': [{'name': 'Agüero', 'minute': 19, 'score1': 1, 'score2': 0}], 'goals2': [{'name': 'Finnbogason', 'minute': 23, 'score1': 1, 'score2': 1}], 'group': 'Group D', 'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'}, 'city': 'Moscow', 'timezone': 'UTC+3'}, {'num': 8, 'date': '2018-06-16', 'time': '21:00', 'team1': {'name': 'Croatia', 'code': 'CRO'}, 'team2': {'name': 'Nigeria', 'code': 'NGA'}, 'score1': 2, 'score2': 0, 'score1i': 1, 'score2i': 0, 'goals1': [{'name': 'Etebo', 'minute': 32, 'score1': 1, 'score2': 0, 'owngoal': True}, {'name': 'Modrić', 'minute': 71, 'score1': 2, 'score2': 0, 'penalty': True}], 'goals2': [], 'group': 'Group D', 'stadium': {'key': 'kaliningrad', 'name': 'Kaliningrad Stadium'}, 'city': 'Kaliningrad', 'timezone': 'UTC+2'}]
# [{'num': 9, 'date': '2018-06-17', 'time': '21:00', 'team1': {'name': 'Brazil', 'code': 'BRA'}, 'team2': {'name': 'Switzerland', 'code': 'SUI'}, 'score1': 1, 'score2': 1, 'score1i': 1, 'score2i': 0, 'goals1': [{'name': 'Coutinho', 'minute': 20, 'score1': 1, 'score2': 0}], 'goals2': [{'name': 'Zuber', 'minute': 50, 'score1': 1, 'score2': 1}], 'group': 'Group E', 'stadium': {'key': 'rostov', 'name': 'Rostov Arena'}, 'city': 'Rostov-on-Don', 'timezone': 'UTC+3'}, {'num': 10, 'date': '2018-06-17', 'time': '16:00', 'team1': {'name': 'Costa Rica', 'code': 'CRC'}, 'team2': {'name': 'Serbia', 'code': 'SRB'}, 'score1': 0, 'score2': 1, 'score1i': 0, 'score2i': 0, 'goals1': [], 'goals2': [{'name': 'Kolarov', 'minute': 56, 'score1': 0, 'score2': 1}], 'group': 'Group E', 'stadium': {'key': 'samara', 'name': 'Samara Arena'}, 'city': 'Samara', 'timezone': 'UTC+4'}, {'num': 11, 'date': '2018-06-17', 'time': '18:00', 'team1': {'name': 'Germany', 'code': 'GER'}, 'team2': {'name': 'Mexico', 'code': 'MEX'}, 'score1': 0, 'score2': 1, 'score1i': 0, 'score2i': 1, 'goals1': [], 'goals2': [{'name': 'Lozano', 'minute': 35, 'score1': 0, 'score2': 1}], 'group': 'Group F', 'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'}, 'city': 'Moscow', 'timezone': 'UTC+3'}]
# [{'num': 12, 'date': '2018-06-18', 'time': '15:00', 'team1': {'name': 'Sweden', 'code': 'SWE'}, 'team2': {'name': 'South Korea', 'code': 'KOR'}, 'score1': 1, 'score2': 0, 'score1i': 0, 'score2i': 0, 'goals1': [{'name': 'Granqvist', 'minute': 65, 'score1': 1, 'score2': 0, 'penalty': True}], 'goals2': [], 'group': 'Group F', 'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'}, 'city': 'Nizhny Novgorod', 'timezone': 'UTC+3'}, {'num': 13, 'date': '2018-06-18', 'time': '18:00', 'team1': {'name': 'Belgium', 'code': 'BEL'}, 'team2': {'name': 'Panama', 'code': 'PAN'}, 'score1': 3, 'score2': 0, 'score1i': 0, 'score2i': 0, 'goals1': [{'name': 'Mertens', 'minute': 47, 'score1': 1, 'score2': 0}, {'name': 'Lukaku', 'minute': 69, 'score1': 2, 'score2': 0}, {'name': 'Lukaku', 'minute': 75, 'score1': 3, 'score2': 0}], 'goals2': [], 'group': 'Group G', 'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'}, 'city': 'Sochi', 'timezone': 'UTC+3'}, {'num': 14, 'date': '2018-06-18', 'time': '21:00', 'team1': {'name': 'Tunisia', 'code': 'TUN'}, 'team2': {'name': 'England', 'code': 'ENG'}, 'score1': 1, 'score2': 2, 'score1i': 1, 'score2i': 1, 'goals1': [{'name': 'Sassi', 'minute': 35, 'score1': 1, 'score2': 1, 'penalty': True}], 'goals2': [{'name': 'Kane', 'minute': 11, 'score1': 0, 'score2': 1}, {'name': 'Kane', 'minute': 90, 'offset': 1, 'score1': 1, 'score2': 2}], 'group': 'Group G', 'stadium': {'key': 'volgograd', 'name': 'Volgograd Arena'}, 'city': 'Volgograd', 'timezone': 'UTC+3'}]
# [{'num': 15, 'date': '2018-06-19', 'time': '18:00', 'team1': {'name': 'Poland', 'code': 'POL'}, 'team2': {'name': 'Senegal', 'code': 'SEN'}, 'score1': 1, 'score2': 2, 'score1i': 0, 'score2i': 1, 'goals1': [{'name': 'Krychowiak', 'minute': 86, 'score1': 1, 'score2': 2}], 'goals2': [{'name': 'Cionek', 'minute': 37, 'score1': 0, 'score2': 1, 'owngoal': True}, {'name': 'Niang', 'minute': 60, 'score1': 0, 'score2': 2}], 'group': 'Group H', 'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'}, 'city': 'Moscow', 'timezone': 'UTC+3'}, {'num': 16, 'date': '2018-06-19', 'time': '15:00', 'team1': {'name': 'Colombia', 'code': 'COL'}, 'team2': {'name': 'Japan', 'code': 'JPN'}, 'score1': 1, 'score2': 2, 'score1i': 1, 'score2i': 1, 'goals1': [{'name': 'J. Quintero', 'minute': 39, 'score1': 1, 'score2': 1}], 'goals2': [{'name': 'Kagawa', 'minute': 6, 'score1': 0, 'score2': 1, 'penalty': True}, {'name': 'Osako', 'minute': 73, 'score1': 1, 'score2': 2}], 'group': 'Group H', 'stadium': {'key': 'mordovia', 'name': 'Mordovia Arena'}, 'city': 'Saransk', 'timezone': 'UTC+3'}, {'num': 17, 'date': '2018-06-19', 'time': '21:00', 'team1': {'name': 'Russia', 'code': 'RUS'}, 'team2': {'name': 'Egypt', 'code': 'EGY'}, 'score1': 3, 'score2': 1, 'score1i': 0, 'score2i': 0, 'goals1': [{'name': 'A. Fathi', 'minute': 47, 'score1': 1, 'score2': 0, 'owngoal': True}, {'name': 'Cheryshev', 'minute': 59, 'score1': 2, 'score2': 0}, {'name': 'Dzyuba', 'minute': 62, 'score1': 3, 'score2': 0}], 'goals2': [{'name': 'M. Salah', 'minute': 73, 'score1': 3, 'score2': 1, 'penalty': True}], 'group': 'Group A', 'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'}, 'city': 'Saint Petersburg', 'timezone': 'UTC+3'}]
# [{'num': 18, 'date': '2018-06-20', 'time': '18:00', 'team1': {'name': 'Uruguay', 'code': 'URU'}, 'team2': {'name': 'Saudi Arabia', 'code': 'KSA'}, 'score1': 1, 'score2': 0, 'score1i': 1, 'score2i': 0, 'goals1': [{'name': 'L. Suárez', 'minute': 23, 'score1': 1, 'score2': 0}], 'goals2': [], 'group': 'Group A', 'stadium': {'key': 'rostov', 'name': 'Rostov Arena'}, 'city': 'Rostov-on-Don', 'timezone': 'UTC+3'}, {'num': 19, 'date': '2018-06-20', 'time': '15:00', 'team1': {'name': 'Portugal', 'code': 'POR'}, 'team2': {'name': 'Morocco', 'code': 'MAR'}, 'score1': 1, 'score2': 0, 'score1i': 1, 'score2i': 0, 'goals1': [{'name': 'Ronaldo', 'minute': 4, 'score1': 1, 'score2': 0}], 'goals2': [], 'group': 'Group B', 'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'}, 'city': 'Moscow', 'timezone': 'UTC+3'}, {'num': 20, 'date': '2018-06-20', 'time': '21:00', 'team1': {'name': 'Iran', 'code': 'IRN'}, 'team2': {'name': 'Spain', 'code': 'ESP'}, 'score1': 0, 'score2': 1, 'score1i': 0, 'score2i': 0, 'goals1': [], 'goals2': [{'name': 'Diego Costa', 'minute': 54, 'score1': 0, 'score2': 1}], 'group': 'Group B', 'stadium': {'key': 'kazan', 'name': 'Kazan Arena'}, 'city': 'Kazan', 'timezone': 'UTC+3'}]
# [{'num': 21, 'date': '2018-06-21', 'time': '20:00', 'team1': {'name': 'France', 'code': 'FRA'}, 'team2': {'name': 'Peru', 'code': 'PER'}, 'score1': 1, 'score2': 0, 'score1i': 1, 'score2i': 0, 'goals1': [{'name': 'Mbappé', 'minute': 34, 'score1': 1, 'score2': 0}], 'goals2': [], 'group': 'Group C', 'stadium': {'key': 'ekaterinburg', 'name': 'Ekaterinburg Arena'}, 'city': 'Ekaterinburg', 'timezone': 'UTC+5'}, {'num': 22, 'date': '2018-06-21', 'time': '16:00', 'team1': {'name': 'Denmark', 'code': 'DEN'}, 'team2': {'name': 'Australia', 'code': 'AUS'}, 'score1': 1, 'score2': 1, 'score1i': 1, 'score2i': 1, 'goals1': [{'name': 'Eriksen', 'minute': 7, 'score1': 1, 'score2': 0}], 'goals2': [{'name': 'Jedinak', 'minute': 38, 'score1': 1, 'score2': 1, 'penalty': True}], 'group': 'Group C', 'stadium': {'key': 'samara', 'name': 'Samara Arena'}, 'city': 'Samara', 'timezone': 'UTC+4'}, {'num': 23, 'date': '2018-06-21', 'time': '21:00', 'team1': {'name': 'Argentina', 'code': 'ARG'}, 'team2': {'name': 'Croatia', 'code': 'CRO'}, 'score1': 0, 'score2': 3, 'score1i': 0, 'score2i': 0, 'goals1': [], 'goals2': [{'name': 'Rebić', 'minute': 53, 'score1': 0, 'score2': 1}, {'name': 'Modrić', 'minute': 80, 'score1': 0, 'score2': 2}, {'name': 'Rakitić', 'minute': 90, 'offset': 1, 'score1': 0, 'score2': 3}], 'group': 'Group D', 'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'}, 'city': 'Nizhny Novgorod', 'timezone': 'UTC+3'}]
# [{'num': 24, 'date': '2018-06-22', 'time': '18:00', 'team1': {'name': 'Nigeria', 'code': 'NGA'}, 'team2': {'name': 'Iceland', 'code': 'ISL'}, 'score1': 2, 'score2': 0, 'score1i': 0, 'score2i': 0, 'goals1': [{'name': 'Musa', 'minute': 49, 'score1': 1, 'score2': 0}, {'name': 'Musa', 'minute': 75, 'score1': 2, 'score2': 0}], 'goals2': [], 'group': 'Group D', 'stadium': {'key': 'volgograd', 'name': 'Volgograd Arena'}, 'city': 'Volgograd', 'timezone': 'UTC+3'}, {'num': 25, 'date': '2018-06-22', 'time': '15:00', 'team1': {'name': 'Brazil', 'code': 'BRA'}, 'team2': {'name': 'Costa Rica', 'code': 'CRC'}, 'score1': 2, 'score2': 0, 'score1i': 0, 'score2i': 0, 'group': 'Group E', 'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'}, 'city': 'Saint Petersburg', 'timezone': 'UTC+3'}, {'num': 26, 'date': '2018-06-22', 'time': '20:00', 'team1': {'name': 'Serbia', 'code': 'SRB'}, 'team2': {'name': 'Switzerland', 'code': 'SUI'}, 'score1': 1, 'score2': 2, 'score1i': 1, 'score2i': 0, 'goals1': [{'name': 'Mitrović', 'minute': 5, 'score1': 1, 'score2': 0}], 'goals2': [{'name': 'Xhaka', 'minute': 52, 'score1': 1, 'score2': 1}, {'name': 'Shaqiri', 'minute': 90, 'score1': 1, 'score2': 2}], 'group': 'Group E', 'stadium': {'key': 'kaliningrad', 'name': 'Kaliningrad Stadium'}, 'city': 'Kaliningrad', 'timezone': 'UTC+2'}]
# [{'num': 27, 'date': '2018-06-23', 'time': '21:00', 'team1': {'name': 'Germany', 'code': 'GER'}, 'team2': {'name': 'Sweden', 'code': 'SWE'}, 'score1': 2, 'score2': 1, 'score1i': 0, 'score2i': 1, 'goals1': [{'name': 'Reus', 'minute': 48, 'score1': 1, 'score2': 1}, {'name': 'Kroos', 'minute': 90, 'offset': 5, 'score1': 2, 'score2': 1}], 'goals2': [{'name': 'Toivonen', 'minute': 32, 'score1': 0, 'score2': 1}], 'group': 'Group F', 'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'}, 'city': 'Sochi', 'timezone': 'UTC+3'}, {'num': 28, 'date': '2018-06-23', 'time': '18:00', 'team1': {'name': 'South Korea', 'code': 'KOR'}, 'team2': {'name': 'Mexico', 'code': 'MEX'}, 'score1': 1, 'score2': 2, 'score1i': 0, 'score2i': 1, 'goals1': [{'name': 'Son Heung-min', 'minute': 90, 'offset': 3, 'score1': 1, 'score2': 2}], 'goals2': [{'name': 'Carlos V.', 'minute': 26, 'score1': 0, 'score2': 1, 'penalty': True}, {'name': 'J. Hernández', 'minute': 66, 'score1': 0, 'score2': 2}], 'group': 'Group F', 'stadium': {'key': 'rostov', 'name': 'Rostov Arena'}, 'city': 'Rostov-on-Don', 'timezone': 'UTC+3'}, {'num': 29, 'date': '2018-06-23', 'time': '15:00', 'team1': {'name': 'Belgium', 'code': 'BEL'}, 'team2': {'name': 'Tunisia', 'code': 'TUN'}, 'score1': 5, 'score2': 2, 'score1i': 3, 'score2i': 1, 'goals1': [{'name': 'E. Hazard', 'minute': 6, 'score1': 1, 'score2': 0, 'penalty': True}, {'name': 'R. Lukaku', 'minute': 16, 'score1': 2, 'score2': 0}, {'name': 'R. Lukaku', 'minute': 45, 'offset': 3, 'score1': 3, 'score2': 1}, {'name': 'E. Hazard', 'minute': 51, 'score1': 4, 'score2': 1}, {'name': 'Batshuayi', 'minute': 90, 'score1': 5, 'score2': 1}], 'goals2': [{'name': 'Bronn', 'minute': 18, 'score1': 2, 'score2': 1}, {'name': 'Khazri', 'minute': 90, 'offset': 3, 'score1': 5, 'score2': 2}], 'group': 'Group G', 'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'}, 'city': 'Moscow', 'timezone': 'UTC+3'}]
# [{'num': 30, 'date': '2018-06-24', 'time': '15:00', 'team1': {'name': 'England', 'code': 'ENG'}, 'team2': {'name': 'Panama', 'code': 'PAN'}, 'score1': 6, 'score2': 1, 'score1i': 5, 'score2i': 0, 'goals1': [{'name': 'Stones', 'minute': 8, 'score1': 1, 'score2': 0}, {'name': 'Kane', 'minute': 22, 'score1': 2, 'score2': 0, 'penalty': True}, {'name': 'Lingard', 'minute': 36, 'score1': 3, 'score2': 0}, {'name': 'Stones', 'minute': 40, 'score1': 4, 'score2': 0}, {'name': 'Kane', 'minute': 45, 'offset': 1, 'score1': 5, 'score2': 0, 'penalty': True}, {'name': 'Kane', 'minute': 62, 'score1': 6, 'score2': 0}], 'goals2': [{'name': 'Baloy', 'minute': 78, 'score1': 6, 'score2': 1}], 'group': 'Group G', 'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'}, 'city': 'Nizhny Novgorod', 'timezone': 'UTC+3'}, {'num': 31, 'date': '2018-06-24', 'time': '21:00', 'team1': {'name': 'Poland', 'code': 'POL'}, 'team2': {'name': 'Colombia', 'code': 'COL'}, 'score1': 0, 'score2': 3, 'score1i': 0, 'score2i': 1, 'goals1': [], 'goals2': [{'name': 'Y. Mina', 'minute': 40, 'score1': 0, 'score2': 1}, {'name': 'Falcao', 'minute': 70, 'score1': 0, 'score2': 2}, {'name': 'Cuadrado', 'minute': 75, 'score1': 0, 'score2': 3}], 'group': 'Group H', 'stadium': {'key': 'kazan', 'name': 'Kazan Arena'}, 'city': 'Kazan', 'timezone': 'UTC+3'}, {'num': 32, 'date': '2018-06-24', 'time': '20:00', 'team1': {'name': 'Japan', 'code': 'JPN'}, 'team2': {'name': 'Senegal', 'code': 'SEN'}, 'score1': 2, 'score2': 2, 'score1i': 1, 'score2i': 1, 'goals1': [{'name': 'Inui', 'minute': 34, 'score1': 1, 'score2': 1}, {'name': 'Honda', 'minute': 78, 'score1': 2, 'score2': 2}], 'goals2': [{'name': 'Mané', 'minute': 11, 'score1': 0, 'score2': 1}, {'name': 'M. Wagué', 'minute': 71, 'score1': 1, 'score2': 2}], 'group': 'Group H', 'stadium': {'key': 'ekaterinburg', 'name': 'Ekaterinburg Arena'}, 'city': 'Ekaterinburg', 'timezone': 'UTC+5'}]
# [{'num': 33, 'date': '2018-06-25', 'time': '18:00', 'team1': {'name': 'Uruguay', 'code': 'URU'}, 'team2': {'name': 'Russia', 'code': 'RUS'}, 'score1': 3, 'score2': 0, 'score1i': 2, 'score2i': 0, 'goals1': [{'name': 'L. Suárez', 'minute': 10, 'score1': 1, 'score2': 0}, {'name': 'Cheryshev', 'minute': 23, 'score1': 2, 'score2': 0, 'owngoal': True}, {'name': 'E. Cavani', 'minute': 90, 'score1': 3, 'score2': 0}], 'goals2': [], 'group': 'Group A', 'stadium': {'key': 'samara', 'name': 'Samara Arena'}, 'city': 'Samara', 'timezone': 'UTC+4'}, {'num': 34, 'date': '2018-06-25', 'time': '17:00', 'team1': {'name': 'Saudi Arabia', 'code': 'KSA'}, 'team2': {'name': 'Egypt', 'code': 'EGY'}, 'score1': 2, 'score2': 1, 'score1i': 1, 'score2i': 1, 'goals1': [{'name': 'Salman Al-Faraj', 'minute': 45, 'offset': 6, 'score1': 1, 'score2': 1, 'penalty': True}, {'name': 'Salem Al-Dawsari', 'minute': 90, 'offset': 5, 'score1': 2, 'score2': 1}], 'goals2': [{'name': 'M. Salah', 'minute': 22, 'score1': 0, 'score2': 1}], 'group': 'Group A', 'stadium': {'key': 'volgograd', 'name': 'Volgograd Arena'}, 'city': 'Volgograd', 'timezone': 'UTC+3'}, {'num': 35, 'date': '2018-06-25', 'time': '21:00', 'team1': {'name': 'Iran', 'code': 'IRN'}, 'team2': {'name': 'Portugal', 'code': 'POR'}, 'score1': 1, 'score2': 1, 'score1i': 0, 'score2i': 1, 'goals1': [{'name': 'Karim Ansarifard', 'minute': 90, 'offset': 3, 'score1': 1, 'score2': 1, 'penalty': True}], 'goals2': [{'name': 'Quaresma', 'minute': 45, 'score1': 0, 'score2': 1}], 'group': 'Group B', 'stadium': {'key': 'mordovia', 'name': 'Mordovia Arena'}, 'city': 'Saransk', 'timezone': 'UTC+3'}, {'num': 36, 'date': '2018-06-25', 'time': '20:00', 'team1': {'name': 'Spain', 'code': 'ESP'}, 'team2': {'name': 'Morocco', 'code': 'MAR'}, 'score1': 2, 'score2': 2, 'score1i': 1, 'score2i': 1, 'goals1': [{'name': 'Isco', 'minute': 19, 'score1': 1, 'score2': 1}, {'name': 'Iago Aspas', 'minute': 90, 'offset': 1, 'score1': 2, 'score2': 2}], 'goals2': [{'name': 'Boutaib', 'minute': 14, 'score1': 0, 'score2': 1}, {'name': 'En-Nesyri', 'minute': 81, 'score1': 1, 'score2': 2}], 'group': 'Group B', 'stadium': {'key': 'kaliningrad', 'name': 'Kaliningrad Stadium'}, 'city': 'Kaliningrad', 'timezone': 'UTC+2'}]
# [{'num': 37, 'date': '2018-06-26', 'time': '17:00', 'team1': {'name': 'Denmark', 'code': 'DEN'}, 'team2': {'name': 'France', 'code': 'FRA'}, 'score1': 0, 'score2': 0, 'score1i': 0, 'score2i': 0, 'group': 'Group C', 'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'}, 'city': 'Moscow', 'timezone': 'UTC+3'}, {'num': 38, 'date': '2018-06-26', 'time': '17:00', 'team1': {'name': 'Australia', 'code': 'AUS'}, 'team2': {'name': 'Peru', 'code': 'PER'}, 'score1': 0, 'score2': 2, 'score1i': 0, 'score2i': 1, 'goals1': [], 'goals2': [{'name': 'Carrillo', 'minute': 18, 'score1': 0, 'score2': 1}, {'name': 'Guerrero', 'minute': 50, 'score1': 0, 'score2': 2}], 'group': 'Group C', 'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'}, 'city': 'Sochi', 'timezone': 'UTC+3'}, {'num': 39, 'date': '2018-06-26', 'time': '21:00', 'team1': {'name': 'Nigeria', 'code': 'NGA'}, 'team2': {'name': 'Argentina', 'code': 'ARG'}, 'score1': 1, 'score2': 2, 'score1i': 0, 'score2i': 1, 'goals1': [{'name': 'Moses', 'minute': 51, 'score1': 1, 'score2': 1, 'penalty': True}], 'goals2': [{'name': 'Messi', 'minute': 14, 'score1': 0, 'score2': 1}, {'name': 'Marcos Rojo', 'minute': 86, 'score1': 1, 'score2': 2}], 'group': 'Group D', 'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'}, 'city': 'Saint Petersburg', 'timezone': 'UTC+3'}, {'num': 40, 'date': '2018-06-26', 'time': '21:00', 'team1': {'name': 'Iceland', 'code': 'ISL'}, 'team2': {'name': 'Croatia', 'code': 'CRO'}, 'score1': 1, 'score2': 2, 'score1i': 0, 'score2i': 0, 'goals1': [{'name': 'G. Sigurðsson', 'minute': 76, 'score1': 1, 'score2': 1, 'penalty': True}], 'goals2': [{'name': 'Badelj', 'minute': 53, 'score1': 0, 'score2': 1}, {'name': 'Perišić', 'minute': 90, 'score1': 1, 'score2': 2}], 'group': 'Group D', 'stadium': {'key': 'rostov', 'name': 'Rostov Arena'}, 'city': 'Rostov-on-Don', 'timezone': 'UTC+3'}]
# [{'num': 41, 'date': '2018-06-27', 'time': '21:00', 'team1': {'name': 'Serbia', 'code': 'SRB'}, 'team2': {'name': 'Brazil', 'code': 'BRA'}, 'score1': 0, 'score2': 2, 'score1i': 0, 'score2i': 1, 'goals1': [], 'goals2': [{'name': 'Paulinho', 'minute': 36, 'score1': 0, 'score2': 1}, {'name': 'Thiago Silva', 'minute': 68, 'score1': 0, 'score2': 2}], 'group': 'Group E', 'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'}, 'city': 'Moscow', 'timezone': 'UTC+3'}, {'num': 42, 'date': '2018-06-27', 'time': '21:00', 'team1': {'name': 'Switzerland', 'code': 'SUI'}, 'team2': {'name': 'Costa Rica', 'code': 'CRC'}, 'score1': 2, 'score2': 2, 'score1i': 1, 'score2i': 0, 'goals1': [{'name': 'Džemaili', 'minute': 31, 'score1': 1, 'score2': 0}, {'name': 'Drmić', 'minute': 88, 'score1': 2, 'score2': 1}], 'goals2': [{'name': 'Waston', 'minute': 56, 'score1': 1, 'score2': 1}, {'name': 'Sommer', 'minute': 90, 'offset': 3, 'score1': 2, 'score2': 2, 'owngoal': True}], 'group': 'Group E', 'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'}, 'city': 'Nizhny Novgorod', 'timezone': 'UTC+3'}, {'num': 43, 'date': '2018-06-27', 'time': '17:00', 'team1': {'name': 'South Korea', 'code': 'KOR'}, 'team2': {'name': 'Germany', 'code': 'GER'}, 'score1': 2, 'score2': 0, 'score1i': 0, 'score2i': 0, 'goals1': [{'name': 'Kim Young-gwon', 'minute': 90, 'offset': 2, 'score1': 1, 'score2': 0}, {'name': 'Son Heung-min', 'minute': 90, 'offset': 6, 'score1': 2, 'score2': 0}], 'goals2': [], 'group': 'Group F', 'stadium': {'key': 'kazan', 'name': 'Kazan Arena'}, 'city': 'Kazan', 'timezone': 'UTC+3'}, {'num': 44, 'date': '2018-06-27', 'time': '19:00', 'team1': {'name': 'Mexico', 'code': 'MEX'}, 'team2': {'name': 'Sweden', 'code': 'SWE'}, 'score1': 0, 'score2': 3, 'score1i': 0, 'score2i': 0, 'goals1': [], 'goals2': [{'name': 'Augustinsson', 'minute': 50, 'score1': 0, 'score2': 1}, {'name': 'Granqvist', 'minute': 62, 'score1': 0, 'score2': 2, 'penalty': True}, {'name': 'Álvarez', 'minute': 74, 'score1': 0, 'score2': 3, 'owngoal': True}], 'group': 'Group F', 'stadium': {'key': 'ekaterinburg', 'name': 'Ekaterinburg Arena'}, 'city': 'Ekaterinburg', 'timezone': 'UTC+5'}]
# [{'num': 45, 'date': '2018-06-28', 'time': '20:00', 'team1': {'name': 'England', 'code': 'ENG'}, 'team2': {'name': 'Belgium', 'code': 'BEL'}, 'score1': 0, 'score2': 1, 'score1i': 0, 'score2i': 0, 'goals1': [], 'goals2': [{'name': 'Adnan Januzaj', 'minute': 51, 'score1': 0, 'score2': 1}], 'group': 'Group G', 'stadium': {'key': 'kaliningrad', 'name': 'Kaliningrad Stadium'}, 'city': 'Kaliningrad', 'timezone': 'UTC+2'}, {'num': 46, 'date': '2018-06-28', 'time': '21:00', 'team1': {'name': 'Panama', 'code': 'PAN'}, 'team2': {'name': 'Tunisia', 'code': 'TUN'}, 'score1': 1, 'score2': 2, 'score1i': 1, 'score2i': 0, 'goals1': [{'name': 'Yassine Meriah', 'minute': 33, 'score1': 1, 'score2': 0, 'owngoal': True}], 'goals2': [{'name': 'Fakhereedine Ben Youssef', 'minute': 51, 'score1': 1, 'score2': 1}, {'name': 'Wahbi Khazri', 'minute': 66, 'score1': 1, 'score2': 2}], 'group': 'Group G', 'stadium': {'key': 'mordovia', 'name': 'Mordovia Arena'}, 'city': 'Saransk', 'timezone': 'UTC+3'}, {'num': 47, 'date': '2018-06-28', 'time': '17:00', 'team1': {'name': 'Japan', 'code': 'JPN'}, 'team2': {'name': 'Poland', 'code': 'POL'}, 'score1': 0, 'score2': 1, 'score1i': 0, 'score2i': 1, 'goals1': [], 'goals2': [{'name': 'Bednarek', 'minute': 59, 'score1': 0, 'score2': 1}], 'group': 'Group H', 'stadium': {'key': 'volgograd', 'name': 'Volgograd Arena'}, 'city': 'Volgograd', 'timezone': 'UTC+3'}, {'num': 48, 'date': '2018-06-28', 'time': '18:00', 'team1': {'name': 'Senegal', 'code': 'SEN'}, 'team2': {'name': 'Colombia', 'code': 'COL'}, 'score1': 0, 'score2': 1, 'score1i': 0, 'score2i': 1, 'goals1': [], 'goals2': [{'name': 'Y. Mina', 'minute': 74, 'score1': 0, 'score2': 1}], 'group': 'Group H', 'stadium': {'key': 'samara', 'name': 'Samara Arena'}, 'city': 'Samara', 'timezone': 'UTC+4'}]
# [{'num': 49, 'date': '2018-06-30', 'time': '21:00', 'team1': {'name': 'Uruguay', 'code': 'URU'}, 'team2': {'name': 'Portugal', 'code': 'POR'}, 'score1': 2, 'score2': 1, 'score1i': 1, 'score2i': 0, 'score1et': None, 'score2et': None, 'score1p': None, 'score2p': None, 'knockout': True, 'goals1': [{'name': 'Edinson Cavani', 'minute': 7, 'score1': 1, 'score2': 0}, {'name': 'Edinson Cavani', 'minute': 62, 'score1': 2, 'score2': 1}], 'goals2': [{'name': 'Pepe', 'minute': 55, 'score1': 1, 'score2': 1}], 'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'}, 'city': 'Sochi', 'timezone': 'UTC+3'}, {'num': 50, 'date': '2018-06-30', 'time': '17:00', 'team1': {'name': 'France', 'code': 'FRA'}, 'team2': {'name': 'Argentina', 'code': 'ARG'}, 'score1': 4, 'score2': 3, 'score1i': 1, 'score2i': 1, 'score1et': None, 'score2et': None, 'score1p': None, 'score2p': None, 'knockout': True, 'goals1': [{'name': 'Antoine Griezmann', 'minute': 13, 'score1': 1, 'score2': 0, 'penalty': True}, {'name': 'Benjamin Pavard', 'minute': 57, 'score1': 2, 'score2': 2}, {'name': 'Kylian Mbappé', 'minute': 64, 'score1': 3, 'score2': 2}, {'name': 'Kylian Mbappé', 'minute': 68, 'score1': 4, 'score2': 2}], 'goals2': [{'name': 'Ángel Di María', 'minute': 41, 'score1': 1, 'score2': 1}, {'name': 'Gabriel Mercado', 'minute': 48, 'score1': 1, 'score2': 2}, {'name': 'Sergio Agüero', 'minute': 90, 'offset': 3, 'score1': 4, 'score2': 3}], 'stadium': {'key': 'kazan', 'name': 'Kazan Arena'}, 'city': 'Kazan', 'timezone': 'UTC+3'}, {'num': 51, 'date': '2018-07-01', 'time': '17:00', 'team1': {'name': 'Spain', 'code': 'ESP'}, 'team2': {'name': 'Russia', 'code': 'RUS'}, 'score1': 1, 'score2': 1, 'score1i': 1, 'score2i': 1, 'score1et': 1, 'score2et': 1, 'score1p': 3, 'score2p': 4, 'knockout': True, 'goals1': [{'name': 'Sergei Ignashevich', 'minute': 12, 'score1': 1, 'score2': 0, 'owngoal': True}], 'goals2': [{'name': 'Artem Dzyuba', 'minute': 41, 'score1': 1, 'score2': 1, 'penalty': True}], 'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'}, 'city': 'Moscow', 'timezone': 'UTC+3'}, {'num': 52, 'date': '2018-07-01', 'time': '21:00', 'team1': {'name': 'Croatia', 'code': 'CRO'}, 'team2': {'name': 'Denmark', 'code': 'DEN'}, 'score1': 1, 'score2': 1, 'score1i': 1, 'score2i': 1, 'score1et': 1, 'score2et': 1, 'score1p': 3, 'score2p': 2, 'knockout': True, 'goals1': [{'name': 'Mario Mandžukić', 'minute': 4, 'score1': 1, 'score2': 1}], 'goals2': [{'name': 'Mathias Jørgensen', 'minute': 1, 'score1': 0, 'score2': 1}], 'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'}, 'city': 'Nizhny Novgorod', 'timezone': 'UTC+3'}, {'num': 53, 'date': '2018-07-02', 'time': '18:00', 'team1': {'name': 'Brazil', 'code': 'BRA'}, 'team2': {'name': 'Mexico', 'code': 'MEX'}, 'score1': 2, 'score2': 0, 'score1i': 0, 'score2i': 0, 'score1et': None, 'score2et': None, 'score1p': None, 'score2p': None, 'knockout': True, 'goals1': [{'name': 'Neymar', 'minute': 51, 'score1': 1, 'score2': 0}, {'name': 'Roberto Firmino', 'minute': 88, 'score1': 2, 'score2': 0}], 'goals2': [], 'stadium': {'key': 'samara', 'name': 'Samara Arena'}, 'city': 'Samara', 'timezone': 'UTC+4'}, {'num': 54, 'date': '2018-07-02', 'time': '21:00', 'team1': {'name': 'Belgium', 'code': 'BEL'}, 'team2': {'name': 'Japan', 'code': 'JPN'}, 'score1': 3, 'score2': 2, 'score1i': 0, 'score2i': 0, 'score1et': None, 'score2et': None, 'score1p': None, 'score2p': None, 'knockout': True, 'goals1': [{'name': 'Jan Vertonghen', 'minute': 69, 'score1': 1, 'score2': 2}, {'name': 'Marouane Fellaini', 'minute': 74, 'score1': 2, 'score2': 2}, {'name': 'Nacer Chadli', 'minute': 90, 'offset': 4, 'score1': 3, 'score2': 2}], 'goals2': [{'name': 'Genki Haraguchi', 'minute': 48, 'score1': 0, 'score2': 1}, {'name': 'Takashi Inui', 'minute': 52, 'score1': 0, 'score2': 2}], 'stadium': {'key': 'rostov', 'name': 'Rostov Arena'}, 'city': 'Rostov-on-Don', 'timezone': 'UTC+3'}, {'num': 55, 'date': '2018-07-03', 'time': '17:00', 'team1': {'name': 'Sweden', 'code': 'SW ...
# [{'num': 57, 'date': '2018-07-06', 'time': '17:00', 'team1': {'name': 'Uruguay', 'code': 'URU'}, 'team2': {'name': 'France', 'code': 'FRA'}, 'score1': 0, 'score2': 2, 'score1i': 0, 'score2i': 1, 'score1et': None, 'score2et': None, 'score1p': None, 'score2p': None, 'knockout': True, 'goals1': [], 'goals2': [{'name': 'Raphaël Varane', 'minute': 40, 'score1': 0, 'score2': 1}, {'name': 'Antoine Griezmann', 'minute': 61, 'score1': 0, 'score2': 2}], 'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'}, 'city': 'Nizhny Novgorod', 'timezone': 'UTC+3'}, {'num': 58, 'date': '2018-07-06', 'time': '21:00', 'team1': {'name': 'Brazil', 'code': 'BRA'}, 'team2': {'name': 'Belgium', 'code': 'BEL'}, 'score1': 1, 'score2': 2, 'score1i': 0, 'score2i': 2, 'score1et': None, 'score2et': None, 'score1p': None, 'score2p': None, 'knockout': True, 'goals1': [{'name': 'Renato Augusto', 'minute': 76, 'score1': 1, 'score2': 2}], 'goals2': [{'name': 'Fernandinho', 'minute': 13, 'score1': 0, 'score2': 1, 'owngoal': True}, {'name': 'Kevin De Bruyne', 'minute': 31, 'score1': 0, 'score2': 2}], 'stadium': {'key': 'kazan', 'name': 'Kazan Arena'}, 'city': 'Kazan', 'timezone': 'UTC+3'}, {'num': 59, 'date': '2018-07-07', 'time': '21:00', 'team1': {'name': 'Russia', 'code': 'RUS'}, 'team2': {'name': 'Croatia', 'code': 'CRO'}, 'score1': 1, 'score2': 1, 'score1i': 1, 'score2i': 1, 'score1et': 2, 'score2et': 2, 'score1p': 3, 'score2p': 4, 'knockout': True, 'goals1': [{'name': 'Denis Cheryshev', 'minute': 31, 'score1': 1, 'score2': 0}, {'name': 'Mário Figueira Fernandes', 'minute': 115, 'score1': 2, 'score2': 2}], 'goals2': [{'name': 'Andrej Kramarić', 'minute': 39, 'score1': 1, 'score2': 1}, {'name': 'Domagoj Vida', 'minute': 100, 'score1': 1, 'score2': 2}], 'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'}, 'city': 'Sochi', 'timezone': 'UTC+3'}, {'num': 60, 'date': '2018-07-07', 'time': '18:00', 'team1': {'name': 'Sweden', 'code': 'SWE'}, 'team2': {'name': 'England', 'code': 'ENG'}, 'score1': 0, 'score2': 2, 'score1i': 0, 'score2i': 1, 'score1et': None, 'score2et': None, 'score1p': None, 'score2p': None, 'knockout': True, 'goals1': [], 'goals2': [{'name': 'Harry Maguire', 'minute': 30, 'score1': 0, 'score2': 1}, {'name': 'Dele Alli', 'minute': 58, 'score1': 0, 'score2': 2}], 'stadium': {'key': 'samara', 'name': 'Samara Arena'}, 'city': 'Samara', 'timezone': 'UTC+4'}]
# [{'num': 61, 'date': '2018-07-10', 'time': '21:00', 'team1': {'name': 'France', 'code': 'FRA'}, 'team2': {'name': 'Belgium', 'code': 'BEL'}, 'score1': 1, 'score2': 0, 'score1i': 0, 'score2i': 0, 'score1et': None, 'score2et': None, 'score1p': None, 'score2p': None, 'knockout': True, 'goals1': [{'name': 'Samuel Umtiti', 'minute': 51, 'score1': 1, 'score2': 0}], 'goals2': [], 'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'}, 'city': 'Saint Petersburg', 'timezone': 'UTC+3'}, {'num': 62, 'date': '2018-07-11', 'time': '21:00', 'team1': {'name': 'Croatia', 'code': 'CRO'}, 'team2': {'name': 'England', 'code': 'ENG'}, 'score1': 1, 'score2': 1, 'score1i': 0, 'score2i': 1, 'score1et': 2, 'score2et': 1, 'score1p': None, 'score2p': None, 'knockout': True, 'goals1': [{'name': 'Ivan Perišić', 'minute': 68, 'score1': 1, 'score2': 1}, {'name': 'Mario Mandžukić', 'minute': 109, 'score1': 2, 'score2': 1}], 'goals2': [{'name': 'Kieran Trippier', 'minute': 5, 'score1': 0, 'score2': 1}], 'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'}, 'city': 'Moscow', 'timezone': 'UTC+3'}]
# [{'num': 63, 'date': '2018-07-14', 'time': '17:00', 'team1': {'name': 'Belgium', 'code': 'BEL'}, 'team2': {'name': 'England', 'code': 'ENG'}, 'score1': 2, 'score2': 0, 'score1i': 1, 'score2i': 0, 'score1et': None, 'score2et': None, 'score1p': None, 'score2p': None, 'knockout': True, 'goals1': [{'name': 'Thomas Meunier', 'minute': 4, 'score1': 1, 'score2': 0}, {'name': 'Eden Hazard', 'minute': 82, 'score1': 2, 'score2': 0}], 'goals2': [], 'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'}, 'city': 'Saint Petersburg', 'timezone': 'UTC+3'}]
# [{'num': 64, 'date': '2018-07-15', 'time': '18:00', 'team1': {'name': 'France', 'code': 'FRA'}, 'team2': {'name': 'Croatia', 'code': 'CRO'}, 'score1': 4, 'score2': 2, 'score1i': 2, 'score2i': 1, 'score1et': None, 'score2et': None, 'score1p': None, 'score2p': None, 'knockout': True, 'goals1': [{'name': 'Mario Mandžukić', 'minute': 18, 'score1': 1, 'score2': 0, 'owngoal': True}, {'name': 'Griezmann', 'minute': 38, 'score1': 2, 'score2': 1, 'penalty': True}, {'name': 'Pogba', 'minute': 59, 'score1': 3, 'score2': 1}, {'name': 'Mbappé', 'minute': 65, 'score1': 4, 'score2': 1}], 'goals2': [{'name': 'Perišić', 'minute': 28, 'score1': 1, 'score2': 1}, {'name': 'Mario Mandžukić', 'minute': 69, 'score1': 4, 'score2': 2}], 'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'}, 'city': 'Moscow', 'timezone': 'UTC+3'}]

# %%
# Replace None with appropriate code
matches = []

# "round" is a built-in function in Python so we use "round_" instead
for round in rounds:
    # Extract the list of matches for this round
    round_matches = round['matches']
    # Add them to the overall list of matches
    matches.extend(round_matches)
matches
# Out:
# [{'num': 1,
#   'date': '2018-06-14',
#   'time': '18:00',
#   'team1': {'name': 'Russia', 'code': 'RUS'},
#   'team2': {'name': 'Saudi Arabia', 'code': 'KSA'},
#   'score1': 5,
#   'score2': 0,
#   'score1i': 2,
#   'score2i': 0,
#   'goals1': [{'name': 'Gazinsky', 'minute': 12, 'score1': 1, 'score2': 0},
#    {'name': 'Cheryshev', 'minute': 43, 'score1': 2, 'score2': 0},
#    {'name': 'Dzyuba', 'minute': 71, 'score1': 3, 'score2': 0},
#    {'name': 'Cheryshev', 'minute': 90, 'offset': 1, 'score1': 4, 'score2': 0},
#    {'name': 'Golovin', 'minute': 90, 'offset': 4, 'score1': 5, 'score2': 0}],
#   'goals2': [],
#   'group': 'Group A',
#   'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#   'city': 'Moscow',
#   'timezone': 'UTC+3'},
#  {'num': 2,
#   'date': '2018-06-15',
#   'time': '17:00',
#   'team1': {'name': 'Egypt', 'code': 'EGY'},
#   'team2': {'name': 'Uruguay', 'code': 'URU'},
#   'score1': 0,
#   'score2': 1,
#   'score1i': 0,
#   'score2i': 0,
#   'goals1': [],
#   'goals2': [{'name': 'Giménez', 'minute': 89, 'score1': 0, 'score2': 1}],
#   'group': 'Group A',
#   'stadium': {'key': 'ekaterinburg', 'name': 'Ekaterinburg Arena'},
#   'city': 'Ekaterinburg',
#   'timezone': 'UTC+5'},
#  {'num': 3,
#   'date': '2018-06-15',
#   'time': '21:00',
#   'team1': {'name': 'Portugal', 'code': 'POR'},
#   'team2': {'name': 'Spain', 'code': 'ESP'},
#   'score1': 3,
#   'score2': 3,
#   'score1i': 2,
#   'score2i': 1,
#   'goals1': [{'name': 'Ronaldo',
#     'minute': 4,
#     'score1': 1,
#     'score2': 0,
#     'penalty': True},
#    {'name': 'Ronaldo', 'minute': 44, 'score1': 2, 'score2': 1},
#    {'name': 'Ronaldo', 'minute': 88, 'score1': 3, 'score2': 3}],
#   'goals2': [{'name': 'Costa', 'minute': 24, 'score1': 1, 'score2': 1},
#    {'name': 'Costa', 'minute': 55, 'score1': 2, 'score2': 2},
#    {'name': 'Nacho', 'minute': 58, 'score1': 2, 'score2': 3}],
#   'group': 'Group B',
#   'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#   'city': 'Sochi',
#   'timezone': 'UTC+3'},
#  {'num': 4,
#   'date': '2018-06-15',
#   'time': '18:00',
#   'team1': {'name': 'Morocco', 'code': 'MAR'},
#   'team2': {'name': 'Iran', 'code': 'IRN'},
#   'score1': 0,
#   'score2': 1,
#   'score1i': 0,
#   'score2i': 0,
#   'goals1': [],
#   'goals2': [{'name': 'Bouhaddouz',
#     'minute': 90,
#     'offset': 5,
#     'score1': 0,
#     'score2': 1,
#     'owngoal': True}],
#   'group': 'Group B',
#   'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#   'city': 'Saint Petersburg',
#   'timezone': 'UTC+3'},
#  {'num': 5,
#   'date': '2018-06-16',
#   'time': '13:00',
#   'team1': {'name': 'France', 'code': 'FRA'},
#   'team2': {'name': 'Australia', 'code': 'AUS'},
#   'score1': 2,
#   'score2': 1,
#   'score1i': 0,
#   'score2i': 0,
#   'goals1': [{'name': 'Griezmann',
#     'minute': 58,
#     'score1': 1,
#     'score2': 0,
#     'penalty': True},
#    {'name': 'Behich',
#     'minute': 81,
#     'score1': 2,
#     'score2': 1,
#     'owngoal': True}],
#   'goals2': [{'name': 'Jedinak',
#     'minute': 62,
#     'score1': 1,
#     'score2': 1,
#     'penalty': True}],
#   'group': 'Group C',
#   'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#   'city': 'Kazan',
#   'timezone': 'UTC+3'},
#  {'num': 6,
#   'date': '2018-06-16',
#   'time': '19:00',
#   'team1': {'name': 'Peru', 'code': 'PER'},
#   'team2': {'name': 'Denmark', 'code': 'DEN'},
#   'score1': 0,
#   'score2': 1,
#   'score1i': 0,
#   'score2i': 0,
#   'goals1': [],
#   'goals2': [{'name': 'Poulsen', 'minute': 59, 'score1': 0, 'score2': 1}],
#   'group': 'Group C',
#   'stadium': {'key': 'mordovia', 'name': 'Mordovia Arena'},
#   'city': 'Saransk',
#   'timezone': 'UTC+3'},
#  {'num': 7,
#   'date': '2018-06-16',
#   'time': '16:00',
#   'team1': {'name': 'Argentina', 'code': 'ARG'},
#   'team2': {'name': 'Iceland', 'code': 'ISL'},
#   'score1': 1,
#   'score2': 1,
#   'score1i': 1,
#   'score2i': 1,
#   'goals1': [{'name': 'Agüero', 'minute': 19, 'score1': 1, 'score2': 0}],
#   'goals2': [{'name': 'Finnbogason', 'minute': 23, 'score1': 1, 'score2': 1}],
#   'group': 'Group D',
#   'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'},
#   'city': 'Moscow',
#   'timezone': 'UTC+3'},
#  {'num': 8,
#   'date': '2018-06-16',
#   'time': '21:00',
#   'team1': {'name': 'Croatia', 'code': 'CRO'},
#   'team2': {'name': 'Nigeria', 'code': 'NGA'},
#   'score1': 2,
#   'score2': 0,
#   'score1i': 1,
#   'score2i': 0,
#   'goals1': [{'name': 'Etebo',
#     'minute': 32,
#     'score1': 1,
#     'score2': 0,
#     'owngoal': True},
#    {'name': 'Modrić',
#     'minute': 71,
#     'score1': 2,
#     'score2': 0,
#     'penalty': True}],
#   'goals2': [],
#   'group': 'Group D',
#   'stadium': {'key': 'kaliningrad', 'name': 'Kaliningrad Stadium'},
#   'city': 'Kaliningrad',
#   'timezone': 'UTC+2'},
#  {'num': 9,
#   'date': '2018-06-17',
#   'time': '21:00',
#   'team1': {'name': 'Brazil', 'code': 'BRA'},
#   'team2': {'name': 'Switzerland', 'code': 'SUI'},
#   'score1': 1,
#   'score2': 1,
#   'score1i': 1,
#   'score2i': 0,
#   'goals1': [{'name': 'Coutinho', 'minute': 20, 'score1': 1, 'score2': 0}],
#   'goals2': [{'name': 'Zuber', 'minute': 50, 'score1': 1, 'score2': 1}],
#   'group': 'Group E',
#   'stadium': {'key': 'rostov', 'name': 'Rostov Arena'},
#   'city': 'Rostov-on-Don',
#   'timezone': 'UTC+3'},
#  {'num': 10,
#   'date': '2018-06-17',
#   'time': '16:00',
#   'team1': {'name': 'Costa Rica', 'code': 'CRC'},
#   'team2': {'name': 'Serbia', 'code': 'SRB'},
#   'score1': 0,
#   'score2': 1,
#   'score1i': 0,
#   'score2i': 0,
#   'goals1': [],
#   'goals2': [{'name': 'Kolarov', 'minute': 56, 'score1': 0, 'score2': 1}],
#   'group': 'Group E',
#   'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#   'city': 'Samara',
#   'timezone': 'UTC+4'},
#  {'num': 11,
#   'date': '2018-06-17',
#   'time': '18:00',
#   'team1': {'name': 'Germany', 'code': 'GER'},
#   'team2': {'name': 'Mexico', 'code': 'MEX'},
#   'score1': 0,
#   'score2': 1,
#   'score1i': 0,
#   'score2i': 1,
#   'goals1': [],
#   'goals2': [{'name': 'Lozano', 'minute': 35, 'score1': 0, 'score2': 1}],
#   'group': 'Group F',
#   'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#   'city': 'Moscow',
#   'timezone': 'UTC+3'},
#  {'num': 12,
#   'date': '2018-06-18',
#   'time': '15:00',
#   'team1': {'name': 'Sweden', 'code': 'SWE'},
#   'team2': {'name': 'South Korea', 'code': 'KOR'},
#   'score1': 1,
#   'score2': 0,
#   'score1i': 0,
#   'score2i': 0,
#   'goals1': [{'name': 'Granqvist',
#     'minute': 65,
#     'score1': 1,
#     'score2': 0,
#     'penalty': True}],
#   'goals2': [],
#   'group': 'Group F',
#   'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'},
#   'city': 'Nizhny Novgorod',
#   'timezone': 'UTC+3'},
#  {'num': 13,
#   'date': '2018-06-18',
#   'time': '18:00',
#   'team1': {'name': 'Belgium', 'code': 'BEL'},
#   'team2': {'name': 'Panama', 'code': 'PAN'},
#   'score1': 3,
#   'score2': 0,
#   'score1i': 0,
#   'score2i': 0,
#   'goals1': [{'name': 'Mertens', 'minute': 47, 'score1': 1, 'score2': 0},
#    {'name': 'Lukaku', 'minute': 69, 'score1': 2, 'score2': 0},
#    {'name': 'Lukaku', 'minute': 75, 'score1': 3, 'score2': 0}],
#   'goals2': [],
#   'group': 'Group G',
#   'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#   'city': 'Sochi',
#   'timezone': 'UTC+3'},
#  {'num': 14,
#   'date': '2018-06-18',
#   'time': '21:00',
#   'team1': {'name': 'Tunisia', 'code': 'TUN'},
#   'team2': {'name': 'England', 'code': 'ENG'},
#   'score1': 1,
#   'score2': 2,
#   'score1i': 1,
#   'score2i': 1,
#   'goals1': [{'name': 'Sassi',
#     'minute': 35,
#     'score1': 1,
#     'score2': 1,
#     'penalty': True}],
#   'goals2': [{'name': 'Kane', 'minute': 11, 'score1': 0, 'score2': 1},
#    {'name': 'Kane', 'minute': 90, 'offset': 1, 'score1': 1, 'score2': 2}],
#   'group': 'Group G',
#   'stadium': {'key': 'volgograd', 'name': 'Volgograd Arena'},
#   'city': 'Volgograd',
#   'timezone': 'UTC+3'},
#  {'num': 15,
#   'date': '2018-06-19',
#   'time': '18:00',
#   'team1': {'name': 'Poland', 'code': 'POL'},
#   'team2': {'name': 'Senegal', 'code': 'SEN'},
#   'score1': 1,
#   'score2': 2,
#   'score1i': 0,
#   'score2i': 1,
#   'goals1': [{'name': 'Krychowiak', 'minute': 86, 'score1': 1, 'score2': 2}],
#   'goals2': [{'name': 'Cionek',
#     'minute': 37,
#     'score1': 0,
#     'score2': 1,
#     'owngoal': True},
#    {'name': 'Niang', 'minute': 60, 'score1': 0, 'score2': 2}],
#   'group': 'Group H',
#   'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'},
#   'city': 'Moscow',
#   'timezone': 'UTC+3'},
#  {'num': 16,
#   'date': '2018-06-19',
#   'time': '15:00',
#   'team1': {'name': 'Colombia', 'code': 'COL'},
#   'team2': {'name': 'Japan', 'code': 'JPN'},
#   'score1': 1,
#   'score2': 2,
#   'score1i': 1,
#   'score2i': 1,
#   'goals1': [{'name': 'J. Quintero', 'minute': 39, 'score1': 1, 'score2': 1}],
#   'goals2': [{'name': 'Kagawa',
#     'minute': 6,
#     'score1': 0,
#     'score2': 1,
#     'penalty': True},
#    {'name': 'Osako', 'minute': 73, 'score1': 1, 'score2': 2}],
#   'group': 'Group H',
#   'stadium': {'key': 'mordovia', 'name': 'Mordovia Arena'},
#   'city': 'Saransk',
#   'timezone': 'UTC+3'},
#  {'num': 17,
#   'date': '2018-06-19',
#   'time': '21:00',
#   'team1': {'name': 'Russia', 'code': 'RUS'},
#   'team2': {'name': 'Egypt', 'code': 'EGY'},
#   'score1': 3,
#   'score2': 1,
#   'score1i': 0,
#   'score2i': 0,
#   'goals1': [{'name': 'A. Fathi',
#     'minute': 47,
#     'score1': 1,
#     'score2': 0,
#     'owngoal': True},
#    {'name': 'Cheryshev', 'minute': 59, 'score1': 2, 'score2': 0},
#    {'name': 'Dzyuba', 'minute': 62, 'score1': 3, 'score2': 0}],
#   'goals2': [{'name': 'M. Salah',
#     'minute': 73,
#     'score1': 3,
#     'score2': 1,
#     'penalty': True}],
#   'group': 'Group A',
#   'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#   'city': 'Saint Petersburg',
#   'timezone': 'UTC+3'},
#  {'num': 18,
#   'date': '2018-06-20',
#   'time': '18:00',
#   'team1': {'name': 'Uruguay', 'code': 'URU'},
#   'team2': {'name': 'Saudi Arabia', 'code': 'KSA'},
#   'score1': 1,
#   'score2': 0,
#   'score1i': 1,
#   'score2i': 0,
#   'goals1': [{'name': 'L. Suárez', 'minute': 23, 'score1': 1, 'score2': 0}],
#   'goals2': [],
#   'group': 'Group A',
#   'stadium': {'key': 'rostov', 'name': 'Rostov Arena'},
#   'city': 'Rostov-on-Don',
#   'timezone': 'UTC+3'},
#  {'num': 19,
#   'date': '2018-06-20',
#   'time': '15:00',
#   'team1': {'name': 'Portugal', 'code': 'POR'},
#   'team2': {'name': 'Morocco', 'code': 'MAR'},
#   'score1': 1,
#   'score2': 0,
#   'score1i': 1,
#   'score2i': 0,
#   'goals1': [{'name': 'Ronaldo', 'minute': 4, 'score1': 1, 'score2': 0}],
#   'goals2': [],
#   'group': 'Group B',
#   'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#   'city': 'Moscow',
#   'timezone': 'UTC+3'},
#  {'num': 20,
#   'date': '2018-06-20',
#   'time': '21:00',
#   'team1': {'name': 'Iran', 'code': 'IRN'},
#   'team2': {'name': 'Spain', 'code': 'ESP'},
#   'score1': 0,
#   'score2': 1,
#   'score1i': 0,
#   'score2i': 0,
#   'goals1': [],
#   'goals2': [{'name': 'Diego Costa', 'minute': 54, 'score1': 0, 'score2': 1}],
#   'group': 'Group B',
#   'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#   'city': 'Kazan',
#   'timezone': 'UTC+3'},
#  {'num': 21,
#   'date': '2018-06-21',
#   'time': '20:00',
#   'team1': {'name': 'France', 'code': 'FRA'},
#   'team2': {'name': 'Peru', 'code': 'PER'},
#   'score1': 1,
#   'score2': 0,
#   'score1i': 1,
#   'score2i': 0,
#   'goals1': [{'name': 'Mbappé', 'minute': 34, 'score1': 1, 'score2': 0}],
#   'goals2': [],
#   'group': 'Group C',
#   'stadium': {'key': 'ekaterinburg', 'name': 'Ekaterinburg Arena'},
#   'city': 'Ekaterinburg',
#   'timezone': 'UTC+5'},
#  {'num': 22,
#   'date': '2018-06-21',
#   'time': '16:00',
#   'team1': {'name': 'Denmark', 'code': 'DEN'},
#   'team2': {'name': 'Australia', 'code': 'AUS'},
#   'score1': 1,
#   'score2': 1,
#   'score1i': 1,
#   'score2i': 1,
#   'goals1': [{'name': 'Eriksen', 'minute': 7, 'score1': 1, 'score2': 0}],
#   'goals2': [{'name': 'Jedinak',
#     'minute': 38,
#     'score1': 1,
#     'score2': 1,
#     'penalty': True}],
#   'group': 'Group C',
#   'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#   'city': 'Samara',
#   'timezone': 'UTC+4'},
#  {'num': 23,
#   'date': '2018-06-21',
#   'time': '21:00',
#   'team1': {'name': 'Argentina', 'code': 'ARG'},
#   'team2': {'name': 'Croatia', 'code': 'CRO'},
#   'score1': 0,
#   'score2': 3,
#   'score1i': 0,
#   'score2i': 0,
#   'goals1': [],
#   'goals2': [{'name': 'Rebić', 'minute': 53, 'score1': 0, 'score2': 1},
#    {'name': 'Modrić', 'minute': 80, 'score1': 0, 'score2': 2},
#    {'name': 'Rakitić', 'minute': 90, 'offset': 1, 'score1': 0, 'score2': 3}],
#   'group': 'Group D',
#   'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'},
#   'city': 'Nizhny Novgorod',
#   'timezone': 'UTC+3'},
#  {'num': 24,
#   'date': '2018-06-22',
#   'time': '18:00',
#   'team1': {'name': 'Nigeria', 'code': 'NGA'},
#   'team2': {'name': 'Iceland', 'code': 'ISL'},
#   'score1': 2,
#   'score2': 0,
#   'score1i': 0,
#   'score2i': 0,
#   'goals1': [{'name': 'Musa', 'minute': 49, 'score1': 1, 'score2': 0},
#    {'name': 'Musa', 'minute': 75, 'score1': 2, 'score2': 0}],
#   'goals2': [],
#   'group': 'Group D',
#   'stadium': {'key': 'volgograd', 'name': 'Volgograd Arena'},
#   'city': 'Volgograd',
#   'timezone': 'UTC+3'},
#  {'num': 25,
#   'date': '2018-06-22',
#   'time': '15:00',
#   'team1': {'name': 'Brazil', 'code': 'BRA'},
#   'team2': {'name': 'Costa Rica', 'code': 'CRC'},
#   'score1': 2,
#   'score2': 0,
#   'score1i': 0,
#   'score2i': 0,
#   'group': 'Group E',
#   'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#   'city': 'Saint Petersburg',
#   'timezone': 'UTC+3'},
#  {'num': 26,
#   'date': '2018-06-22',
#   'time': '20:00',
#   'team1': {'name': 'Serbia', 'code': 'SRB'},
#   'team2': {'name': 'Switzerland', 'code': 'SUI'},
#   'score1': 1,
#   'score2': 2,
#   'score1i': 1,
#   'score2i': 0,
#   'goals1': [{'name': 'Mitrović', 'minute': 5, 'score1': 1, 'score2': 0}],
#   'goals2': [{'name': 'Xhaka', 'minute': 52, 'score1': 1, 'score2': 1},
#    {'name': 'Shaqiri', 'minute': 90, 'score1': 1, 'score2': 2}],
#   'group': 'Group E',
#   'stadium': {'key': 'kaliningrad', 'name': 'Kaliningrad Stadium'},
#   'city': 'Kaliningrad',
#   'timezone': 'UTC+2'},
#  {'num': 27,
#   'date': '2018-06-23',
#   'time': '21:00',
#   'team1': {'name': 'Germany', 'code': 'GER'},
#   'team2': {'name': 'Sweden', 'code': 'SWE'},
#   'score1': 2,
#   'score2': 1,
#   'score1i': 0,
#   'score2i': 1,
#   'goals1': [{'name': 'Reus', 'minute': 48, 'score1': 1, 'score2': 1},
#    {'name': 'Kroos', 'minute': 90, 'offset': 5, 'score1': 2, 'score2': 1}],
#   'goals2': [{'name': 'Toivonen', 'minute': 32, 'score1': 0, 'score2': 1}],
#   'group': 'Group F',
#   'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#   'city': 'Sochi',
#   'timezone': 'UTC+3'},
#  {'num': 28,
#   'date': '2018-06-23',
#   'time': '18:00',
#   'team1': {'name': 'South Korea', 'code': 'KOR'},
#   'team2': {'name': 'Mexico', 'code': 'MEX'},
#   'score1': 1,
#   'score2': 2,
#   'score1i': 0,
#   'score2i': 1,
#   'goals1': [{'name': 'Son Heung-min',
#     'minute': 90,
#     'offset': 3,
#     'score1': 1,
#     'score2': 2}],
#   'goals2': [{'name': 'Carlos V.',
#     'minute': 26,
#     'score1': 0,
#     'score2': 1,
#     'penalty': True},
#    {'name': 'J. Hernández', 'minute': 66, 'score1': 0, 'score2': 2}],
#   'group': 'Group F',
#   'stadium': {'key': 'rostov', 'name': 'Rostov Arena'},
#   'city': 'Rostov-on-Don',
#   'timezone': 'UTC+3'},
#  {'num': 29,
#   'date': '2018-06-23',
#   'time': '15:00',
#   'team1': {'name': 'Belgium', 'code': 'BEL'},
#   'team2': {'name': 'Tunisia', 'code': 'TUN'},
#   'score1': 5,
#   'score2': 2,
#   'score1i': 3,
#   'score2i': 1,
#   'goals1': [{'name': 'E. Hazard',
#     'minute': 6,
#     'score1': 1,
#     'score2': 0,
#     'penalty': True},
#    {'name': 'R. Lukaku', 'minute': 16, 'score1': 2, 'score2': 0},
#    {'name': 'R. Lukaku', 'minute': 45, 'offset': 3, 'score1': 3, 'score2': 1},
#    {'name': 'E. Hazard', 'minute': 51, 'score1': 4, 'score2': 1},
#    {'name': 'Batshuayi', 'minute': 90, 'score1': 5, 'score2': 1}],
#   'goals2': [{'name': 'Bronn', 'minute': 18, 'score1': 2, 'score2': 1},
#    {'name': 'Khazri', 'minute': 90, 'offset': 3, 'score1': 5, 'score2': 2}],
#   'group': 'Group G',
#   'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'},
#   'city': 'Moscow',
#   'timezone': 'UTC+3'},
#  {'num': 30,
#   'date': '2018-06-24',
#   'time': '15:00',
#   'team1': {'name': 'England', 'code': 'ENG'},
#   'team2': {'name': 'Panama', 'code': 'PAN'},
#   'score1': 6,
#   'score2': 1,
#   'score1i': 5,
#   'score2i': 0,
#   'goals1': [{'name': 'Stones', 'minute': 8, 'score1': 1, 'score2': 0},
#    {'name': 'Kane', 'minute': 22, 'score1': 2, 'score2': 0, 'penalty': True},
#    {'name': 'Lingard', 'minute': 36, 'score1': 3, 'score2': 0},
#    {'name': 'Stones', 'minute': 40, 'score1': 4, 'score2': 0},
#    {'name': 'Kane',
#     'minute': 45,
#     'offset': 1,
#     'score1': 5,
#     'score2': 0,
#     'penalty': True},
#    {'name': 'Kane', 'minute': 62, 'score1': 6, 'score2': 0}],
#   'goals2': [{'name': 'Baloy', 'minute': 78, 'score1': 6, 'score2': 1}],
#   'group': 'Group G',
#   'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'},
#   'city': 'Nizhny Novgorod',
#   'timezone': 'UTC+3'},
#  {'num': 31,
#   'date': '2018-06-24',
#   'time': '21:00',
#   'team1': {'name': 'Poland', 'code': 'POL'},
#   'team2': {'name': 'Colombia', 'code': 'COL'},
#   'score1': 0,
#   'score2': 3,
#   'score1i': 0,
#   'score2i': 1,
#   'goals1': [],
#   'goals2': [{'name': 'Y. Mina', 'minute': 40, 'score1': 0, 'score2': 1},
#    {'name': 'Falcao', 'minute': 70, 'score1': 0, 'score2': 2},
#    {'name': 'Cuadrado', 'minute': 75, 'score1': 0, 'score2': 3}],
#   'group': 'Group H',
#   'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#   'city': 'Kazan',
#   'timezone': 'UTC+3'},
#  {'num': 32,
#   'date': '2018-06-24',
#   'time': '20:00',
#   'team1': {'name': 'Japan', 'code': 'JPN'},
#   'team2': {'name': 'Senegal', 'code': 'SEN'},
#   'score1': 2,
#   'score2': 2,
#   'score1i': 1,
#   'score2i': 1,
#   'goals1': [{'name': 'Inui', 'minute': 34, 'score1': 1, 'score2': 1},
#    {'name': 'Honda', 'minute': 78, 'score1': 2, 'score2': 2}],
#   'goals2': [{'name': 'Mané', 'minute': 11, 'score1': 0, 'score2': 1},
#    {'name': 'M. Wagué', 'minute': 71, 'score1': 1, 'score2': 2}],
#   'group': 'Group H',
#   'stadium': {'key': 'ekaterinburg', 'name': 'Ekaterinburg Arena'},
#   'city': 'Ekaterinburg',
#   'timezone': 'UTC+5'},
#  {'num': 33,
#   'date': '2018-06-25',
#   'time': '18:00',
#   'team1': {'name': 'Uruguay', 'code': 'URU'},
#   'team2': {'name': 'Russia', 'code': 'RUS'},
#   'score1': 3,
#   'score2': 0,
#   'score1i': 2,
#   'score2i': 0,
#   'goals1': [{'name': 'L. Suárez', 'minute': 10, 'score1': 1, 'score2': 0},
#    {'name': 'Cheryshev',
#     'minute': 23,
#     'score1': 2,
#     'score2': 0,
#     'owngoal': True},
#    {'name': 'E. Cavani', 'minute': 90, 'score1': 3, 'score2': 0}],
#   'goals2': [],
#   'group': 'Group A',
#   'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#   'city': 'Samara',
#   'timezone': 'UTC+4'},
#  {'num': 34,
#   'date': '2018-06-25',
#   'time': '17:00',
#   'team1': {'name': 'Saudi Arabia', 'code': 'KSA'},
#   'team2': {'name': 'Egypt', 'code': 'EGY'},
#   'score1': 2,
#   'score2': 1,
#   'score1i': 1,
#   'score2i': 1,
#   'goals1': [{'name': 'Salman Al-Faraj',
#     'minute': 45,
#     'offset': 6,
#     'score1': 1,
#     'score2': 1,
#     'penalty': True},
#    {'name': 'Salem Al-Dawsari',
#     'minute': 90,
#     'offset': 5,
#     'score1': 2,
#     'score2': 1}],
#   'goals2': [{'name': 'M. Salah', 'minute': 22, 'score1': 0, 'score2': 1}],
#   'group': 'Group A',
#   'stadium': {'key': 'volgograd', 'name': 'Volgograd Arena'},
#   'city': 'Volgograd',
#   'timezone': 'UTC+3'},
#  {'num': 35,
#   'date': '2018-06-25',
#   'time': '21:00',
#   'team1': {'name': 'Iran', 'code': 'IRN'},
#   'team2': {'name': 'Portugal', 'code': 'POR'},
#   'score1': 1,
#   'score2': 1,
#   'score1i': 0,
#   'score2i': 1,
#   'goals1': [{'name': 'Karim Ansarifard',
#     'minute': 90,
#     'offset': 3,
#     'score1': 1,
#     'score2': 1,
#     'penalty': True}],
#   'goals2': [{'name': 'Quaresma', 'minute': 45, 'score1': 0, 'score2': 1}],
#   'group': 'Group B',
#   'stadium': {'key': 'mordovia', 'name': 'Mordovia Arena'},
#   'city': 'Saransk',
#   'timezone': 'UTC+3'},
#  {'num': 36,
#   'date': '2018-06-25',
#   'time': '20:00',
#   'team1': {'name': 'Spain', 'code': 'ESP'},
#   'team2': {'name': 'Morocco', 'code': 'MAR'},
#   'score1': 2,
#   'score2': 2,
#   'score1i': 1,
#   'score2i': 1,
#   'goals1': [{'name': 'Isco', 'minute': 19, 'score1': 1, 'score2': 1},
#    {'name': 'Iago Aspas',
#     'minute': 90,
#     'offset': 1,
#     'score1': 2,
#     'score2': 2}],
#   'goals2': [{'name': 'Boutaib', 'minute': 14, 'score1': 0, 'score2': 1},
#    {'name': 'En-Nesyri', 'minute': 81, 'score1': 1, 'score2': 2}],
#   'group': 'Group B',
#   'stadium': {'key': 'kaliningrad', 'name': 'Kaliningrad Stadium'},
#   'city': 'Kaliningrad',
#   'timezone': 'UTC+2'},
#  {'num': 37,
#   'date': '2018-06-26',
#   'time': '17:00',
#   'team1': {'name': 'Denmark', 'code': 'DEN'},
#   'team2': {'name': 'France', 'code': 'FRA'},
#   'score1': 0,
#   'score2': 0,
#   'score1i': 0,
#   'score2i': 0,
#   'group': 'Group C',
#   'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#   'city': 'Moscow',
#   'timezone': 'UTC+3'},
#  {'num': 38,
#   'date': '2018-06-26',
#   'time': '17:00',
#   'team1': {'name': 'Australia', 'code': 'AUS'},
#   'team2': {'name': 'Peru', 'code': 'PER'},
#   'score1': 0,
#   'score2': 2,
#   'score1i': 0,
#   'score2i': 1,
#   'goals1': [],
#   'goals2': [{'name': 'Carrillo', 'minute': 18, 'score1': 0, 'score2': 1},
#    {'name': 'Guerrero', 'minute': 50, 'score1': 0, 'score2': 2}],
#   'group': 'Group C',
#   'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#   'city': 'Sochi',
#   'timezone': 'UTC+3'},
#  {'num': 39,
#   'date': '2018-06-26',
#   'time': '21:00',
#   'team1': {'name': 'Nigeria', 'code': 'NGA'},
#   'team2': {'name': 'Argentina', 'code': 'ARG'},
#   'score1': 1,
#   'score2': 2,
#   'score1i': 0,
#   'score2i': 1,
#   'goals1': [{'name': 'Moses',
#     'minute': 51,
#     'score1': 1,
#     'score2': 1,
#     'penalty': True}],
#   'goals2': [{'name': 'Messi', 'minute': 14, 'score1': 0, 'score2': 1},
#    {'name': 'Marcos Rojo', 'minute': 86, 'score1': 1, 'score2': 2}],
#   'group': 'Group D',
#   'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#   'city': 'Saint Petersburg',
#   'timezone': 'UTC+3'},
#  {'num': 40,
#   'date': '2018-06-26',
#   'time': '21:00',
#   'team1': {'name': 'Iceland', 'code': 'ISL'},
#   'team2': {'name': 'Croatia', 'code': 'CRO'},
#   'score1': 1,
#   'score2': 2,
#   'score1i': 0,
#   'score2i': 0,
#   'goals1': [{'name': 'G. Sigurðsson',
#     'minute': 76,
#     'score1': 1,
#     'score2': 1,
#     'penalty': True}],
#   'goals2': [{'name': 'Badelj', 'minute': 53, 'score1': 0, 'score2': 1},
#    {'name': 'Perišić', 'minute': 90, 'score1': 1, 'score2': 2}],
#   'group': 'Group D',
#   'stadium': {'key': 'rostov', 'name': 'Rostov Arena'},
#   'city': 'Rostov-on-Don',
#   'timezone': 'UTC+3'},
#  {'num': 41,
#   'date': '2018-06-27',
#   'time': '21:00',
#   'team1': {'name': 'Serbia', 'code': 'SRB'},
#   'team2': {'name': 'Brazil', 'code': 'BRA'},
#   'score1': 0,
#   'score2': 2,
#   'score1i': 0,
#   'score2i': 1,
#   'goals1': [],
#   'goals2': [{'name': 'Paulinho', 'minute': 36, 'score1': 0, 'score2': 1},
#    {'name': 'Thiago Silva', 'minute': 68, 'score1': 0, 'score2': 2}],
#   'group': 'Group E',
#   'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'},
#   'city': 'Moscow',
#   'timezone': 'UTC+3'},
#  {'num': 42,
#   'date': '2018-06-27',
#   'time': '21:00',
#   'team1': {'name': 'Switzerland', 'code': 'SUI'},
#   'team2': {'name': 'Costa Rica', 'code': 'CRC'},
#   'score1': 2,
#   'score2': 2,
#   'score1i': 1,
#   'score2i': 0,
#   'goals1': [{'name': 'Džemaili', 'minute': 31, 'score1': 1, 'score2': 0},
#    {'name': 'Drmić', 'minute': 88, 'score1': 2, 'score2': 1}],
#   'goals2': [{'name': 'Waston', 'minute': 56, 'score1': 1, 'score2': 1},
#    {'name': 'Sommer',
#     'minute': 90,
#     'offset': 3,
#     'score1': 2,
#     'score2': 2,
#     'owngoal': True}],
#   'group': 'Group E',
#   'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'},
#   'city': 'Nizhny Novgorod',
#   'timezone': 'UTC+3'},
#  {'num': 43,
#   'date': '2018-06-27',
#   'time': '17:00',
#   'team1': {'name': 'South Korea', 'code': 'KOR'},
#   'team2': {'name': 'Germany', 'code': 'GER'},
#   'score1': 2,
#   'score2': 0,
#   'score1i': 0,
#   'score2i': 0,
#   'goals1': [{'name': 'Kim Young-gwon',
#     'minute': 90,
#     'offset': 2,
#     'score1': 1,
#     'score2': 0},
#    {'name': 'Son Heung-min',
#     'minute': 90,
#     'offset': 6,
#     'score1': 2,
#     'score2': 0}],
#   'goals2': [],
#   'group': 'Group F',
#   'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#   'city': 'Kazan',
#   'timezone': 'UTC+3'},
#  {'num': 44,
#   'date': '2018-06-27',
#   'time': '19:00',
#   'team1': {'name': 'Mexico', 'code': 'MEX'},
#   'team2': {'name': 'Sweden', 'code': 'SWE'},
#   'score1': 0,
#   'score2': 3,
#   'score1i': 0,
#   'score2i': 0,
#   'goals1': [],
#   'goals2': [{'name': 'Augustinsson', 'minute': 50, 'score1': 0, 'score2': 1},
#    {'name': 'Granqvist',
#     'minute': 62,
#     'score1': 0,
#     'score2': 2,
#     'penalty': True},
#    {'name': 'Álvarez',
#     'minute': 74,
#     'score1': 0,
#     'score2': 3,
#     'owngoal': True}],
#   'group': 'Group F',
#   'stadium': {'key': 'ekaterinburg', 'name': 'Ekaterinburg Arena'},
#   'city': 'Ekaterinburg',
#   'timezone': 'UTC+5'},
#  {'num': 45,
#   'date': '2018-06-28',
#   'time': '20:00',
#   'team1': {'name': 'England', 'code': 'ENG'},
#   'team2': {'name': 'Belgium', 'code': 'BEL'},
#   'score1': 0,
#   'score2': 1,
#   'score1i': 0,
#   'score2i': 0,
#   'goals1': [],
#   'goals2': [{'name': 'Adnan Januzaj',
#     'minute': 51,
#     'score1': 0,
#     'score2': 1}],
#   'group': 'Group G',
#   'stadium': {'key': 'kaliningrad', 'name': 'Kaliningrad Stadium'},
#   'city': 'Kaliningrad',
#   'timezone': 'UTC+2'},
#  {'num': 46,
#   'date': '2018-06-28',
#   'time': '21:00',
#   'team1': {'name': 'Panama', 'code': 'PAN'},
#   'team2': {'name': 'Tunisia', 'code': 'TUN'},
#   'score1': 1,
#   'score2': 2,
#   'score1i': 1,
#   'score2i': 0,
#   'goals1': [{'name': 'Yassine Meriah',
#     'minute': 33,
#     'score1': 1,
#     'score2': 0,
#     'owngoal': True}],
#   'goals2': [{'name': 'Fakhereedine Ben Youssef',
#     'minute': 51,
#     'score1': 1,
#     'score2': 1},
#    {'name': 'Wahbi Khazri', 'minute': 66, 'score1': 1, 'score2': 2}],
#   'group': 'Group G',
#   'stadium': {'key': 'mordovia', 'name': 'Mordovia Arena'},
#   'city': 'Saransk',
#   'timezone': 'UTC+3'},
#  {'num': 47,
#   'date': '2018-06-28',
#   'time': '17:00',
#   'team1': {'name': 'Japan', 'code': 'JPN'},
#   'team2': {'name': 'Poland', 'code': 'POL'},
#   'score1': 0,
#   'score2': 1,
#   'score1i': 0,
#   'score2i': 1,
#   'goals1': [],
#   'goals2': [{'name': 'Bednarek', 'minute': 59, 'score1': 0, 'score2': 1}],
#   'group': 'Group H',
#   'stadium': {'key': 'volgograd', 'name': 'Volgograd Arena'},
#   'city': 'Volgograd',
#   'timezone': 'UTC+3'},
#  {'num': 48,
#   'date': '2018-06-28',
#   'time': '18:00',
#   'team1': {'name': 'Senegal', 'code': 'SEN'},
#   'team2': {'name': 'Colombia', 'code': 'COL'},
#   'score1': 0,
#   'score2': 1,
#   'score1i': 0,
#   'score2i': 1,
#   'goals1': [],
#   'goals2': [{'name': 'Y. Mina', 'minute': 74, 'score1': 0, 'score2': 1}],
#   'group': 'Group H',
#   'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#   'city': 'Samara',
#   'timezone': 'UTC+4'},
#  {'num': 49,
#   'date': '2018-06-30',
#   'time': '21:00',
#   'team1': {'name': 'Uruguay', 'code': 'URU'},
#   'team2': {'name': 'Portugal', 'code': 'POR'},
#   'score1': 2,
#   'score2': 1,
#   'score1i': 1,
#   'score2i': 0,
#   'score1et': None,
#   'score2et': None,
#   'score1p': None,
#   'score2p': None,
#   'knockout': True,
#   'goals1': [{'name': 'Edinson Cavani', 'minute': 7, 'score1': 1, 'score2': 0},
#    {'name': 'Edinson Cavani', 'minute': 62, 'score1': 2, 'score2': 1}],
#   'goals2': [{'name': 'Pepe', 'minute': 55, 'score1': 1, 'score2': 1}],
#   'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#   'city': 'Sochi',
#   'timezone': 'UTC+3'},
#  {'num': 50,
#   'date': '2018-06-30',
#   'time': '17:00',
#   'team1': {'name': 'France', 'code': 'FRA'},
#   'team2': {'name': 'Argentina', 'code': 'ARG'},
#   'score1': 4,
#   'score2': 3,
#   'score1i': 1,
#   'score2i': 1,
#   'score1et': None,
#   'score2et': None,
#   'score1p': None,
#   'score2p': None,
#   'knockout': True,
#   'goals1': [{'name': 'Antoine Griezmann',
#     'minute': 13,
#     'score1': 1,
#     'score2': 0,
#     'penalty': True},
#    {'name': 'Benjamin Pavard', 'minute': 57, 'score1': 2, 'score2': 2},
#    {'name': 'Kylian Mbappé', 'minute': 64, 'score1': 3, 'score2': 2},
#    {'name': 'Kylian Mbappé', 'minute': 68, 'score1': 4, 'score2': 2}],
#   'goals2': [{'name': 'Ángel Di María',
#     'minute': 41,
#     'score1': 1,
#     'score2': 1},
#    {'name': 'Gabriel Mercado', 'minute': 48, 'score1': 1, 'score2': 2},
#    {'name': 'Sergio Agüero',
#     'minute': 90,
#     'offset': 3,
#     'score1': 4,
#     'score2': 3}],
#   'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#   'city': 'Kazan',
#   'timezone': 'UTC+3'},
#  {'num': 51,
#   'date': '2018-07-01',
#   'time': '17:00',
#   'team1': {'name': 'Spain', 'code': 'ESP'},
#   'team2': {'name': 'Russia', 'code': 'RUS'},
#   'score1': 1,
#   'score2': 1,
#   'score1i': 1,
#   'score2i': 1,
#   'score1et': 1,
#   'score2et': 1,
#   'score1p': 3,
#   'score2p': 4,
#   'knockout': True,
#   'goals1': [{'name': 'Sergei Ignashevich',
#     'minute': 12,
#     'score1': 1,
#     'score2': 0,
#     'owngoal': True}],
#   'goals2': [{'name': 'Artem Dzyuba',
#     'minute': 41,
#     'score1': 1,
#     'score2': 1,
#     'penalty': True}],
#   'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#   'city': 'Moscow',
#   'timezone': 'UTC+3'},
#  {'num': 52,
#   'date': '2018-07-01',
#   'time': '21:00',
#   'team1': {'name': 'Croatia', 'code': 'CRO'},
#   'team2': {'name': 'Denmark', 'code': 'DEN'},
#   'score1': 1,
#   'score2': 1,
#   'score1i': 1,
#   'score2i': 1,
#   'score1et': 1,
#   'score2et': 1,
#   'score1p': 3,
#   'score2p': 2,
#   'knockout': True,
#   'goals1': [{'name': 'Mario Mandžukić',
#     'minute': 4,
#     'score1': 1,
#     'score2': 1}],
#   'goals2': [{'name': 'Mathias Jørgensen',
#     'minute': 1,
#     'score1': 0,
#     'score2': 1}],
#   'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'},
#   'city': 'Nizhny Novgorod',
#   'timezone': 'UTC+3'},
#  {'num': 53,
#   'date': '2018-07-02',
#   'time': '18:00',
#   'team1': {'name': 'Brazil', 'code': 'BRA'},
#   'team2': {'name': 'Mexico', 'code': 'MEX'},
#   'score1': 2,
#   'score2': 0,
#   'score1i': 0,
#   'score2i': 0,
#   'score1et': None,
#   'score2et': None,
#   'score1p': None,
#   'score2p': None,
#   'knockout': True,
#   'goals1': [{'name': 'Neymar', 'minute': 51, 'score1': 1, 'score2': 0},
#    {'name': 'Roberto Firmino', 'minute': 88, 'score1': 2, 'score2': 0}],
#   'goals2': [],
#   'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#   'city': 'Samara',
#   'timezone': 'UTC+4'},
#  {'num': 54,
#   'date': '2018-07-02',
#   'time': '21:00',
#   'team1': {'name': 'Belgium', 'code': 'BEL'},
#   'team2': {'name': 'Japan', 'code': 'JPN'},
#   'score1': 3,
#   'score2': 2,
#   'score1i': 0,
#   'score2i': 0,
#   'score1et': None,
#   'score2et': None,
#   'score1p': None,
#   'score2p': None,
#   'knockout': True,
#   'goals1': [{'name': 'Jan Vertonghen',
#     'minute': 69,
#     'score1': 1,
#     'score2': 2},
#    {'name': 'Marouane Fellaini', 'minute': 74, 'score1': 2, 'score2': 2},
#    {'name': 'Nacer Chadli',
#     'minute': 90,
#     'offset': 4,
#     'score1': 3,
#     'score2': 2}],
#   'goals2': [{'name': 'Genki Haraguchi',
#     'minute': 48,
#     'score1': 0,
#     'score2': 1},
#    {'name': 'Takashi Inui', 'minute': 52, 'score1': 0, 'score2': 2}],
#   'stadium': {'key': 'rostov', 'name': 'Rostov Arena'},
#   'city': 'Rostov-on-Don',
#   'timezone': 'UTC+3'},
#  {'num': 55,
#   'date': '2018-07-03',
#   'time': '17:00',
#   'team1': {'name': 'Sweden', 'code': 'SWE'},
#   'team2': {'name': 'Switzerland', 'code': 'SUI'},
#   'score1': 1,
#   'score2': 0,
#   'score1i': 0,
#   'score2i': 0,
#   'score1et': None,
#   'score2et': None,
#   'score1p': None,
#   'score2p': None,
#   'knockout': True,
#   'goals1': [{'name': 'Emil Forsberg',
#     'minute': 66,
#     'score1': 1,
#     'score2': 0}],
#   'goals2': [],
#   'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#   'city': 'Saint Petersburg',
#   'timezone': 'UTC+3'},
#  {'num': 56,
#   'date': '2018-07-03',
#   'time': '21:00',
#   'team1': {'name': 'Colombia', 'code': 'COL'},
#   'team2': {'name': 'England', 'code': 'ENG'},
#   'score1': 1,
#   'score2': 1,
#   'score1i': 0,
#   'score2i': 0,
#   'score1et': 1,
#   'score2et': 1,
#   'score1p': 3,
#   'score2p': 4,
#   'knockout': True,
#   'goals1': [{'name': 'Yerry Mina',
#     'minute': 90,
#     'offset': 3,
#     'score1': 1,
#     'score2': 1}],
#   'goals2': [{'name': 'Harry Kane',
#     'minute': 57,
#     'score1': 0,
#     'score2': 1,
#     'penalty': True}],
#   'stadium': {'key': 'spartak', 'name': 'Spartak Stadium'},
#   'city': 'Moscow',
#   'timezone': 'UTC+3'},
#  {'num': 57,
#   'date': '2018-07-06',
#   'time': '17:00',
#   'team1': {'name': 'Uruguay', 'code': 'URU'},
#   'team2': {'name': 'France', 'code': 'FRA'},
#   'score1': 0,
#   'score2': 2,
#   'score1i': 0,
#   'score2i': 1,
#   'score1et': None,
#   'score2et': None,
#   'score1p': None,
#   'score2p': None,
#   'knockout': True,
#   'goals1': [],
#   'goals2': [{'name': 'Raphaël Varane',
#     'minute': 40,
#     'score1': 0,
#     'score2': 1},
#    {'name': 'Antoine Griezmann', 'minute': 61, 'score1': 0, 'score2': 2}],
#   'stadium': {'key': 'nizhnynovgorod', 'name': 'Nizhny Novgorod Stadium'},
#   'city': 'Nizhny Novgorod',
#   'timezone': 'UTC+3'},
#  {'num': 58,
#   'date': '2018-07-06',
#   'time': '21:00',
#   'team1': {'name': 'Brazil', 'code': 'BRA'},
#   'team2': {'name': 'Belgium', 'code': 'BEL'},
#   'score1': 1,
#   'score2': 2,
#   'score1i': 0,
#   'score2i': 2,
#   'score1et': None,
#   'score2et': None,
#   'score1p': None,
#   'score2p': None,
#   'knockout': True,
#   'goals1': [{'name': 'Renato Augusto',
#     'minute': 76,
#     'score1': 1,
#     'score2': 2}],
#   'goals2': [{'name': 'Fernandinho',
#     'minute': 13,
#     'score1': 0,
#     'score2': 1,
#     'owngoal': True},
#    {'name': 'Kevin De Bruyne', 'minute': 31, 'score1': 0, 'score2': 2}],
#   'stadium': {'key': 'kazan', 'name': 'Kazan Arena'},
#   'city': 'Kazan',
#   'timezone': 'UTC+3'},
#  {'num': 59,
#   'date': '2018-07-07',
#   'time': '21:00',
#   'team1': {'name': 'Russia', 'code': 'RUS'},
#   'team2': {'name': 'Croatia', 'code': 'CRO'},
#   'score1': 1,
#   'score2': 1,
#   'score1i': 1,
#   'score2i': 1,
#   'score1et': 2,
#   'score2et': 2,
#   'score1p': 3,
#   'score2p': 4,
#   'knockout': True,
#   'goals1': [{'name': 'Denis Cheryshev',
#     'minute': 31,
#     'score1': 1,
#     'score2': 0},
#    {'name': 'Mário Figueira Fernandes',
#     'minute': 115,
#     'score1': 2,
#     'score2': 2}],
#   'goals2': [{'name': 'Andrej Kramarić',
#     'minute': 39,
#     'score1': 1,
#     'score2': 1},
#    {'name': 'Domagoj Vida', 'minute': 100, 'score1': 1, 'score2': 2}],
#   'stadium': {'key': 'fisht', 'name': 'Fisht Stadium'},
#   'city': 'Sochi',
#   'timezone': 'UTC+3'},
#  {'num': 60,
#   'date': '2018-07-07',
#   'time': '18:00',
#   'team1': {'name': 'Sweden', 'code': 'SWE'},
#   'team2': {'name': 'England', 'code': 'ENG'},
#   'score1': 0,
#   'score2': 2,
#   'score1i': 0,
#   'score2i': 1,
#   'score1et': None,
#   'score2et': None,
#   'score1p': None,
#   'score2p': None,
#   'knockout': True,
#   'goals1': [],
#   'goals2': [{'name': 'Harry Maguire', 'minute': 30, 'score1': 0, 'score2': 1},
#    {'name': 'Dele Alli', 'minute': 58, 'score1': 0, 'score2': 2}],
#   'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#   'city': 'Samara',
#   'timezone': 'UTC+4'},
#  {'num': 61,
#   'date': '2018-07-10',
#   'time': '21:00',
#   'team1': {'name': 'France', 'code': 'FRA'},
#   'team2': {'name': 'Belgium', 'code': 'BEL'},
#   'score1': 1,
#   'score2': 0,
#   'score1i': 0,
#   'score2i': 0,
#   'score1et': None,
#   'score2et': None,
#   'score1p': None,
#   'score2p': None,
#   'knockout': True,
#   'goals1': [{'name': 'Samuel Umtiti',
#     'minute': 51,
#     'score1': 1,
#     'score2': 0}],
#   'goals2': [],
#   'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#   'city': 'Saint Petersburg',
#   'timezone': 'UTC+3'},
#  {'num': 62,
#   'date': '2018-07-11',
#   'time': '21:00',
#   'team1': {'name': 'Croatia', 'code': 'CRO'},
#   'team2': {'name': 'England', 'code': 'ENG'},
#   'score1': 1,
#   'score2': 1,
#   'score1i': 0,
#   'score2i': 1,
#   'score1et': 2,
#   'score2et': 1,
#   'score1p': None,
#   'score2p': None,
#   'knockout': True,
#   'goals1': [{'name': 'Ivan Perišić', 'minute': 68, 'score1': 1, 'score2': 1},
#    {'name': 'Mario Mandžukić', 'minute': 109, 'score1': 2, 'score2': 1}],
#   'goals2': [{'name': 'Kieran Trippier',
#     'minute': 5,
#     'score1': 0,
#     'score2': 1}],
#   'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#   'city': 'Moscow',
#   'timezone': 'UTC+3'},
#  {'num': 63,
#   'date': '2018-07-14',
#   'time': '17:00',
#   'team1': {'name': 'Belgium', 'code': 'BEL'},
#   'team2': {'name': 'England', 'code': 'ENG'},
#   'score1': 2,
#   'score2': 0,
#   'score1i': 1,
#   'score2i': 0,
#   'score1et': None,
#   'score2et': None,
#   'score1p': None,
#   'score2p': None,
#   'knockout': True,
#   'goals1': [{'name': 'Thomas Meunier', 'minute': 4, 'score1': 1, 'score2': 0},
#    {'name': 'Eden Hazard', 'minute': 82, 'score1': 2, 'score2': 0}],
#   'goals2': [],
#   'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#   'city': 'Saint Petersburg',
#   'timezone': 'UTC+3'},
#  {'num': 64,
#   'date': '2018-07-15',
#   'time': '18:00',
#   'team1': {'name': 'France', 'code': 'FRA'},
#   'team2': {'name': 'Croatia', 'code': 'CRO'},
#   'score1': 4,
#   'score2': 2,
#   'score1i': 2,
#   'score2i': 1,
#   'score1et': None,
#   'score2et': None,
#   'score1p': None,
#   'score2p': None,
#   'knockout': True,
#   'goals1': [{'name': 'Mario Mandžukić',
#     'minute': 18,
#     'score1': 1,
#     'score2': 0,
#     'owngoal': True},
#    {'name': 'Griezmann',
#     'minute': 38,
#     'score1': 2,
#     'score2': 1,
#     'penalty': True},
#    {'name': 'Pogba', 'minute': 59, 'score1': 3, 'score2': 1},
#    {'name': 'Mbappé', 'minute': 65, 'score1': 4, 'score2': 1}],
#   'goals2': [{'name': 'Perišić', 'minute': 28, 'score1': 1, 'score2': 1},
#    {'name': 'Mario Mandžukić', 'minute': 69, 'score1': 4, 'score2': 2}],
#   'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#   'city': 'Moscow',
#   'timezone': 'UTC+3'}]

# %%
x = [1, 2, 3]
x.extend([4, 5])
x
# Out:
# [1, 2, 3, 4, 5]

# %%
x = [1, 2, 3]
x.append([4, 5])

# %%
len(matches)
# Out:
# 64

# %%
matches[0]
# Out:
# {'num': 1,
#  'date': '2018-06-14',
#  'time': '18:00',
#  'team1': {'name': 'Russia', 'code': 'RUS'},
#  'team2': {'name': 'Saudi Arabia', 'code': 'KSA'},
#  'score1': 5,
#  'score2': 0,
#  'score1i': 2,
#  'score2i': 0,
#  'goals1': [{'name': 'Gazinsky', 'minute': 12, 'score1': 1, 'score2': 0},
#   {'name': 'Cheryshev', 'minute': 43, 'score1': 2, 'score2': 0},
#   {'name': 'Dzyuba', 'minute': 71, 'score1': 3, 'score2': 0},
#   {'name': 'Cheryshev', 'minute': 90, 'offset': 1, 'score1': 4, 'score2': 0},
#   {'name': 'Golovin', 'minute': 90, 'offset': 4, 'score1': 5, 'score2': 0}],
#  'goals2': [],
#  'group': 'Group A',
#  'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#  'city': 'Moscow',
#  'timezone': 'UTC+3'}

# %% [markdown]
# ### Make sure the asserts pass before moving on to the next step.

# %%
# Run this cell without changes

# There should be 64 matches. If the length is 20, that means
# you have a list of lists instead of a list of dictionaries
assert len(matches) == 64

# Each match in the list should be a dictionary
assert type(matches[0]) == dict

# %% [markdown]
# ### Extracting Teams
# Each match has a team1 and a team2.

# %%
print(matches[0]['team1'])
print(matches[0]['team2'])
# Out:
# {'name': 'Russia', 'code': 'RUS'}
# {'name': 'Saudi Arabia', 'code': 'KSA'}

# %%
teams = []
for match in matches:
    team1 = match['team1']['name']
    team2 = match['team2']['name']
    #print('team1: ',team1,'team2:',team2)
    teams.extend([team1,team2])
unique_teams = sorted(list(set(teams)))

unique_teams
# Out:
# ['Argentina',
#  'Australia',
#  'Belgium',
#  'Brazil',
#  'Colombia',
#  'Costa Rica',
#  'Croatia',
#  'Denmark',
#  'Egypt',
#  'England',
#  'France',
#  'Germany',
#  'Iceland',
#  'Iran',
#  'Japan',
#  'Mexico',
#  'Morocco',
#  'Nigeria',
#  'Panama',
#  'Peru',
#  'Poland',
#  'Portugal',
#  'Russia',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'South Korea',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Tunisia',
#  'Uruguay']

# %%
len(unique_teams)
# Out:
# 32

# %%
# Run this cell without changes

# teams should be a list, not a set
assert type(unique_teams) == list

# 32 teams competed in the 2018 World Cup
assert len(unique_teams) == 32

# Each element of teams should be a string
# (the name), not a dictionary
assert type(unique_teams[0]) == str

# %%
#Teacher code
teams_set = set()

for match in matches:
    # Add team1 name value to teams_set
    teams_set.add(match['team1']['name'])
    teams_set.add(match['team2']['name'])

teams =sorted(list(teams_set))
teams
# Out:
# ['Argentina',
#  'Australia',
#  'Belgium',
#  'Brazil',
#  'Colombia',
#  'Costa Rica',
#  'Croatia',
#  'Denmark',
#  'Egypt',
#  'England',
#  'France',
#  'Germany',
#  'Iceland',
#  'Iran',
#  'Japan',
#  'Mexico',
#  'Morocco',
#  'Nigeria',
#  'Panama',
#  'Peru',
#  'Poland',
#  'Portugal',
#  'Russia',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'South Korea',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Tunisia',
#  'Uruguay']

# %% [markdown]
# ### Associating Countries with 2018 World Cup Performance
# Create a data structure that connects a team name (country name) to its performance in the 2018 FIFA World Cup. We'll use the count of games won in the entire tournament (group stage as well as knockout stage) to represent the performance.
#
# Also, create visualizations to help the reader understand the distribution of games won and the performance of each team.
#
# So, we are building a data structure that connects a country name to the number of wins. There is no universal correct format for a data structure with this purpose, but we are going to use a format that resembles the "dataframe" format that will be introduced later in the course.
#
# Specifically, we'll build a dictionary where each key is the name of a country, and each value is a nested dictionary containing information about the number of wins and the 2018 population.
#
# The final result will look something like this:
#
# {
#   'Argentina': { 'wins': 1, 'population': 44494502 },
#   ...
#   'Uruguay':   { 'wins': 4, 'population': 3449299  }
# }
# For the current step (step 2), we'll build a data structure that looks something like this:
#
# {
#   'Argentina': { 'wins': 1 },
#   ...
#   'Uruguay':   { 'wins': 4 }
# }

# %% [markdown]
# ### Initializing with Wins Set to Zero

# %%
combined_data = {}
for team in teams:
    combined_data[team]= {'wins' :0}

# %%
#Added Teachers code
combined_data = {team: {"wins": 0} for team in teams}

# %%
combined_data
# Out:
# {'Argentina': {'wins': 0},
#  'Australia': {'wins': 0},
#  'Belgium': {'wins': 0},
#  'Brazil': {'wins': 0},
#  'Colombia': {'wins': 0},
#  'Costa Rica': {'wins': 0},
#  'Croatia': {'wins': 0},
#  'Denmark': {'wins': 0},
#  'Egypt': {'wins': 0},
#  'England': {'wins': 0},
#  'France': {'wins': 0},
#  'Germany': {'wins': 0},
#  'Iceland': {'wins': 0},
#  'Iran': {'wins': 0},
#  'Japan': {'wins': 0},
#  'Mexico': {'wins': 0},
#  'Morocco': {'wins': 0},
#  'Nigeria': {'wins': 0},
#  'Panama': {'wins': 0},
#  'Peru': {'wins': 0},
#  'Poland': {'wins': 0},
#  'Portugal': {'wins': 0},
#  'Russia': {'wins': 0},
#  'Saudi Arabia': {'wins': 0},
#  'Senegal': {'wins': 0},
#  'Serbia': {'wins': 0},
#  'South Korea': {'wins': 0},
#  'Spain': {'wins': 0},
#  'Sweden': {'wins': 0},
#  'Switzerland': {'wins': 0},
#  'Tunisia': {'wins': 0},
#  'Uruguay': {'wins': 0}}

# %%
len(combined_data)
# Out:
# 32

# %% [markdown]
# ### Check that the asserts pass.

# %%
# Run this cell without changes

# combined_data should be a dictionary
assert type(combined_data) == dict

# the keys should be strings
assert type(list(combined_data.keys())[0]) == str

# the values should be dictionaries
assert combined_data["Japan"] == {"wins": 0}

# %% [markdown]
# ### Adding Wins from Matches
# Now it's time to revisit the matches list from earlier, in order to associate a team with the number of times it has won a match.
#
# This time, let's write some functions to help organize our logic.
#
# Write a function find_winner that takes in a match dictionary, and returns the name of the team that won the match. Recall that a match is structured like this:
#
# {
#   'num': 1,
#   'date': '2018-06-14',
#   'time': '18:00',
#   'team1': { 'name': 'Russia',       'code': 'RUS' },
#   'team2': { 'name': 'Saudi Arabia', 'code': 'KSA' },
#   'score1': 5,
#   'score2': 0,
#   'score1i': 2,
#   'score2i': 0,
#   'goals1': [
#     { 'name': 'Gazinsky',  'minute': 12, 'score1': 1, 'score2': 0 },
#     { 'name': 'Cheryshev', 'minute': 43, 'score1': 2, 'score2': 0 },
#     { 'name': 'Dzyuba',    'minute': 71, 'score1': 3, 'score2': 0 },
#     { 'name': 'Cheryshev', 'minute': 90, 'offset': 1, 'score1': 4, 'score2': 0 },
#     { 'name': 'Golovin',   'minute': 90, 'offset': 4, 'score1': 5, 'score2': 0 }
#   ],
#   'goals2': [],
#   'group': 'Group A',
#   'stadium': { 'key': 'luzhniki', 'name': 'Luzhniki Stadium' },
#   'city': 'Moscow',
#   'timezone': 'UTC+3'
# }
# The winner is determined by comparing the values associated with the 'score1' and 'score2' keys. If score 1 is larger, then the name associated with the 'team1' key is the winner. If score 2 is larger, then the name associated with the 'team2' key is the winner. If the values are the same, there is no winner, so return None. (Unlike the group round of the World Cup, we are only counting wins as our "performance" construct, not 3 points for a win and 1 point for a tie.)

# %%
matches[3]
# Out:
# {'num': 4,
#  'date': '2018-06-15',
#  'time': '18:00',
#  'team1': {'name': 'Morocco', 'code': 'MAR'},
#  'team2': {'name': 'Iran', 'code': 'IRN'},
#  'score1': 0,
#  'score2': 1,
#  'score1i': 0,
#  'score2i': 0,
#  'goals1': [],
#  'goals2': [{'name': 'Bouhaddouz',
#    'minute': 90,
#    'offset': 5,
#    'score1': 0,
#    'score2': 1,
#    'owngoal': True}],
#  'group': 'Group B',
#  'stadium': {'key': 'saintpetersburg', 'name': 'Saint Petersburg Stadium'},
#  'city': 'Saint Petersburg',
#  'timezone': 'UTC+3'}

# %%
# Replace None with appropriate code


def find_winner(match):
    """
    Given a dictionary containing information about a match,
    return the name of the winner (or None in the case of a tie)
    """
#print(match['goals1'])
    score1 = match['score1']
    score2 = match['score2']
    #print(score1,score2)
    if score1 > score2:
        return match['team1']['name']
    elif score1 < score2 :
        return match['team2']['name']
    elif score1 == score2:
        return None
  
#find_winner(matches[2])

# %%
assert find_winner(matches[0]) == "Russia"
assert find_winner(matches[1]) == "Uruguay"
assert find_winner(matches[2]) == None

# %% [markdown]
# ### Now that we have this helper function, loop over every match in matches, find the winner, and add 1 to the associated count of wins in combined_data. If the winner is None, skip adding it to the dictionary.

# %%
for match in matches:
      winner = find_winner(match)
      # Only proceed to the next step if there was
    # a winner
      if winner:
        combined_data[winner]['wins'] +=1

# %%
combined_data
# Out:
# {'Argentina': {'wins': 1},
#  'Australia': {'wins': 0},
#  'Belgium': {'wins': 6},
#  'Brazil': {'wins': 3},
#  'Colombia': {'wins': 2},
#  'Costa Rica': {'wins': 0},
#  'Croatia': {'wins': 3},
#  'Denmark': {'wins': 1},
#  'Egypt': {'wins': 0},
#  'England': {'wins': 3},
#  'France': {'wins': 6},
#  'Germany': {'wins': 1},
#  'Iceland': {'wins': 0},
#  'Iran': {'wins': 1},
#  'Japan': {'wins': 1},
#  'Mexico': {'wins': 2},
#  'Morocco': {'wins': 0},
#  'Nigeria': {'wins': 1},
#  'Panama': {'wins': 0},
#  'Peru': {'wins': 1},
#  'Poland': {'wins': 1},
#  'Portugal': {'wins': 1},
#  'Russia': {'wins': 2},
#  'Saudi Arabia': {'wins': 1},
#  'Senegal': {'wins': 1},
#  'Serbia': {'wins': 1},
#  'South Korea': {'wins': 1},
#  'Spain': {'wins': 1},
#  'Sweden': {'wins': 3},
#  'Switzerland': {'wins': 1},
#  'Tunisia': {'wins': 1},
#  'Uruguay': {'wins': 4}}

# %% [markdown]
# ### Analysis of wins
# While we could try to understand all 32 of those numbers just by scanning through them, let's use some descriptive statistics and data visualizations instead

# %%
len(combined_data)
# Out:
# 32

# %% [markdown]
# ### Statistical Summary of Wins
# The code below calculates the mean, median, and standard deviation of the number of wins. If it doesn't work, that is an indication that something went wrong with the creation of the combined_data variable, and you might want to look at the solution branch and fix your code before proceeding.

# %%
for x in combined_data:
    print(combined_data[x]['wins'])
# Out:
# 1
# 0
# 6
# 3
# 2
# 0
# 3
# 1
# 0
# 3
# 6
# 1
# 0
# 1
# 1
# 2
# 0
# 1
# 0
# 1
# 1
# 1
# 2
# 1
# 1
# 1
# 1
# 1
# 3
# 1
# 1
# 4

# %%
#use list comprehension
import numpy as np
from statistics import mode
wins = [combined_data[win]['wins'] for win in combined_data]
print('mean',np.mean(wins))
print('median',np.median(wins))
print('mode',mode(wins))
print('std',np.std(wins))
# Out:
# mean 1.5625
# median 1.0
# mode 1
# std 1.5194057226429023

# %%
#teahers code
# Run this cell without changes
import numpy as np

wins = [val["wins"] for val in combined_data.values()]

print("Mean number of wins:", np.mean(wins))
print("Median number of wins:", np.median(wins))
print("Standard deviation of number of wins:", np.std(wins))
# Out:
# Mean number of wins: 1.5625
# Median number of wins: 1.0
# Standard deviation of number of wins: 1.5194057226429023

# %% [markdown]
# ### Visualization of Wins
# In addition to those numbers, let's make a histogram (showing the distributions of the number of wins) and a bar graph (showing the number of wins by country).

# %%
#my code
countries = [country for country in combined_data.keys()]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,8))
ax.hist(wins,edgecolor='black');

# %%
fig, ax = plt.subplots(figsize=(15,8))
ax.barh(countries[::-1],wins[::-1])
#plt.xticks(rotation=80,fontsize=20);
# Out:
# <BarContainer object of 32 artists>

# %%
### Teachers code
# Run this cell without changes
import matplotlib.pyplot as plt

# Set up figure and axes
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 7))
fig.set_tight_layout(True)

# Histogram of Wins and Frequencies
ax1.hist(x=wins, bins=range(8), align="left", color="green")
ax1.set_xticks(range(7))
ax1.set_xlabel("Wins in 2018 World Cup")
ax1.set_ylabel("Frequency")
ax1.set_title("Distribution of Wins")

# Horizontal Bar Graph of Wins by Country
ax2.barh(teams[::-1], wins[::-1], color="green")
ax2.set_xlabel("Wins in 2018 World Cup")
ax2.set_title("Wins by Country");

# %% [markdown]
# ### Interpretation of Win Analysis
# Before we move to looking at the relationship between wins and population, it's useful to understand the distribution of wins alone. A few notes of interpretation:
#
# The number of wins is skewed and looks like a negative binomial distribution, which makes sense conceptually
# The "typical" value here is 1 (both the median and the highest point of the histogram), meaning a typical team that qualifies for the World Cup wins once
# There are a few teams we might consider outliers: Belgium and France, with 6x the wins of the "typical" team and 1.5x the wins of the next "runner-up" (Uruguay, with 4 wins)
# This is a fairly small dataset, something that becomes more noticeable with such a "spiky" (not smooth) histogra

# %% [markdown]
# ### 3. Associating Countries with 2018 Population
# Add to the existing data structure so that it also connects each country name to its 2018 population, and create visualizations comparable to those from step 2.
#
# Now we're ready to add the 2018 population to combined_data, finally using the CSV file
#
# Recall that combined_data currently looks something like this:
#
# {
#   'Argentina': { 'wins': 1 },
#   ...
#   'Uruguay':   { 'wins': 4 }
# }
# And the goal is for it to look something like this:
#
# {
#   'Argentina': { 'wins': 1, 'population': 44494502 },
#   ...
#   'Uruguay':   { 'wins': 4, 'population': 3449299  }
# }

# %% [markdown]
# ### Exploring the Structure of the Population Data CSV
# Recall that previously we loaded information from a CSV containing population data into a list of dictionaries called population_data.

# %%
len(population_data)
# Out:
# 12695

# %% [markdown]
# ### 12,695 is a very large number of rows to print out, so let's look at some samples instead.

# %%
np.random.seed(42)
population_record_samples = np.random.choice(population_data, size=10)
population_record_samples
# Out:
# array([{'': '9984', 'Country Name': 'Malta', 'Country Code': 'MLT', 'Year': '1983', 'Value': '330524'},
#        {'': '3574', 'Country Name': 'Bahrain', 'Country Code': 'BHR', 'Year': '1994', 'Value': '549583'},
#        {'': '8104', 'Country Name': 'Iran, Islamic Rep.', 'Country Code': 'IRN', 'Year': '1988', 'Value': '53077313'},
#        {'': '7905', 'Country Name': 'Iceland', 'Country Code': 'ISL', 'Year': '1966', 'Value': '195570'},
#        {'': '14678', 'Country Name': 'United Arab Emirates', 'Country Code': 'ARE', 'Year': '1966', 'Value': '159976'},
#        {'': '13998', 'Country Name': 'Thailand', 'Country Code': 'THA', 'Year': '1994', 'Value': '58875269'},
#        {'': '8448', 'Country Name': 'Jamaica', 'Country Code': 'JAM', 'Year': '1978', 'Value': '2105907'},
#        {'': '8979', 'Country Name': 'Kuwait', 'Country Code': 'KWT', 'Year': '1978', 'Value': '1224067'},
#        {'': '3180', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2013', 'Value': '42202935'},
#        {'': '7140', 'Country Name': 'Gibraltar', 'Country Code': 'GIB', 'Year': '1968', 'Value': '27685'}],
#       dtype=object)

# %% [markdown]
# There are 2 filtering tasks, 1 data normalization task, and 1 type conversion task to be completed, based on what we can see in this sample. We'll walk through each of them below.
#
# (In a more realistic data cleaning environment, you most likely won't happen to get a sample that demonstrates all of the data cleaning steps needed, but this sample was chosen carefully for example purposes.)

# %% [markdown]
# ### Filtering Population Data
# We already should have suspected that this dataset would require some filtering, since there are 32 records in our current combined_data dataset and 12,695 records in population_data. Now that we have looked at this sample, we can identify 2 features we'll want to use in order to filter down the population_data records to just 32. Try to identify them before looking at the answer below.
#
# .

# %% [markdown]
# ### Answer: the two features to filter on are 'Country Name' and 'Year'. We can see from the sample above that there are countries in population_data that are not present in combined_data (e.g. Malta) and there are years present that are not 2018.
#
# in the cell below, create a new variable population_data_filtered that only includes relevant records from population_data. Relevant records are records where the country name is one of the countries in the teams list, and the year is "2018".
#
# (It's okay to leave 2018 as a string since we are not performing any math operations on it, just make sure you check for "2018" and not 2018.)

# %%
population_data_filtered = []
for record in population_data:
    if record['Year'] =='2018' and record['Country Name'] in teams:
        population_data_filtered.append(record)
len(population_data_filtered)
# Out:
# 27

# %%
population_data_filtered = [record for record in population_data if record['Year'] =='2018' and record['Country Name'] in teams]
len(population_data_filtered)
# Out:
# 27

# %% [markdown]
# Hmm...what went wrong? Why do we only have 27 records, and not 32?
#
# Did we really get a dataset with 12k records that's missing 5 of the data points we need?
#
# Let's take a closer look at the population data samples again, specifically the third one:

# %%
population_record_samples[2]
# Out:
# {'': '8104',
#  'Country Name': 'Iran, Islamic Rep.',
#  'Country Code': 'IRN',
#  'Year': '1988',
#  'Value': '53077313'}

# %% [markdown]
# And compare that with the value for Iran in teams:

# %%
teams[13]
# Out:
# 'Iran'

# %% [markdown]
# Ohhhh...we have a data normalization issue. One dataset refers to this country as 'Iran, Islamic Rep.', while the other refers to it as 'Iran'. This is a common issue we face when using data about countries and regions, where there is no universally-accepted naming convention.
# ### Normalizing Locations in Population Data
# Sometimes data normalization can be a very, very time-consuming task where you need to find "crosswalk" data that can link the two formats together, or you need to write advanced regex formulas to line everything up.
#
# For this task, there are only 5 missing, so we'll just go ahead and give you a function that makes the appropriate substitutions.

# %%
def normalize_location(country_name):
    '''
    Given a country name,return the name that the
    country uses when playing in the FIFA World Cup
    '''
    name_sub_dict = {
        'Russian Federation':'Russia',
        'Egypt, Arab Rep.' : 'Egypt',
        'United Kingdom' :'England',
        'Iran, Islamic Rep.': 'Iran',
        'Korea, Rep.':'South Korea'
    }
    #The .get method returns the corresponding value from
    #the dict if present, otherwise returns a country_name
    return name_sub_dict.get(country_name,country_name)

    # Example where normalized location is different
print(normalize_location('Russian Federation'))
print(normalize_location('Korea, Rep.'))
#Example where normalized Location is the same
print(normalize_location('Argentina'))
# Out:
# Russia
# South Korea
# Argentina

# %% [markdown]
# ### Now, write new code to create population_data_filtered with normalized country names.

# %%
# Replace None with appropriate code

population_data_filtered = []

for record in population_data:
    # Get normalized country name
    name = normalize_location(record['Country Name'])
    # Add record to population_data_filtered if relevant
    if record['Year']=='2018' and name in teams:
        # Replace the country name in the record
        record['Country Name'] = name
        # Append to list
        population_data_filtered.append(record)

len(population_data_filtered)  # 32
# Out:
# 32

# %%
population_data_filtered
# Out:
# [{'': '3185',
#   'Country Name': 'Argentina',
#   'Country Code': 'ARG',
#   'Year': '2018',
#   'Value': 44494502},
#  {'': '3362',
#   'Country Name': 'Australia',
#   'Country Code': 'AUS',
#   'Year': '2018',
#   'Value': 24982688},
#  {'': '3834',
#   'Country Name': 'Belgium',
#   'Country Code': 'BEL',
#   'Year': '2018',
#   'Value': 11433256},
#  {'': '4306',
#   'Country Name': 'Brazil',
#   'Country Code': 'BRA',
#   'Year': '2018',
#   'Value': 209469333},
#  {'': '5250',
#   'Country Name': 'Colombia',
#   'Country Code': 'COL',
#   'Year': '2018',
#   'Value': 49648685},
#  {'': '5486',
#   'Country Name': 'Costa Rica',
#   'Country Code': 'CRI',
#   'Year': '2018',
#   'Value': 4999441},
#  {'': '5604',
#   'Country Name': 'Croatia',
#   'Country Code': 'HRV',
#   'Year': '2018',
#   'Value': 4087843},
#  {'': '5899',
#   'Country Name': 'Denmark',
#   'Country Code': 'DNK',
#   'Year': '2018',
#   'Value': 5793636},
#  {'': '6194',
#   'Country Name': 'Egypt',
#   'Country Code': 'EGY',
#   'Year': '2018',
#   'Value': 98423595},
#  {'': '6777',
#   'Country Name': 'France',
#   'Country Code': 'FRA',
#   'Year': '2018',
#   'Value': 66977107},
#  {'': '7072',
#   'Country Name': 'Germany',
#   'Country Code': 'DEU',
#   'Year': '2018',
#   'Value': 82905782},
#  {'': '7957',
#   'Country Name': 'Iceland',
#   'Country Code': 'ISL',
#   'Year': '2018',
#   'Value': 352721},
#  {'': '8134',
#   'Country Name': 'Iran',
#   'Country Code': 'IRN',
#   'Year': '2018',
#   'Value': 81800269},
#  {'': '8547',
#   'Country Name': 'Japan',
#   'Country Code': 'JPN',
#   'Year': '2018',
#   'Value': 126529100},
#  {'': '8901',
#   'Country Name': 'South Korea',
#   'Country Code': 'KOR',
#   'Year': '2018',
#   'Value': 51606633},
#  {'': '10255',
#   'Country Name': 'Mexico',
#   'Country Code': 'MEX',
#   'Year': '2018',
#   'Value': 126190788},
#  {'': '10609',
#   'Country Name': 'Morocco',
#   'Country Code': 'MAR',
#   'Year': '2018',
#   'Value': 36029138},
#  {'': '11258',
#   'Country Name': 'Nigeria',
#   'Country Code': 'NGA',
#   'Year': '2018',
#   'Value': 195874740},
#  {'': '11671',
#   'Country Name': 'Panama',
#   'Country Code': 'PAN',
#   'Year': '2018',
#   'Value': 4176873},
#  {'': '11848',
#   'Country Name': 'Peru',
#   'Country Code': 'PER',
#   'Year': '2018',
#   'Value': 31989256},
#  {'': '11966',
#   'Country Name': 'Poland',
#   'Country Code': 'POL',
#   'Year': '2018',
#   'Value': 37974750},
#  {'': '12025',
#   'Country Name': 'Portugal',
#   'Country Code': 'PRT',
#   'Year': '2018',
#   'Value': 10283822},
#  {'': '12261',
#   'Country Name': 'Russia',
#   'Country Code': 'RUS',
#   'Year': '2018',
#   'Value': 144478050},
#  {'': '12556',
#   'Country Name': 'Saudi Arabia',
#   'Country Code': 'SAU',
#   'Year': '2018',
#   'Value': 33699947},
#  {'': '12615',
#   'Country Name': 'Senegal',
#   'Country Code': 'SEN',
#   'Year': '2018',
#   'Value': 15854360},
#  {'': '12644',
#   'Country Name': 'Serbia',
#   'Country Code': 'SRB',
#   'Year': '2018',
#   'Value': 6982604},
#  {'': '13255',
#   'Country Name': 'Spain',
#   'Country Code': 'ESP',
#   'Year': '2018',
#   'Value': 46796540},
#  {'': '13727',
#   'Country Name': 'Sweden',
#   'Country Code': 'SWE',
#   'Year': '2018',
#   'Value': 10175214},
#  {'': '13786',
#   'Country Name': 'Switzerland',
#   'Country Code': 'CHE',
#   'Year': '2018',
#   'Value': 8513227},
#  {'': '14317',
#   'Country Name': 'Tunisia',
#   'Country Code': 'TUN',
#   'Year': '2018',
#   'Value': 11565204},
#  {'': '14789',
#   'Country Name': 'England',
#   'Country Code': 'GBR',
#   'Year': '2018',
#   'Value': 66460344},
#  {'': '14907',
#   'Country Name': 'Uruguay',
#   'Country Code': 'URY',
#   'Year': '2018',
#   'Value': 3449299}]

# %% [markdown]
# #### Great, now we should have 32 records instead of 27.
# ### Type Conversion of Population Data
# We need to do one more thing before we'll have population data that is usable for analysis. Take a look at this record from population_data_filtered to see if you can spot it:

# %%
population_data_filtered[0]
# Out:
# {'': '3185',
#  'Country Name': 'Argentina',
#  'Country Code': 'ARG',
#  'Year': '2018',
#  'Value': '44494502'}

# %% [markdown]
# #### Every key has the same data type (str), including the population value. In this example, it's '44494502', when it needs to be 44494502 if we want to be able to compute statistics with it.
#
# In the cell below, loop over population_data_filtered and convert the data type of the value associated with the "Value" key from a string to an integer, using the built-in int() function.

# %%
for record in population_data_filtered:
    #Convert the population value from str to int
    record['Value'] = int(record['Value'])

population_data_filtered[-1]
# Out:
# {'': '14907',
#  'Country Name': 'Uruguay',
#  'Country Code': 'URY',
#  'Year': '2018',
#  'Value': 3449299}

# %% [markdown]
# #### Check that it worked with the assert statement below:

# %%
assert type(population_data_filtered[-1]["Value"]) == int

# %% [markdown]
# ### Adding Population Data
# Now it's time to add the population data to combined_data. Recall that the data structure currently looks like this:
#
# #### The goal is for it to be structured like this:
#
# ###### {
# ######   'Argentina': { 'wins': 1, 'population': 44494502 },
#   ...
# ######   'Uruguay':   { 'wins': 4, 'population': 3449299  }
# ###### }
# In the cell below, loop over population_data_filtered and add information about population to each country in combined_data:

# %%
for record in population_data_filtered:
    #Extract the Country name from the record
    country = record['Country Name']
    # Extract the population value from the record
    population  =  record['Value']
    #print(country,population)
    # Add this information to combined_data
    combined_data[country]['population'] = population
        
combined_data
# Out:
# {'Argentina': {'wins': 1, 'population': 44494502},
#  'Australia': {'wins': 0, 'population': 24982688},
#  'Belgium': {'wins': 6, 'population': 11433256},
#  'Brazil': {'wins': 3, 'population': 209469333},
#  'Colombia': {'wins': 2, 'population': 49648685},
#  'Costa Rica': {'wins': 0, 'population': 4999441},
#  'Croatia': {'wins': 3, 'population': 4087843},
#  'Denmark': {'wins': 1, 'population': 5793636},
#  'Egypt': {'wins': 0, 'population': 98423595},
#  'England': {'wins': 3, 'population': 66460344},
#  'France': {'wins': 6, 'population': 66977107},
#  'Germany': {'wins': 1, 'population': 82905782},
#  'Iceland': {'wins': 0, 'population': 352721},
#  'Iran': {'wins': 1, 'population': 81800269},
#  'Japan': {'wins': 1, 'population': 126529100},
#  'Mexico': {'wins': 2, 'population': 126190788},
#  'Morocco': {'wins': 0, 'population': 36029138},
#  'Nigeria': {'wins': 1, 'population': 195874740},
#  'Panama': {'wins': 0, 'population': 4176873},
#  'Peru': {'wins': 1, 'population': 31989256},
#  'Poland': {'wins': 1, 'population': 37974750},
#  'Portugal': {'wins': 1, 'population': 10283822},
#  'Russia': {'wins': 2, 'population': 144478050},
#  'Saudi Arabia': {'wins': 1, 'population': 33699947},
#  'Senegal': {'wins': 1, 'population': 15854360},
#  'Serbia': {'wins': 1, 'population': 6982604},
#  'South Korea': {'wins': 1, 'population': 51606633},
#  'Spain': {'wins': 1, 'population': 46796540},
#  'Sweden': {'wins': 3, 'population': 10175214},
#  'Switzerland': {'wins': 1, 'population': 8513227},
#  'Tunisia': {'wins': 1, 'population': 11565204},
#  'Uruguay': {'wins': 4, 'population': 3449299}}

# %%
# Run this cell without changes
assert type(combined_data["Uruguay"]) == dict
assert type(combined_data["Uruguay"]["population"]) == int

# %% [markdown]
# ### Analysis of Population
# Let's perform the same analysis for population that we performed for count of wins.

# %%
populations = [val['population'] for val in combined_data.values()]
populations
# Out:
# [44494502,
#  24982688,
#  11433256,
#  209469333,
#  49648685,
#  4999441,
#  4087843,
#  5793636,
#  98423595,
#  66460344,
#  66977107,
#  82905782,
#  352721,
#  81800269,
#  126529100,
#  126190788,
#  36029138,
#  195874740,
#  4176873,
#  31989256,
#  37974750,
#  10283822,
#  144478050,
#  33699947,
#  15854360,
#  6982604,
#  51606633,
#  46796540,
#  10175214,
#  8513227,
#  11565204,
#  3449299]

# %%
print("Mean population:", np.mean(populations))
print("Median population:", np.median(populations))
print("Standard deviation of population:", np.std(populations))
# Out:
# Mean population: 51687460.84375
# Median population: 34864542.5
# Standard deviation of population: 55195121.60871871

# %% [markdown]
# ### Visualizations of Population

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2,figsize=(12,7))
fig.set_tight_layout(True)
# Histogram of Populations and Frequencies
ax1.hist(populations,color='blue',edgecolor='black')
ax1.set_xlabel('2018 Population')
ax1.set_ylabel('Frequency')
ax1.set_title('Distribution of population');
# Horizontal Bar Graph of Population by Country
ax2.barh(teams[::-1],populations[::-1],color='blue')
ax2.set_xlabel('2018 Population')
ax2.set_title('Population by Country');

# %% [markdown]
# ### Interpretation of Population Analysis¶
# Similar to the distribution of the number of wins, the distribution of population is skewed.
# It's hard to choose a single "typical" value here because there is so much variation.
# The countries with the largest populations (Brazil, Nigeria, and Russia) do not overlap with the countries with the most wins (Belgium, France, and Uruguay)

# %% [markdown]
# ### Analysis of Population vs. Performance
# Choose an appropriate statistical measure to analyze the relationship between population and performance, and create a visualization representing this relationship.
#
# Statistical Measure
# So far we have learned about only two statistics for understanding the relationship between variables: covariance and correlation. We will use correlation here, because that provides a more standardized, interpretable metric.

# %%
np.corrcoef(wins, populations)[0][1]
# Out:
# 0.07592816849178588

# %% [markdown]
# In the cell below, interpret this number. What direction is this correlation? Is it strong or weak?

# %%
# Replace None with appropriate code
"""
This is a very weak positive correlation. In other words, while
we have measured some positive association, we can't conclude that
a higher population is truly associated with more wins in general
because this value is so small.
"""
# Out:
# "\nThis is a very weak positive correlation. In other words, while\nwe have measured some positive association, we can't conclude that\na higher population is truly associated with more wins in general\nbecause this value is so small.\n"

# %% [markdown]
# ### Data Visualization
# A scatter plot is he most sensible form of data visualization for showing this relationship, because we have two dimensions of data, but there is no "increasing" variable (e.g. time) that would indicate we should use a line graph.

# %%
# Set up figure
fig, ax = plt.subplots(figsize=(8, 5))

# Basic scatter plot
ax.scatter(x=populations, y=wins, color="gray", alpha=0.5, s=100)
ax.set_xlabel("2018 Population")
ax.set_ylabel("2018 World Cup Wins")
ax.set_title("Population vs. World Cup Wins")

highlighted_points = {
    "Belgium": 2,  # Numbers are the index of that
    "Brazil": 3,  # country in populations & wins
    "France": 10,
    "Nigeria": 17,
}
for country, index in highlighted_points.items():
    # Get x and y position of data point
    x = populations[index]
    y = wins[index]
    # Move each point slightly down and to the left
    # (numbers were chosen by manually tweaking)
    xtext = x - (1.25e6 * len(country))
    ytext = y - 0.5
    # Annotate with relevant arguments
    ax.annotate(text=country, xy=(x, y), xytext=(xtext, ytext))

# %% [markdown]
# ### Data Visualization Interpretation
# Interpret this plot in the cell below. Does this align with the findings from the statistical measure (correlation), as well as the map shown at the beginning of this lab (showing the best results by country)?

# %%
'''This scatter plot does align with the findings from our
correlation calculation. The data points in the scatter
plot seem fairly randomly spread, and not grouped around
a straight line (with either a positive or a negative slope).

The annotations help us to see that the largest number of
wins were from countries with relatively small populations,
that the countries with the largest populations had relatively
few wins, and that many of the countries involved had small
populations as well as few wins.

Overall, this aligns well with the map at the beginning of
the lab, which shows both large and small countries with both
strong and weak performance. One important thing to note is
that our dataset was about the 2018 World Cup in particular,
but this map includes more data, so we can see that Brazil
(the largest country by population in the 2018 World Cup)
has been the World Cup champion before, even though their
performance was worse than Belgium's or France's in this
particular tournament.

Some further notes:
- Remember that correlation is not causation. Even though we
  detected a weak positive correlation, that is not saying
  that increasing the population of a country would necessarily
  improve their World Cup performance.
- At the same time, we have not *disproven* this causal link.
  In later lessons we will introduce additional statistical
  methods for detecting relationships between variables, but
  even then we won't be able to confirm that two variables are
  unrelated, we'll only be able to provide evidence that they
  are related (or fail to provide that evidence).'''
# Out:
# "This scatter plot does align with the findings from our\ncorrelation calculation. The data points in the scatter\nplot seem fairly randomly spread, and not grouped around\na straight line (with either a positive or a negative slope).\n\nThe annotations help us to see that the largest number of\nwins were from countries with relatively small populations,\nthat the countries with the largest populations had relatively\nfew wins, and that many of the countries involved had small\npopulations as well as few wins.\n\nOverall, this aligns well with the map at the beginning of\nthe lab, which shows both large and small countries with both\nstrong and weak performance. One important thing to note is\nthat our dataset was about the 2018 World Cup in particular,\nbut this map includes more data, so we can see that Brazil\n(the largest country by population in the 2018 World Cup)\nhas been the World Cup champion before, even though their\nperformance was worse than Belgium's or France's in this\nparticular tournament.\n\nSome further notes:\n- Remember that correlation is not causation. Even though we\n  detected a weak positive correlation, that is not saying\n  that increasing the population of a country would necessarily\n  improve their World Cup performance.\n- At the same time, we have not *disproven* this causal link.\n  In later lessons we will introduce additional statistical\n  methods for detecting relationships between variables, but\n  even then we won't be able to confirm that two variables are\n  unrelated, we'll only be able to provide evidence that they\n  are related (or fail to provide that evidence)."

# %% [markdown]
# Final Analysis
# What is the relationship between the population of a country and their performance in the 2018 FIFA World Cup?
#
# Overall, we found a very weakly positive relationship between the population of a country and their performance in the 2018 FIFA World Cup, as demonstrated by both the correlation between populations and wins, and the scatter plot.
#
# In the cell below, write down your thoughts on these questions:
#
# What are your thoughts on why you may see this result?
# What would you research next?
